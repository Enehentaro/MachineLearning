# %% [markdown]
# # 環境構築
#
#
#
# *   Pythonモジュールへのパス追加

# %%
# !pwd
# Out:
# /mnt/MachineLearning

# %%
import sys
sys.path.append('/mnt/MachineLearning/modules')

# %%
# %matplotlib inline
import os
import glob
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy import interpolate
import show_mod

# %% [markdown]
# # 前処理

# %%
#読み込むデータのパスの設定

data_path = './data'
input_list = glob.glob(data_path+"/*"+"/inputdata.csv")

input_list
# Out:
# ['./data/office1/inputdata.csv',
#  './data/office10/inputdata.csv',
#  './data/office15/inputdata.csv',
#  './data/office16/inputdata.csv',
#  './data/office2/inputdata.csv',
#  './data/office22/inputdata.csv',
#  './data/office28/inputdata.csv',
#  './data/office3/inputdata.csv',
#  './data/office7/inputdata.csv']

# %%
#input(空調条件等)の読み込み
df_input = None

for input_fname in input_list:
    df_read = pd.read_csv(input_fname, index_col="case_name")
    if df_input is None:
        df_input = df_read
    else:
        df_input = pd.concat([df_input, df_read])

df_input
# Out:
#                       aircon  ventilation exhaust    1_x   1_y    1_z  \
# case_name
# office1_960_164_aout     960          164       a  4.760  2.18  1.255
# office1_0_205_aout         0          205       a  4.760  2.18  1.255
# office1_660_41_bout      660           41       b  4.760  2.18  1.255
# office1_960_82_bout      960           82       b  4.760  2.18  1.255
# office1_960_205_bout     960          205       b  4.760  2.18  1.255
# ...                      ...          ...     ...    ...   ...    ...
# office7_960_82_bout      960           82       b  1.266  2.29  1.255
# office7_660_0            660            0     off  1.266  2.29  1.255
# office7_360_246_aout     360          246       a  1.266  2.29  1.255
# office7_960_0            960            0     off  1.266  2.29  1.255
# office7_960_246_bout     960          246       b  1.266  2.29  1.255
#
#                       1_angle    2_x    2_y    2_z  ...    4_z  4_angle  \
# case_name                                           ...
# office1_960_164_aout    180.0  3.285  3.160  1.255  ...  1.255     90.0
# office1_0_205_aout      180.0  3.285  3.160  1.255  ...  1.255     90.0
# office1_660_41_bout     180.0  3.285  3.160  1.255  ...  1.255     90.0
# office1_960_82_bout     180.0  3.285  3.160  1.255  ...  1.255     90.0
# office1_960_205_bout    180.0  3.285  3.160  1.255  ...  1.255     90.0
# ...                       ...    ...    ...    ...  ...    ...      ...
# office7_960_82_bout       0.0  3.140  3.059  1.255  ...  1.255     90.0
# office7_660_0             0.0  3.140  3.059  1.255  ...  1.255     90.0
# office7_360_246_aout      0.0  3.140  3.059  1.255  ...  1.255     90.0
# office7_960_0             0.0  3.140  3.059  1.255  ...  1.255     90.0
# office7_960_246_bout      0.0  3.140  3.059  1.255  ...  1.255     90.0
#
#                         5_x    5_y    5_z  5_angle  office_size_x  \
# case_name
# office1_960_164_aout  2.885  1.241  1.255     90.0            6.0
# office1_0_205_aout    2.885  1.241  1.255     90.0            6.0
# office1_660_41_bout   2.885  1.241  1.255     90.0            6.0
# office1_960_82_bout   2.885  1.241  1.255     90.0            6.0
# office1_960_205_bout  2.885  1.241  1.255     90.0            6.0
# ...                     ...    ...    ...      ...            ...
# office7_960_82_bout   2.760  1.141  1.255     90.0            9.0
# office7_660_0         2.760  1.141  1.255     90.0            9.0
# office7_360_246_aout  2.760  1.141  1.255     90.0            9.0
# office7_960_0         2.760  1.141  1.255     90.0            9.0
# office7_960_246_bout  2.760  1.141  1.255     90.0            9.0
#
#                       office_size_y  aircon_position_x  aircon_position_y
# case_name
# office1_960_164_aout            5.5                3.0               2.75
# office1_0_205_aout              5.5                3.0               2.75
# office1_660_41_bout             5.5                3.0               2.75
# office1_960_82_bout             5.5                3.0               2.75
# office1_960_205_bout            5.5                3.0               2.75
# ...                             ...                ...                ...
# office7_960_82_bout             4.0                4.5               2.00
# office7_660_0                   4.0                4.5               2.00
# office7_360_246_aout            4.0                4.5               2.00
# office7_960_0                   4.0                4.5               2.00
# office7_960_246_bout            4.0                4.5               2.00
#
# [263 rows x 27 columns]

# %%
#空調条件のみ抽出
df_meta = df_input.loc[:, ['aircon', 'ventilation', 'exhaust']]

df_meta
# Out:
#                       aircon  ventilation exhaust
# case_name
# office1_960_164_aout     960          164       a
# office1_0_205_aout         0          205       a
# office1_660_41_bout      660           41       b
# office1_960_82_bout      960           82       b
# office1_960_205_bout     960          205       b
# ...                      ...          ...     ...
# office7_960_82_bout      960           82       b
# office7_660_0            660            0     off
# office7_360_246_aout     360          246       a
# office7_960_0            960            0     off
# office7_960_246_bout     960          246       b
#
# [263 rows x 3 columns]

# %%
#排気口位置a,b,offをダミー変数化

df_meta = pd.get_dummies(df_meta, columns=['exhaust'])
# dummies = pd.get_dummies(df_input['exhaust'])
# df_input.drop("exhaust", axis=1, inplace=True)
# df_input = pd.concat([df_input, dummies], axis=1)
# df_input = df_input.reindex(columns=['aircon','ventilation','exhaust_a','b','off'
#           ,'1_x','1_y','1_z','1_angle','2_x','2_y','2_z','2_angle','3_x','3_y','3_z','3_angle'
#           ,'4_x','4_y','4_z','4_angle','5_x','5_y','5_z','5_angle',"office_size_x","office_size_y"
#           ,"aircon_position_x","aircon_position_y"])

df_meta
# Out:
#                       aircon  ventilation  exhaust_a  exhaust_b  exhaust_off
# case_name
# office1_960_164_aout     960          164          1          0            0
# office1_0_205_aout         0          205          1          0            0
# office1_660_41_bout      660           41          0          1            0
# office1_960_82_bout      960           82          0          1            0
# office1_960_205_bout     960          205          0          1            0
# ...                      ...          ...        ...        ...          ...
# office7_960_82_bout      960           82          0          1            0
# office7_660_0            660            0          0          0            1
# office7_360_246_aout     360          246          1          0            0
# office7_960_0            960            0          0          0            1
# office7_960_246_bout     960          246          0          1            0
#
# [263 rows x 5 columns]

# %%
df_count = pd.read_csv("./CountResults/sitting/count_from2sec_patientAverage.csv", index_col="casename")

df_count
# Out:
#                       num_drop  volume[ml]         RoI
# casename
# office2_0_0             6739.4    0.000067  204.224242
# office2_0_164_aout      7865.4    0.000063  238.345455
# office2_0_164_bout      6049.8    0.000062  183.327273
# office2_0_246_aout      7934.4    0.000050  240.436364
# office2_0_246_bout      7662.0    0.000082  232.181818
# ...                        ...         ...         ...
# office3_960_164_bout    5117.4    0.000075  155.072727
# office3_960_246_aout    4428.0    0.000073  134.181818
# office3_960_246_bout    3890.0    0.000066  117.878788
# office3_960_82_aout     5221.2    0.000072  158.218182
# office3_960_82_bout     5280.8    0.000053  160.024242
#
# [263 rows x 3 columns]

# %%
# df_meta.join(df_count)
df_total = pd.merge(df_meta, df_count, left_index=True, right_index=True)

df_total
# Out:
#                       aircon  ventilation  exhaust_a  exhaust_b  exhaust_off  \
# office1_960_164_aout     960          164          1          0            0
# office1_0_205_aout         0          205          1          0            0
# office1_660_41_bout      660           41          0          1            0
# office1_960_82_bout      960           82          0          1            0
# office1_960_205_bout     960          205          0          1            0
# ...                      ...          ...        ...        ...          ...
# office7_960_82_bout      960           82          0          1            0
# office7_660_0            660            0          0          0            1
# office7_360_246_aout     360          246          1          0            0
# office7_960_0            960            0          0          0            1
# office7_960_246_bout     960          246          0          1            0
#
#                       num_drop  volume[ml]         RoI
# office1_960_164_aout    5203.0    0.000049  157.666667
# office1_0_205_aout      7809.8    0.000076  236.660606
# office1_660_41_bout     5928.6    0.000046  179.654545
# office1_960_82_bout     6454.6    0.000083  195.593939
# office1_960_205_bout    5522.4    0.000056  167.345455
# ...                        ...         ...         ...
# office7_960_82_bout     7550.2    0.000107  209.727778
# office7_660_0           6621.8    0.000080  183.938889
# office7_360_246_aout    6474.2    0.000081  179.838889
# office7_960_0           7348.4    0.000095  204.122222
# office7_960_246_bout    7408.4    0.000102  205.788889
#
# [263 rows x 8 columns]

# %%
import seaborn as sns

sns.pairplot(df_total)

# %%
from sklearn import preprocessing

#入力データの標準化
stdscaler = preprocessing.StandardScaler()
stdscaler.fit(df_total)
df_total_tf = stdscaler.transform(df_total)

df_total_standardized = pd.DataFrame(df_total_tf, index=df_total.index, columns=df_total.columns)
df_total_standardized

# df_input_std = df_input.copy()
# for i in range(int(input_std.shape[1])):
#     df_input_std.iloc[:, i] = input_std[:, i]
# Out:
#                         aircon  ventilation  exhaust_a  exhaust_b  \
# office1_960_164_aout  1.261546     0.294952   1.143249  -0.874700
# office1_0_205_aout   -1.380856     0.785916   1.143249  -0.874700
# office1_660_41_bout   0.435795    -1.177940  -0.874700   1.143249
# office1_960_82_bout   1.261546    -0.686976  -0.874700   1.143249
# office1_960_205_bout  1.261546     0.785916  -0.874700   1.143249
# ...                        ...          ...        ...        ...
# office7_960_82_bout   1.261546    -0.686976  -0.874700   1.143249
# office7_660_0         0.435795    -1.668904  -0.874700  -0.874700
# office7_360_246_aout -0.389955     1.276880   1.143249  -0.874700
# office7_960_0         1.261546    -1.668904  -0.874700  -0.874700
# office7_960_246_bout  1.261546     1.276880  -0.874700   1.143249
#
#                       exhaust_off  num_drop  volume[ml]       RoI
# office1_960_164_aout    -0.391802 -0.950160   -1.018438  0.057732
# office1_0_205_aout      -0.391802  1.621106    0.595029  1.999648
# office1_660_41_bout     -0.391802 -0.234450   -1.226587  0.598262
# office1_960_82_bout     -0.391802  0.284379    0.977896  0.990102
# office1_960_205_bout    -0.391802 -0.635113   -0.585326  0.295666
# ...                           ...       ...         ...       ...
# office7_960_82_bout     -0.391802  1.365045    2.398745  1.337555
# office7_660_0            2.552310  0.449300    0.818117  0.703584
# office7_360_246_aout    -0.391802  0.303712    0.859225  0.602794
# office7_960_0            2.552310  1.165996    1.690738  1.199753
# office7_960_246_bout    -0.391802  1.225178    2.115534  1.240725
#
# [263 rows x 8 columns]

# %%
df_meta_standardized = df_total_standardized[["aircon", "ventilation", "exhaust_a", "exhaust_b", "exhaust_off"]]

df_RoI_standardized = df_total_standardized["RoI"]

# %%
# import numpy as np
# import pointCloud_sampling as pcs

# # rng = np.random.default_rng()

# #予め点群をサンプリングしておいたものを取得
# sampledPointCloud_dict = pcs.read_sampledPointCloud('/content/drive/MyDrive/ML/PointNetTrial/data/pointCloud_sampled')

# sampledPointCloud_dict
# Out:
# {'office2': array([[2.832 , 4.588 , 1.263 ],
#         [3.1   , 1.55  , 0.4833],
#         [2.709 , 3.093 , 1.244 ],
#         ...,
#         [2.759 , 3.36  , 0.48  ],
#         [4.88  , 2.81  , 1.264 ],
#         [4.204 , 1.661 , 0.75  ]], dtype=float32),
#  'office1': array([[1.107 , 2.073 , 0.7   ],
#         [3.351 , 3.223 , 1.347 ],
#         [3.775 , 2.427 , 0.5866],
#         ...,
#         [3.429 , 2.181 , 0.    ],
#         [2.571 , 2.373 , 0.05  ],
#         [3.251 , 3.485 , 0.8337]], dtype=float32),
#  'office16': array([[6.079 , 3.707 , 1.014 ],
#         [2.294 , 5.    , 2.212 ],
#         [5.793 , 1.455 , 1.233 ],
#         ...,
#         [3.407 , 0.6372, 0.    ],
#         [4.553 , 1.361 , 1.168 ],
#         [6.197 , 3.81  , 0.5341]], dtype=float32),
#  'office22': array([[3.693 , 3.918 , 0.1951],
#         [5.5   , 2.623 , 0.3624],
#         [5.201 , 4.189 , 0.8347],
#         ...,
#         [5.507 , 2.542 , 0.4169],
#         [4.744 , 2.955 , 0.7   ],
#         [2.534 , 3.035 , 0.    ]], dtype=float32),
#  'office7': array([[4.668 , 3.155 , 1.266 ],
#         [3.197 , 3.118 , 1.239 ],
#         [2.2   , 2.722 , 0.75  ],
#         ...,
#         [4.257 , 2.125 , 0.7   ],
#         [0.    , 1.027 , 0.9922],
#         [3.213 , 3.2   , 1.445 ]], dtype=float32),
#  'office10': array([[3.094 , 4.017 , 1.224 ],
#         [4.556 , 3.989 , 1.243 ],
#         [2.588 , 2.189 , 0.48  ],
#         ...,
#         [2.567 , 2.027 , 0.8228],
#         [1.115 , 3.099 , 1.29  ],
#         [1.941 , 3.65  , 0.05  ]], dtype=float32),
#  'office28': array([[2.809 , 5.035 , 0.8685],
#         [4.488 , 4.825 , 1.253 ],
#         [1.542 , 3.927 , 0.3949],
#         ...,
#         [5.05  , 4.299 , 0.2216],
#         [7.323 , 2.361 , 0.    ],
#         [4.55  , 2.751 , 0.9646]], dtype=float32),
#  'office15': array([[2.002 , 4.404 , 0.7   ],
#         [1.947 , 2.25  , 0.3741],
#         [1.093 , 4.655 , 1.289 ],
#         ...,
#         [1.529 , 3.435 , 0.4161],
#         [3.064 , 2.508 , 1.218 ],
#         [1.57  , 3.878 , 0.75  ]], dtype=float32),
#  'office3': array([[0.2163, 3.612 , 0.    ],
#         [4.915 , 3.894 , 1.452 ],
#         [5.3   , 0.45  , 0.169 ],
#         ...,
#         [5.47  , 0.7804, 0.1317],
#         [5.157 , 2.651 , 0.    ],
#         [4.937 , 3.604 , 0.9034]], dtype=float32)}

# %%
import os
import random
import numpy as np
import json
import glob
from stl import mesh
from enum import Enum, auto

# 列挙型の定義
class OfficePart(Enum):
    aircon = auto()
    airvent = auto()
    body = auto()
    room = auto()
    desks = auto()


"""
データの前処理

オフィスモデル（STLファイル）を読み込み、点群情報のみ取り出し、
ランダムサンプリングで指定個の点群(ndarray)にする。
"""
officemodel_path = 'OfficeModel/model_origin'
# office_list = os.listdir(officemodel_path)
case_list = [s.replace('office', 'case') for s in os.listdir(data_path)]
# office_list = ['office1', 'office2', 'office3', 'office7', 'office10', 'office15', 'office16', 'office22', 'office28']
# print(office_list)

# 列挙型のメンバーの列挙
for part in OfficePart:
    print(part)
    
NUM_POINTS = 2048

sampledPointCloud_dict = {}
for casename in case_list:
    officename = casename.replace('case', 'office') 
    pc_dict = {}
    for part in OfficePart:
        path = officemodel_path + '/' + casename + '/' + part.name
        # print(path)
        stl_list = glob.glob(path + "/*.stl")
        print(stl_list)
        pc_list = []
        for stlfname in stl_list:
            for mesh_read in mesh.Mesh.from_multi_file(stlfname):
                points = mesh_read.points.reshape([-1, 3])
                pc_list.append(points)

        points_concat = np.concatenate(pc_list)
        points_concat = np.unique(points_concat, axis=0)
        pc_dict[part] = points_concat.copy()
                        

    pc_aircon = pc_dict[OfficePart.aircon]
    pc_airvent = pc_dict[OfficePart.airvent]
    pc_room = pc_dict[OfficePart.room]
    pc_base = np.concatenate([pc_aircon, pc_airvent, pc_room])
    num_sampling = NUM_POINTS - len(pc_base)

#     pc_forSampling = np.concatenate([pc_dict[OfficePart.body], pc_dict[OfficePart.desks]])
# #     pc_forSampling = pc_dict[OfficePart.desks]
#     print(f'#sampling {num_sampling} from {len(pc_forSampling)}', )
#     rand_list = random.sample(range(len(pc_forSampling)), k=num_sampling)
#     pc_sampled = pc_forSampling[rand_list, :]
    
    num_sampling_body = num_sampling // 2
    num_sampling_desks = num_sampling - num_sampling_body
    
    print("num_sampling_body = ", num_sampling_body)
    pc_body = pc_dict[OfficePart.body]
    rand_list = random.sample(range(len(pc_body)), k=num_sampling_body)
    pc_sampled_body = pc_body[rand_list, :]
    
    print("num_sampling_desks = ", num_sampling_desks)
    pc_desks = pc_dict[OfficePart.desks]
    rand_list = random.sample(range(len(pc_desks)), k=num_sampling_desks)
    pc_sampled_desks = pc_desks[rand_list, :]
    
    
#     pointCloud = np.concatenate([pc_base, pc_sampled])
    pointCloud = np.concatenate([pc_base, pc_sampled_body, pc_sampled_desks])
    print(pointCloud.shape)
    sampledPointCloud_dict[officename] = pointCloud
# Out:
# OfficePart.aircon
# OfficePart.airvent
# OfficePart.body
# OfficePart.room
# OfficePart.desks
# ['OfficeModel/model_origin/case1/aircon/aircon_body.stl', 'OfficeModel/model_origin/case1/aircon/aircon_inlets.stl', 'OfficeModel/model_origin/case1/aircon/aircon_outlet.stl']
# ['OfficeModel/model_origin/case1/airvent/20210812_airvent_a.stl', 'OfficeModel/model_origin/case1/airvent/airvent_b.stl']
# ['OfficeModel/model_origin/case1/body/20210810_bodies.stl']
# ['OfficeModel/model_origin/case1/room/20210810_office_bottom.stl', 'OfficeModel/model_origin/case1/room/20210810_office_side1.stl', 'OfficeModel/model_origin/case1/room/20210810_office_side2.stl', 'OfficeModel/model_origin/case1/room/20210810_office_side3.stl', 'OfficeModel/model_origin/case1/room/20210810_office_top.stl', 'OfficeModel/model_origin/case1/room/20210812_office_side4.stl']
# ['OfficeModel/model_origin/case1/desks/20210810_desks.stl']
# num_sampling_body =  720
# num_sampling_desks =  720
# (2048, 3)
# ['OfficeModel/model_origin/case10/aircon/20210812_aircon_inlets_model3.stl', 'OfficeModel/model_origin/case10/aircon/aircon_body_model3.stl', 'OfficeModel/model_origin/case10/aircon/aircon_outlet_model3.stl']
# ['OfficeModel/model_origin/case10/airvent/20210812_airvent_a_model3.stl', 'OfficeModel/model_origin/case10/airvent/20210812_airvent_b_model3.stl']
# ['OfficeModel/model_origin/case10/body/20210812_bodies_case10.stl']
# ['OfficeModel/model_origin/case10/room/20210812_office_bottom_model3.stl', 'OfficeModel/model_origin/case10/room/20210812_office_side1_model3.stl', 'OfficeModel/model_origin/case10/room/20210812_office_side2_model3.stl', 'OfficeModel/model_origin/case10/room/20210812_office_side3_model3.stl', 'OfficeModel/model_origin/case10/room/20210812_office_side4_model3.stl', 'OfficeModel/model_origin/case10/room/20210812_office_top_model3.stl']
# ['OfficeModel/model_origin/case10/desks/20210812_desks_case10.stl']
# num_sampling_body =  720
# num_sampling_desks =  720
# (2048, 3)
# ['OfficeModel/model_origin/case15/aircon/20210812_aircon_inlets_model3.stl', 'OfficeModel/model_origin/case15/aircon/aircon_body_model3.stl', 'OfficeModel/model_origin/case15/aircon/aircon_outlet_model3.stl']
# ['OfficeModel/model_origin/case15/airvent/20210812_airvent_a_model3.stl', 'OfficeModel/model_origin/case15/airvent/20210812_airvent_b_model3.stl']
# ['OfficeModel/model_origin/case15/body/20210812_bodies_case15.stl']
# ['OfficeModel/model_origin/case15/room/20210812_office_bottom_model3.stl', 'OfficeModel/model_origin/case15/room/20210812_office_side1_model3.stl', 'OfficeModel/model_origin/case15/room/20210812_office_side2_model3.stl', 'OfficeModel/model_origin/case15/room/20210812_office_side3_model3.stl', 'OfficeModel/model_origin/case15/room/20210812_office_side4_model3.stl', 'OfficeModel/model_origin/case15/room/20210812_office_top_model3.stl']
# ['OfficeModel/model_origin/case15/desks/20210812_desks_case15.stl']
# num_sampling_body =  720
# num_sampling_desks =  720
# (2048, 3)
# ['OfficeModel/model_origin/case16/aircon/20210812_aircon_inlets_model4.stl', 'OfficeModel/model_origin/case16/aircon/aircon_body_model4.stl', 'OfficeModel/model_origin/case16/aircon/aircon_outlet_model4.stl']
# ['OfficeModel/model_origin/case16/airvent/20210812_airvent_a_model4.stl', 'OfficeModel/model_origin/case16/airvent/20210812_airvent_b_model4.stl']
# ['OfficeModel/model_origin/case16/body/20210812_bodies_case16.stl']
# ['OfficeModel/model_origin/case16/room/20210812_office_bottom_model4.stl', 'OfficeModel/model_origin/case16/room/20210812_office_side1_model4.stl', 'OfficeModel/model_origin/case16/room/20210812_office_side2_model4.stl', 'OfficeModel/model_origin/case16/room/20210812_office_side3_model4.stl', 'OfficeModel/model_origin/case16/room/20210812_office_side4_model4.stl', 'OfficeModel/model_origin/case16/room/20210812_office_top_model4.stl']
# ['OfficeModel/model_origin/case16/desks/20210812_desks_case16.stl']
# num_sampling_body =  720
# num_sampling_desks =  720
# (2048, 3)
# ['OfficeModel/model_origin/case2/aircon/aircon_body.stl', 'OfficeModel/model_origin/case2/aircon/aircon_inlets.stl', 'OfficeModel/model_origin/case2/aircon/aircon_outlet.stl']
# ['OfficeModel/model_origin/case2/airvent/20210812_airvent_a.stl', 'OfficeModel/model_origin/case2/airvent/airvent_b.stl']
# ['OfficeModel/model_origin/case2/body/20210812_bodies_case2.stl']
# ['OfficeModel/model_origin/case2/room/20210810_office_bottom.stl', 'OfficeModel/model_origin/case2/room/20210810_office_side1.stl', 'OfficeModel/model_origin/case2/room/20210810_office_side2.stl', 'OfficeModel/model_origin/case2/room/20210810_office_side3.stl', 'OfficeModel/model_origin/case2/room/20210810_office_top.stl', 'OfficeModel/model_origin/case2/room/20210812_office_side4.stl']
# ['OfficeModel/model_origin/case2/desks/20210812_desks_case2.stl']
# num_sampling_body =  720
# num_sampling_desks =  720
# (2048, 3)
# ['OfficeModel/model_origin/case22/aircon/20210812_aircon_inlets_model5.stl', 'OfficeModel/model_origin/case22/aircon/aircon_body_model5.stl', 'OfficeModel/model_origin/case22/aircon/aircon_outlet_model5.stl']
# ['OfficeModel/model_origin/case22/airvent/20210812_airvent_a_model5.stl', 'OfficeModel/model_origin/case22/airvent/20210812_airvent_b_model5.stl']
# ['OfficeModel/model_origin/case22/body/20210812_bodies_case22.stl']
# ['OfficeModel/model_origin/case22/room/20210812_office_bottom_model5.stl', 'OfficeModel/model_origin/case22/room/20210812_office_side1_model5.stl', 'OfficeModel/model_origin/case22/room/20210812_office_side2_model5.stl', 'OfficeModel/model_origin/case22/room/20210812_office_side3_model5.stl', 'OfficeModel/model_origin/case22/room/20210812_office_side4_model5.stl', 'OfficeModel/model_origin/case22/room/20210812_office_top_model5.stl']
# ['OfficeModel/model_origin/case22/desks/20210812_desks_case22.stl']
# num_sampling_body =  688
# num_sampling_desks =  688
# (2048, 3)
# ['OfficeModel/model_origin/case28/aircon/20210812_aircon_inlets_model6.stl', 'OfficeModel/model_origin/case28/aircon/aircon_body_model6.stl', 'OfficeModel/model_origin/case28/aircon/aircon_outlet_model6.stl']
# ['OfficeModel/model_origin/case28/airvent/20210812_airvent_a_model6.stl', 'OfficeModel/model_origin/case28/airvent/20210812_airvent_b_model6.stl']
# ['OfficeModel/model_origin/case28/body/20210812_bodies_case28.stl']
# ['OfficeModel/model_origin/case28/room/20210812_office_bottom_model6.stl', 'OfficeModel/model_origin/case28/room/20210812_office_side1_model6.stl', 'OfficeModel/model_origin/case28/room/20210812_office_side2_model6.stl', 'OfficeModel/model_origin/case28/room/20210812_office_side3_model6.stl', 'OfficeModel/model_origin/case28/room/20210812_office_side4_model6.stl', 'OfficeModel/model_origin/case28/room/20210812_office_top_model6.stl']
# ['OfficeModel/model_origin/case28/desks/20210812_desks_case28.stl']
# num_sampling_body =  691
# num_sampling_desks =  691
# (2048, 3)
# ['OfficeModel/model_origin/case3/aircon/aircon_body.stl', 'OfficeModel/model_origin/case3/aircon/aircon_inlets.stl', 'OfficeModel/model_origin/case3/aircon/aircon_outlet.stl']
# ['OfficeModel/model_origin/case3/airvent/20210812_airvent_a.stl', 'OfficeModel/model_origin/case3/airvent/airvent_b.stl']
# ['OfficeModel/model_origin/case3/body/20210812_bodies_case3.stl']
# ['OfficeModel/model_origin/case3/room/20210810_office_bottom.stl', 'OfficeModel/model_origin/case3/room/20210810_office_side1.stl', 'OfficeModel/model_origin/case3/room/20210810_office_side2.stl', 'OfficeModel/model_origin/case3/room/20210810_office_side3.stl', 'OfficeModel/model_origin/case3/room/20210810_office_top.stl', 'OfficeModel/model_origin/case3/room/20210812_office_side4.stl']
# ['OfficeModel/model_origin/case3/desks/20210812_desks_case3.stl']
# num_sampling_body =  720
# num_sampling_desks =  720
# (2048, 3)
# ['OfficeModel/model_origin/case7/aircon/20210812_aircon_inlets_model2.stl', 'OfficeModel/model_origin/case7/aircon/aircon_body_model2.stl', 'OfficeModel/model_origin/case7/aircon/aircon_outlet_model2.stl']
# ['OfficeModel/model_origin/case7/airvent/20210812_airvent_a_model2.stl', 'OfficeModel/model_origin/case7/airvent/20210812_airvent_b_model2.stl']
# ['OfficeModel/model_origin/case7/body/20210812_bodies_case7.stl']
# ['OfficeModel/model_origin/case7/room/20210812_office_bottom_model2.stl', 'OfficeModel/model_origin/case7/room/20210812_office_side1_model2.stl', 'OfficeModel/model_origin/case7/room/20210812_office_side2_model2.stl', 'OfficeModel/model_origin/case7/room/20210812_office_side3_model2.stl', 'OfficeModel/model_origin/case7/room/20210812_office_side4_model2.stl', 'OfficeModel/model_origin/case7/room/20210812_office_top_model2.stl']
# ['OfficeModel/model_origin/case7/desks/20210812_desks_case7.stl']
# num_sampling_body =  720
# num_sampling_desks =  720
# (2048, 3)

# %%
from matplotlib import pyplot as plt

def plot3d_points(point_cloud):
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(projection="3d")
    ax.scatter(point_cloud[:, 0], point_cloud[:, 1], point_cloud[:, 2], alpha=0.4, s=2)
    # ax.set_axis_off()
    plt.show()
    
plot3d_points(sampledPointCloud_dict['office10'])

# %%
import numpy as np
'''
点群シャッフルによるデータ増強
'''
rng = np.random.default_rng()

pointCloud_augumented_dict = {}
for office_name, pointCloud in sampledPointCloud_dict.items():
    pc_list = []
    for i in range(4):
        pc = pointCloud.copy()

        if i >= 1:
            #点群のシャッフル
            rng.shuffle(pc)

        pc_list.append(pc)

    pointCloud_augumented_dict[office_name] = pc_list

pointCloud_augumented_dict
# Out:
# {'office1': [array([[2.5   , 2.25  , 2.6   ],
#          [2.5   , 2.375 , 2.6   ],
#          [2.5   , 2.45  , 2.6   ],
#          ...,
#          [1.925 , 1.525 , 0.5375],
#          [3.3   , 3.25  , 0.05  ],
#          [2.035 , 3.485 , 0.96  ]], dtype=float32),
#   array([[2.583533 , 3.05     , 2.566467 ],
#          [3.3      , 3.133533 , 2.566467 ],
#          [2.035488 , 3.254372 , 1.09709  ],
#          ...,
#          [1.925    , 1.741667 , 0.05     ],
#          [3.3      , 2.3503   , 2.5497   ],
#          [3.825    , 1.5      , 0.2833333]], dtype=float32),
#   array([[4.656392 , 2.240756 , 0.7325774],
#          [2.6003   , 3.05     , 2.5497   ],
#          [3.3      , 2.4      , 2.5375   ],
#          ...,
#          [1.263256 , 1.234858 , 0.8361718],
#          [3.35     , 2.45     , 2.566467 ],
#          [1.607448 , 1.022934 , 1.12066  ]], dtype=float32),
#   array([[2.85     , 1.15     , 0.265    ],
#          [3.725    , 2.225    , 0.2833333],
#          [2.566167 , 3.05     , 2.6      ],
#          ...,
#          [2.7      , 3.145455 , 2.545455 ],
#          [1.767384 , 3.230094 , 0.9524003],
#          [1.948179 , 3.345538 , 0.657453 ]], dtype=float32)],
#  'office10': [array([[3.       , 2.5      , 2.6      ],
#          [3.       , 2.625    , 2.6      ],
#          [3.       , 2.7      , 2.6      ],
#          ...,
#          [3.401667 , 2.275    , 0.7      ],
#          [0.975    , 3.1      , 0.6733333],
#          [2.635    , 3.1875   , 0.05     ]], dtype=float32),
#   array([[3.866767 , 3.3      , 2.6      ],
#          [4.795    , 4.285    , 0.745    ],
#          [4.830638 , 4.057806 , 0.8754651],
#          ...,
#          [3.32     , 3.3      , 2.6      ],
#          [3.8      , 3.1      , 2.6      ],
#          [3.205    , 4.285    , 0.6733333]], dtype=float32),
#   array([[3.685   , 2.415   , 0.75    ],
#          [5.085   , 2.325   , 0.7     ],
#          [0.925   , 3.03    , 0.53    ],
#          ...,
#          [3.685   , 3.305   , 0.75    ],
#          [5.085   , 3.165   , 0.75    ],
#          [3.8     , 2.640909, 2.509091]], dtype=float32),
#   array([[4.263941 , 1.811421 , 0.6114154],
#          [2.76     , 2.       , 0.3725   ],
#          [4.851667 , 2.275    , 0.7      ],
#          ...,
#          [2.958564 , 4.053843 , 0.6769962],
#          [1.108231 , 2.867218 , 0.7073165],
#          [3.16     , 4.       , 0.265    ]], dtype=float32)],
#  'office15': [array([[3.       , 2.5      , 2.6      ],
#          [3.       , 2.625    , 2.6      ],
#          [3.       , 2.7      , 2.6      ],
#          ...,
#          [0.94     , 1.87     , 0.6733333],
#          [1.7125   , 4.2      , 0.7      ],
#          [2.0375   , 2.35     , 0.05     ]], dtype=float32),
#   array([[2.2      , 2.75     , 0.375    ],
#          [3.68     , 2.7      , 2.6      ],
#          [3.41668  , 4.107955 , 0.3333365],
#          ...,
#          [2.89     , 3.93     , 0.96     ],
#          [2.89     , 2.445    , 0.48     ],
#          [3.125    , 2.525    , 0.265    ]], dtype=float32),
#   array([[3.074421 , 4.040874 , 1.113345 ],
#          [1.55     , 3.75     , 0.7      ],
#          [3.078    , 2.34     , 0.53     ],
#          ...,
#          [1.272    , 1.59     , 0.48     ],
#          [1.110286 , 1.867161 , 1.301092 ],
#          [1.014505 , 1.742947 , 0.6963945]], dtype=float32),
#   array([[3.8      , 3.386364 , 2.536364 ],
#          [3.8      , 2.65     , 2.5375   ],
#          [2.984    , 3.79     , 0.48     ],
#          ...,
#          [0.       , 6.       , 2.6      ],
#          [3.133833 , 3.3      , 2.516167 ],
#          [1.266534 , 3.23257  , 0.7094182]], dtype=float32)],
#  'office16': [array([[4.      , 2.      , 2.6     ],
#          [4.      , 2.125   , 2.6     ],
#          [4.      , 2.2     , 2.6     ],
#          ...,
#          [8.06    , 2.705   , 0.48    ],
#          [4.73    , 3.81    , 0.48    ],
#          [6.066667, 3.2     , 0.7     ]], dtype=float32),
#   array([[4.612011 , 3.200167 , 0.2777051],
#          [7.41215  , 2.644486 , 0.5774363],
#          [5.739999 , 1.759385 , 0.7038524],
#          ...,
#          [7.2875   , 1.875    , 0.05     ],
#          [4.505    , 1.76     , 0.48     ],
#          [6.367157 , 3.447027 , 0.7284787]], dtype=float32),
#   array([[4.917067 , 2.8      , 2.567067 ],
#          [4.572438 , 1.449708 , 0.6748077],
#          [5.033333 , 1.85     , 0.05     ],
#          ...,
#          [4.59     , 3.666    , 0.48     ],
#          [4.2      , 2.068182 , 2.581818 ],
#          [4.2      , 2.0997   , 2.566467 ]], dtype=float32),
#   array([[4.425   , 1.475   , 0.336667],
#          [4.0997  , 2.8     , 2.566467],
#          [7.696667, 2.285   , 0.53    ],
#          ...,
#          [4.85    , 2.2     , 2.5875  ],
#          [4.8     , 2.15    , 2.5875  ],
#          [4.87    , 3.76    , 0.673333]], dtype=float32)],
#  'office2': [array([[2.5     , 2.25    , 2.6     ],
#          [2.5     , 2.375   , 2.6     ],
#          [2.5     , 2.45    , 2.6     ],
#          ...,
#          [4.233333, 2.2     , 0.7     ],
#          [4.291667, 2.25    , 0.75    ],
#          [4.525   , 2.405556, 0.75    ]], dtype=float32),
#   array([[2.625    , 3.05     , 2.6      ],
#          [3.35     , 3.05     , 2.5      ],
#          [3.35     , 3.05     , 2.5375   ],
#          ...,
#          [4.663359 , 4.243979 , 0.6518211],
#          [2.825    , 4.125    , 2.6      ],
#          [3.94888  , 1.167533 , 0.9839677]], dtype=float32),
#   array([[2.744067 , 4.448505 , 1.042991 ],
#          [4.984665 , 2.855226 , 0.7588638],
#          [2.725494 , 4.364019 , 1.071451 ],
#          ...,
#          [4.473212 , 4.392262 , 0.297666 ],
#          [4.15     , 2.25     , 0.05     ],
#          [2.55     , 2.65     , 2.6      ]], dtype=float32),
#   array([[3.5      , 2.5      , 2.6      ],
#          [4.3125   , 3.25     , 0.05     ],
#          [4.905181 , 4.338877 , 0.7799323],
#          ...,
#          [4.984002 , 2.816721 , 1.169453 ],
#          [0.       , 0.       , 0.       ],
#          [4.375971 , 2.545704 , 0.1595385]], dtype=float32)],
#  'office22': [array([[3.85     , 2.75     , 2.6      ],
#          [3.85     , 2.875    , 2.6      ],
#          [3.85     , 2.95     , 2.6      ],
#          ...,
#          [2.85     , 3.766667 , 0.5166667],
#          [3.55     , 3.25     , 0.2125   ],
#          [5.41     , 2.04     , 0.8166667]], dtype=float32),
#   array([[4.1      , 2.196667 , 0.48     ],
#          [5.796652 , 2.403183 , 0.7863184],
#          [4.05     , 2.9      , 2.5      ],
#          ...,
#          [3.990909 , 3.55     , 2.509091 ],
#          [5.7      , 3.533333 , 0.05     ],
#          [5.24     , 4.56     , 0.8525   ]], dtype=float32),
#   array([[4.9      , 3.016667 , 0.2833333],
#          [3.759383 , 3.950519 , 0.3664187],
#          [3.55     , 3.3      , 0.7      ],
#          ...,
#          [3.5      , 2.783333 , 0.05     ],
#          [4.85     , 3.35     , 2.6      ],
#          [4.85     , 3.125    , 2.6      ]], dtype=float32),
#   array([[3.607683 , 4.418073 , 0.5731122],
#          [3.50978  , 4.383348 , 1.384244 ],
#          [5.41     , 2.353333 , 0.48     ],
#          ...,
#          [3.55     , 2.816667 , 0.7      ],
#          [4.05     , 2.9      , 2.5875   ],
#          [5.494062 , 2.625541 , 0.4836985]], dtype=float32)],
#  'office28': [array([[4.35     , 2.5      , 2.6      ],
#          [4.35     , 2.625    , 2.6      ],
#          [4.35     , 2.7      , 2.6      ],
#          ...,
#          [5.05     , 3.775    , 0.5375   ],
#          [3.7      , 3.125    , 0.4833333],
#          [2.25     , 3.308333 , 0.75     ]], dtype=float32),
#   array([[1.581951 , 3.940321 , 0.2527234],
#          [2.2      , 4.45     , 0.2666667],
#          [5.15     , 3.383533 , 2.6      ],
#          ...,
#          [2.847393 , 2.597173 , 0.8767467],
#          [5.35     , 2.5      , 2.6      ],
#          [4.55     , 2.582933 , 2.583233 ]], dtype=float32),
#   array([[5.15    , 3.35    , 2.5497  ],
#          [3.65    , 3.541667, 0.05    ],
#          [4.5     , 4.565   , 0.53    ],
#          ...,
#          [2.985801, 2.758556, 1.266844],
#          [4.627892, 4.917978, 1.153311],
#          [4.272453, 4.433664, 0.588793]], dtype=float32),
#   array([[5.2      , 2.7      , 2.5497   ],
#          [4.554749 , 2.804502 , 0.6229589],
#          [5.281818 , 2.7      , 2.581818 ],
#          ...,
#          [5.15     , 2.566767 , 2.583233 ],
#          [4.79     , 2.65     , 2.6      ],
#          [1.019399 , 3.942175 , 1.075532 ]], dtype=float32)],
#  'office3': [array([[2.5      , 2.25     , 2.6      ],
#          [2.5      , 2.375    , 2.6      ],
#          [2.5      , 2.45     , 2.6      ],
#          ...,
#          [1.31     , 0.62     , 0.8166667],
#          [4.975    , 2.425    , 0.48     ],
#          [5.25     , 4.0625   , 0.7      ]], dtype=float32),
#   array([[1.183638 , 0.3490601, 1.062603 ],
#          [4.81378  , 3.851801 , 1.373789 ],
#          [1.26     , 0.55     , 0.53     ],
#          ...,
#          [0.6072717, 1.799088 , 0.1613248],
#          [3.366767 , 3.05     , 2.5497   ],
#          [0.6572427, 0.716789 , 0.5901658]], dtype=float32),
#   array([[5.323402 , 2.522428 , 0.5006172],
#          [3.3      , 3.1503   , 2.6      ],
#          [0.7809775, 2.093996 , 0.6955576],
#          ...,
#          [5.625    , 1.4      , 0.05     ],
#          [0.9466667, 0.48     , 0.53     ],
#          [5.483333 , 1.45     , 0.05     ]], dtype=float32),
#   array([[4.941642 , 3.796732 , 0.8357254],
#          [1.23476  , 0.5501352, 0.9091379],
#          [4.69     , 2.19     , 0.96     ],
#          ...,
#          [0.9099179, 0.5256441, 0.672611 ],
#          [1.048856 , 0.6487931, 1.011963 ],
#          [4.975    , 2.375    , 0.1575   ]], dtype=float32)],
#  'office7': [array([[4.       , 1.5      , 2.6      ],
#          [4.       , 1.625    , 2.6      ],
#          [4.       , 1.7      , 2.6      ],
#          ...,
#          [4.67     , 3.385    , 0.48     ],
#          [3.08     , 3.335    , 0.8166667],
#          [4.13     , 1.335    , 0.53     ]], dtype=float32),
#   array([[4.05    , 1.9     , 2.6     ],
#          [4.4     , 1.375   , 0.75    ],
#          [4.2     , 1.633233, 2.516767],
#          ...,
#          [4.85    , 1.7     , 2.583233],
#          [4.9003  , 1.7     , 2.6     ],
#          [4.116467, 1.7     , 2.583233]], dtype=float32),
#   array([[4.477087 , 3.28251  , 0.8885449],
#          [2.597794 , 1.37402  , 0.3764767],
#          [3.7      , 2.825    , 0.7      ],
#          ...,
#          [4.575    , 3.15     , 0.1933333],
#          [4.178897 , 1.216231 , 0.6210251],
#          [5.05     , 2.775    , 0.2666667]], dtype=float32),
#   array([[1.241297 , 2.432485 , 0.5813248],
#          [1.12386  , 2.519488 , 1.138234 ],
#          [4.0997   , 2.3      , 2.6      ],
#          ...,
#          [2.944394 , 1.0716   , 0.9120755],
#          [4.32     , 2.45     , 2.6      ],
#          [4.066667 , 1.425    , 0.7      ]], dtype=float32)]}

# %%
'''
点群データ増強に合わせて、メタデータや感染リスク分布のデータも複製して増やす
'''
case_index_list = list(df_total.index)


case_index_augumented_list = []

pointCloudArray_list = []
metaArray_list = []

RoI_list = []

for case_index in case_index_list:
    office_name = case_index.split('_', maxsplit=1)[0]
    pc_list = pointCloud_augumented_dict[office_name]
    for augumentID, pointCloud in enumerate(pc_list):
        case_index_augumented_list.append(case_index + '-' + str(augumentID))
        pointCloudArray_list.append(pointCloud)
        metaArray_list.append(df_meta_standardized.loc[case_index])
        RoI_list.append(df_RoI_standardized.loc[case_index])

case_index_array = np.array(case_index_augumented_list)
pointCloudArray = np.array(pointCloudArray_list)
metaArray = np.array(metaArray_list)
RoIArray = np.array(RoI_list)

# %%
print(case_index_array.shape)

print(pointCloudArray.shape)
print(metaArray.shape)

print(RoIArray.shape)
# Out:
# (1052,)
# (1052, 2048, 3)
# (1052, 5)
# (1052,)

# %%
plot3d_points(pointCloudArray[0, :,:])

# %%
plot3d_points(sampledPointCloud_dict["office7"])

# %% [markdown]
# # モデル実装

# %%
import IPython
import keras_tuner as kt

# %%
from tensorflow import keras
from PointNet import conv_bn, dense_bn


def permutation_invariant_network_builder(hp, inputs):
    """
    順序不変性（PointNetからtnetを除去したもの）モデルビルダー関数

    ハイパーパラメータを引数にとる（チューニング用）
    """

    x = inputs
    
    hp_conv_layers_1 = hp.Int('conv_bn_layers', min_value = 1, max_value = 4, step = 1)
    for i in range(hp_conv_layers_1):
        hp_filters = hp.Int(f'filters_bn-{i}', min_value = 32, max_value = 512, step = 32)
        x = conv_bn(x, hp_filters)
    
    x = keras.layers.GlobalMaxPooling1D()(x)
    
    # Tune the dropout rate for the optimizer 
    # hp_dropout_rate = hp.Choice('dropout_rate', values = [0.3, 0.5, 0.9])
    
    hp_dense_layers = hp.Int('dense_bn_layers', min_value = 0, max_value = 4, step = 1)
    for i in range(hp_dense_layers):
        hp_units = hp.Int(f'units_bn_{i}', min_value = 32, max_value = 512, step = 32)
        x = dense_bn(x, hp_units)
        # x = keras.layers.Dropout(hp_dropout_rate)(x)

    hp_features = hp.Int('features', min_value = 4, max_value = 64, step = 4)
    features = keras.layers.Dense(hp_features, activation="softmax")(x)


    return features

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from keras.layers.convolutional import Conv2DTranspose, Conv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Activation
from keras.layers import LeakyReLU

# %%
from tensorflow.python.client import device_lib; print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9622499177811939915
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 9833938944
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 10190316827539546501
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:06:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]
# 2022-10-09 03:32:41.224115: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-09 03:32:41.708383: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1553] Created device /device:GPU:0 with 9378 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:06:00.0, compute capability: 8.6

# %%
NUM_POINTS = pointCloudArray.shape[1]

def total_model_builder(hp):
    """
    感染リスク分布予測モデル

    順序不変性モデルに、メタデータ（空調条件）を合流させ、
    転置畳み込みで感染リスク分布を出力する。

    KerasTunerから呼び出され、ハイパーパラメータをチューニングする
    """
    input_pointCloud = keras.Input(shape=(NUM_POINTS, 3), name='pointCloud')
    input_meta = keras.Input(shape=(metaArray.shape[1], ), name='meta')

    features_pc = permutation_invariant_network_builder(hp, input_pointCloud)
    
    features = keras.layers.Concatenate()([features_pc, input_meta])

    x = features
    
    hp_dense_layers = hp.Int('dense_layers', min_value = 0, max_value = 4, step = 1)
    for i in range(hp_dense_layers):
        hp_units = hp.Int(f'units-{i}', min_value = 32, max_value = 512, step = 32)
        x = keras.layers.Dense(hp_units)(x)
        x = LeakyReLU()(x)
    
    outputs = keras.layers.Dense(1)(x)

    hp_learning_rate = hp.Choice('learning_rate', values = [1e-2, 1e-3, 1e-4]) 
    model = keras.Model(inputs=[input_pointCloud, input_meta], outputs=outputs, name="predictionnet")
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
        loss='mse',
        metrics=['mae']
        )

    return model

# %% [markdown]
# # チューニング

# %%
'''
特定のofficeだけ、テスト用にとっておく。
学習にも、チューニング中の検証にも使わない。
'''

office_for_test = 'office10'
fit_ID = []
test_ID = []

for (ID, case_index) in enumerate(case_index_augumented_list):
    if office_for_test + '_' not in case_index:
        fit_ID.append(ID)
    else:
        test_ID.append(ID)

print(case_index_array[test_ID])
        
case_index_fit = case_index_array[fit_ID]
X_pc_fit = pointCloudArray[fit_ID]
X_meta_fit = metaArray[fit_ID]
y_fit = RoIArray[fit_ID]

case_index_test = case_index_array[test_ID]
X_pc_test = pointCloudArray[test_ID]
X_meta_test = metaArray[test_ID]
y_test = RoIArray[test_ID]
# Out:
# ['office10_360_164_bout-0' 'office10_360_164_bout-1'
#  'office10_360_164_bout-2' 'office10_360_164_bout-3'
#  'office10_660_246_aout-0' 'office10_660_246_aout-1'
#  'office10_660_246_aout-2' 'office10_660_246_aout-3'
#  'office10_660_82_bout-0' 'office10_660_82_bout-1'
#  'office10_660_82_bout-2' 'office10_660_82_bout-3'
#  'office10_660_82_aout-0' 'office10_660_82_aout-1'
#  'office10_660_82_aout-2' 'office10_660_82_aout-3'
#  'office10_660_164_bout-0' 'office10_660_164_bout-1'
#  'office10_660_164_bout-2' 'office10_660_164_bout-3'
#  'office10_0_164_aout-0' 'office10_0_164_aout-1' 'office10_0_164_aout-2'
#  'office10_0_164_aout-3' 'office10_0_82_aout-0' 'office10_0_82_aout-1'
#  'office10_0_82_aout-2' 'office10_0_82_aout-3' 'office10_660_164_aout-0'
#  'office10_660_164_aout-1' 'office10_660_164_aout-2'
#  'office10_660_164_aout-3' 'office10_660_246_bout-0'
#  'office10_660_246_bout-1' 'office10_660_246_bout-2'
#  'office10_660_246_bout-3' 'office10_360_246_bout-0'
#  'office10_360_246_bout-1' 'office10_360_246_bout-2'
#  'office10_360_246_bout-3' 'office10_960_82_aout-0'
#  'office10_960_82_aout-1' 'office10_960_82_aout-2'
#  'office10_960_82_aout-3' 'office10_360_82_bout-0'
#  'office10_360_82_bout-1' 'office10_360_82_bout-2'
#  'office10_360_82_bout-3' 'office10_360_82_aout-0'
#  'office10_360_82_aout-1' 'office10_360_82_aout-2'
#  'office10_360_82_aout-3' 'office10_0_0-0' 'office10_0_0-1'
#  'office10_0_0-2' 'office10_0_0-3' 'office10_960_164_bout-0'
#  'office10_960_164_bout-1' 'office10_960_164_bout-2'
#  'office10_960_164_bout-3' 'office10_0_246_aout-0' 'office10_0_246_aout-1'
#  'office10_0_246_aout-2' 'office10_0_246_aout-3' 'office10_360_164_aout-0'
#  'office10_360_164_aout-1' 'office10_360_164_aout-2'
#  'office10_360_164_aout-3' 'office10_360_0-0' 'office10_360_0-1'
#  'office10_360_0-2' 'office10_360_0-3' 'office10_0_82_bout-0'
#  'office10_0_82_bout-1' 'office10_0_82_bout-2' 'office10_0_82_bout-3'
#  'office10_960_246_aout-0' 'office10_960_246_aout-1'
#  'office10_960_246_aout-2' 'office10_960_246_aout-3'
#  'office10_960_164_aout-0' 'office10_960_164_aout-1'
#  'office10_960_164_aout-2' 'office10_960_164_aout-3'
#  'office10_0_164_bout-0' 'office10_0_164_bout-1' 'office10_0_164_bout-2'
#  'office10_0_164_bout-3' 'office10_0_246_bout-0' 'office10_0_246_bout-1'
#  'office10_0_246_bout-2' 'office10_0_246_bout-3' 'office10_960_82_bout-0'
#  'office10_960_82_bout-1' 'office10_960_82_bout-2'
#  'office10_960_82_bout-3' 'office10_660_0-0' 'office10_660_0-1'
#  'office10_660_0-2' 'office10_660_0-3' 'office10_360_246_aout-0'
#  'office10_360_246_aout-1' 'office10_360_246_aout-2'
#  'office10_360_246_aout-3' 'office10_960_0-0' 'office10_960_0-1'
#  'office10_960_0-2' 'office10_960_0-3' 'office10_960_246_bout-0'
#  'office10_960_246_bout-1' 'office10_960_246_bout-2'
#  'office10_960_246_bout-3']

# %%
from k_cross_split import get_k_cross_ID_list

'''
チューニングに使うデータを，学習用と検証用に分ける
'''

data_size = len(X_pc_fit)
k = 4
print('data_size =', data_size)
print('k =', k)

#k分割交差検証用の関数だが、ここでは単に訓練データと検証データの分割目的で使う
k_cross_ID_list = get_k_cross_ID_list(data_size, k)

(train_ID, val_ID) = k_cross_ID_list[0]
print(train_ID)
print(val_ID)

X_pc_train = X_pc_fit[train_ID]
X_meta_train = X_meta_fit[train_ID]
y_train = y_fit[train_ID]

X_pc_val = X_pc_fit[val_ID]
X_meta_val = X_meta_fit[val_ID]
y_val = y_fit[val_ID]
# Out:
# data_size = 940
# k = 4
# [663, 878, 815, 639, 265, 211, 740, 269, 141, 361, 338, 592, 419, 256, 251, 712, 48, 242, 176, 56, 585, 222, 861, 603, 24, 612, 645, 634, 54, 2, 935, 903, 312, 300, 145, 766, 445, 172, 385, 326, 549, 98, 78, 770, 129, 204, 891, 736, 36, 232, 71, 551, 911, 909, 541, 283, 567, 152, 787, 565, 488, 610, 455, 865, 399, 426, 618, 266, 383, 582, 346, 714, 862, 826, 116, 561, 514, 150, 50, 473, 349, 882, 446, 726, 771, 627, 16, 711, 12, 606, 182, 96, 872, 613, 584, 294, 774, 371, 902, 365, 321, 619, 719, 69, 643, 418, 376, 10, 554, 325, 745, 661, 540, 708, 79, 574, 591, 47, 0, 478, 227, 682, 189, 500, 532, 577, 508, 32, 480, 547, 479, 786, 895, 925, 658, 747, 65, 798, 789, 494, 594, 568, 262, 268, 94, 772, 409, 415, 519, 397, 885, 650, 276, 185, 733, 680, 469, 470, 241, 576, 534, 3, 393, 342, 438, 506, 430, 153, 64, 120, 63, 7, 8, 706, 166, 485, 570, 235, 797, 390, 309, 836, 6, 332, 395, 151, 630, 575, 386, 277, 717, 5, 822, 907, 296, 775, 780, 810, 27, 449, 315, 493, 327, 648, 313, 379, 675, 316, 285, 38, 827, 29, 784, 837, 581, 727, 516, 490, 231, 883, 146, 573, 536, 347, 809, 272, 746, 253, 381, 664, 604, 440, 35, 817, 731, 512, 180, 58, 614, 308, 720, 492, 768, 475, 197, 693, 434, 81, 505, 513, 156, 274, 785, 854, 15, 134, 640, 394, 345, 743, 340, 259, 465, 938, 916, 881, 466, 657, 626, 428, 378, 184, 905, 869, 344, 496, 229, 588, 558, 240, 
243, 609, 287, 851, 691, 539, 579, 906, 683, 128, 763, 753, 200, 459, 922, 520, 244, 9, 762, 820, 181, 781, 37, 103, 702, 472, 824, 341, 839, 806, 631, 33, 910, 497, 173, 73, 647, 454, 800, 413, 692, 637, 749, 34, 611, 571, 246, 859, 518, 928, 377, 57, 517, 698, 605, 597, 323, 598, 828, 158, 144, 694, 792, 874, 728, 543, 114, 85, 175, 498, 424, 811, 192, 509, 697, 757, 234, 556, 99, 174, 267, 201, 199, 898, 464, 304, 289, 457, 263, 515, 450, 351, 66, 124, 148, 557, 921, 160, 17, 846, 742, 750, 913, 133, 590, 856, 689, 219, 49, 563, 667, 53, 915, 273, 696, 239, 404, 877, 813, 335, 358, 307, 223, 74, 662, 843, 138, 236, 867, 126, 417, 688, 636, 169, 369, 168, 87, 414, 380, 374, 68, 328, 758, 537, 476, 713, 535, 284, 100, 678, 804, 876, 82]

# %%
import shutil
import datetime

# if os.path.exists(output_dir):
#     shutil.rmtree(output_dir)

projectName = 'trial' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# projectName = "trial20221004-023343"
print("projectName : " + projectName)

output_dir = './KerasTuner_log'

# if os.path.exists(output_dir):
#     shutil.rmtree(output_dir)

tuner = kt.Hyperband(total_model_builder,
                     objective = 'val_loss', 
                     max_epochs = 1000,
                    #  factor = 3,
                     directory = output_dir,
                     project_name = projectName
                     )
# Out:
# projectName : trial20221010-015222

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping

# logdir = os.path.join("tblogs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
# tensorboard_cb = keras.callbacks.TensorBoard(log_dir=logdir, histogram_freq=1)

class ClearTrainingOutput(tf.keras.callbacks.Callback):
    def on_train_end(*args, **kwargs):
        IPython.display.clear_output(wait = True)

estop_tuning =  EarlyStopping(monitor='val_loss', min_delta=0.0, patience=100)

# %%
# case_index_train = case_index_array[train_ID]
# case_index_test = case_index_array[test_ID]

# %%
# tuner.search({'pointCloud':X_pc_train, 'meta':X_meta_train}, Y_train,
#              epochs = 40,
#              validation_data = ({'pointCloud':X_pc_test, 'meta':X_meta_test}, Y_test),
#              callbacks = [ClearTrainingOutput()])

# %%
tuner.search({'pointCloud':X_pc_train, 'meta':X_meta_train}, y_train,
             epochs = 1000,
             validation_data = ({'pointCloud':X_pc_val, 'meta':X_meta_val}, y_val),
             # callbacks = [tensorboard_cb, estop_tuning, ClearTrainingOutput()])
             callbacks = [estop_tuning, ClearTrainingOutput()])
# Out:
# Trial 2074 Complete [00h 01m 04s]
# val_loss: 0.21982450783252716
#
# Best val_loss So Far: 0.037046879529953
# Total elapsed time: 05h 32m 53s
# INFO:tensorflow:Oracle triggered exit

# %% [markdown]
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0385s vs `on_train_batch_end` time: 0.0630s). Check your callbacks.

# %%
# function ClickConnect(){
#   console.log("60sごとに再接続");
#   document.querySelector("colab-connect-button").click()
# }
# setInterval(ClickConnect,1000*60);

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in ./KerasTuner_log/trial20221010-015222
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x7f0864462250>
# Trial summary
# Hyperparameters:
# conv_bn_layers: 2
# filters_bn-0: 96
# dense_bn_layers: 1
# features: 16
# dense_layers: 3
# learning_rate: 0.001
# filters_bn-1: 288
# units_bn_0: 128
# units_bn_1: 352
# units_bn_2: 224
# units-0: 96
# units-1: 224
# units_bn_3: 416
# filters_bn-2: 192
# units-2: 416
# units-3: 192
# filters_bn-3: 320
# tuner/epochs: 1000
# tuner/initial_epoch: 334
# tuner/bracket: 5
# tuner/round: 5
# tuner/trial_id: 1734
# Score: 0.037046879529953
# Trial summary
# Hyperparameters:
# conv_bn_layers: 2
# filters_bn-0: 256
# dense_bn_layers: 1
# features: 20
# dense_layers: 2
# learning_rate: 0.001
# filters_bn-1: 128
# units_bn_0: 288
# units_bn_1: 128
# units_bn_2: 416
# units-0: 224
# units-1: 64
# units_bn_3: 160
# filters_bn-2: 96
# units-2: 96
# units-3: 480
# filters_bn-3: 352
# tuner/epochs: 1000
# tuner/initial_epoch: 334
# tuner/bracket: 6
# tuner/round: 6
# tuner/trial_id: 1247
# Score: 0.043392714112997055
# Trial summary
# Hyperparameters:
# conv_bn_layers: 4
# filters_bn-0: 448
# dense_bn_layers: 1
# features: 12
# dense_layers: 2
# learning_rate: 0.001
# filters_bn-1: 224
# units_bn_0: 192
# units_bn_1: 64
# units_bn_2: 288
# units-0: 64
# units-1: 192
# units_bn_3: 448
# filters_bn-2: 64
# units-2: 352
# units-3: 416
# filters_bn-3: 448
# tuner/epochs: 334
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.05774861201643944
# Trial summary
# Hyperparameters:
# conv_bn_layers: 2
# filters_bn-0: 384
# dense_bn_layers: 1
# features: 40
# dense_layers: 3
# learning_rate: 0.001
# filters_bn-1: 352
# units_bn_0: 480
# units_bn_1: 288
# units_bn_2: 128
# units-0: 416
# units-1: 224
# units_bn_3: 480
# filters_bn-2: 224
# units-2: 64
# units-3: 352
# filters_bn-3: 320
# tuner/epochs: 1000
# tuner/initial_epoch: 334
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 2039
# Score: 0.05817531794309616
# Trial summary
# Hyperparameters:
# conv_bn_layers: 2
# filters_bn-0: 352
# dense_bn_layers: 1
# features: 48
# dense_layers: 3
# learning_rate: 0.001
# filters_bn-1: 512
# units_bn_0: 480
# units_bn_1: 448
# units_bn_2: 320
# units-0: 320
# units-1: 288
# units_bn_3: 224
# filters_bn-2: 512
# units-2: 64
# units-3: 128
# filters_bn-3: 448
# tuner/epochs: 334
# tuner/initial_epoch: 112
# tuner/bracket: 3
# tuner/round: 2
# tuner/trial_id: 1995
# Score: 0.05913619324564934
# Trial summary
# Hyperparameters:
# conv_bn_layers: 3
# filters_bn-0: 384
# dense_bn_layers: 1
# features: 12
# dense_layers: 3
# learning_rate: 0.001
# filters_bn-1: 480
# units_bn_0: 448
# units_bn_1: 480
# units_bn_2: 384
# units-0: 320
# units-1: 160
# units_bn_3: 224
# filters_bn-2: 224
# units-2: 352
# units-3: 256
# filters_bn-3: 320
# tuner/epochs: 1000
# tuner/initial_epoch: 334
# tuner/bracket: 6
# tuner/round: 6
# tuner/trial_id: 1248
# Score: 0.06268539279699326
# Trial summary
# Hyperparameters:
# conv_bn_layers: 2
# filters_bn-0: 192
# dense_bn_layers: 1
# features: 40
# dense_layers: 3
# learning_rate: 0.001
# filters_bn-1: 64
# units_bn_0: 192
# units_bn_1: 384
# units_bn_2: 512
# units-0: 384
# units-1: 512
# units_bn_3: 256
# filters_bn-2: 128
# units-2: 64
# units-3: 224
# filters_bn-3: 480
# tuner/epochs: 1000
# tuner/initial_epoch: 334
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 2008
# Score: 0.06525121629238129
# Trial summary
# Hyperparameters:
# conv_bn_layers: 4
# filters_bn-0: 448
# dense_bn_layers: 1
# features: 12
# dense_layers: 2
# learning_rate: 0.001
# filters_bn-1: 224
# units_bn_0: 192
# units_bn_1: 64
# units_bn_2: 288
# units-0: 64
# units-1: 192
# units_bn_3: 448
# filters_bn-2: 64
# units-2: 352
# units-3: 416
# filters_bn-3: 448
# tuner/epochs: 1000
# tuner/initial_epoch: 334
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 2057
# Score: 0.06565888226032257
# Trial summary
# Hyperparameters:
# conv_bn_layers: 3
# filters_bn-0: 448
# dense_bn_layers: 1
# features: 20
# dense_layers: 3
# learning_rate: 0.001
# filters_bn-1: 96
# units_bn_0: 320
# units_bn_1: 128
# units_bn_2: 224
# units-0: 160
# units-1: 64
# units_bn_3: 288
# filters_bn-2: 192
# units-2: 64
# units-3: 480
# filters_bn-3: 192
# tuner/epochs: 334
# tuner/initial_epoch: 112
# tuner/bracket: 5
# tuner/round: 4
# tuner/trial_id: 1724
# Score: 0.06635460257530212
# Trial summary
# Hyperparameters:
# conv_bn_layers: 2
# filters_bn-0: 96
# dense_bn_layers: 1
# features: 16
# dense_layers: 3
# learning_rate: 0.001
# filters_bn-1: 288
# units_bn_0: 128
# units_bn_1: 352
# units_bn_2: 224
# units-0: 96
# units-1: 224
# units_bn_3: 416
# filters_bn-2: 192
# units-2: 416
# units-3: 192
# filters_bn-3: 320
# tuner/epochs: 334
# tuner/initial_epoch: 112
# tuner/bracket: 5
# tuner/round: 4
# tuner/trial_id: 1725
# Score: 0.0669395700097084

# %%
# Get the optimal hyperparameters
# best_hps = tuner.get_best_hyperparameters(num_trials = 1)[0]
best_hps = tuner.get_best_hyperparameters()[0]

# best_conv_layers =best_hps.get('conv_bn_layers')
# print('best_conv_bn_layers = ', best_conv_layers)
# for i in range(best_conv_layers):
#     print(best_hps.get(f'filters_bn-{i}'))
    
# best_dense_layers =best_hps.get('dense_bn_layers')
# print('best_dense_layers = ', best_dense_layers)
# for i in range(best_dense_layers):
#     print(best_hps.get(f'units_bn_{i}'))

# print('best_features = ', best_hps.get('features'))
    
# print('best_learning_rate = ', best_hps.get('learning_rate'))

# %%
# Build the model with the optimal hyperparameters
model = tuner.hypermodel.build(best_hps)

keras.utils.plot_model(model, show_shapes=True)

# %%
from tensorflow.keras.callbacks import EarlyStopping

estop =  EarlyStopping(monitor='val_loss', min_delta=0.0, patience=100)

best_history = model.fit(
    {'pointCloud':X_pc_train, 'meta':X_meta_train}, y_train,
    epochs = 1000,
    validation_data = ({'pointCloud':X_pc_val, 'meta':X_meta_val}, y_val),
    callbacks=[estop]
)
# Out:
# Epoch 1/1000
# 23/23 [==============================] - 2s 23ms/step - loss: 0.6309 - mae: 0.6210 - val_loss: 2.2285 - val_mae: 1.2210
# Epoch 2/1000
# 23/23 [==============================] - 0s 15ms/step - loss: 0.
1000
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0270 - mae: 0.1167 - val_loss: 0.3859 - val_mae: 0.3753
# Epoch 521/1000
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0318 - mae: 0.1327 - val_loss: 0.3929 - val_mae: 0.3225
# Epoch 522/1000
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0203 - mae: 0.1001 - val_loss: 2.4171 - val_mae: 1.1087
# Epoch 523/1000
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0388 - mae: 0.1428 - val_loss: 0.3765 - val_mae: 0.3757
# Epoch 524/1000
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0359 - mae: 0.1430 - val_loss: 0.2636 - val_mae: 0.3185
# Epoch 525/1000
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0270 - mae: 0.1153 - val_loss: 0.1877 - val_mae: 0.2264
# Epoch 526/1000
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0423 - mae: 0.1545 - val_loss: 2.3306 - val_mae: 1.0892
# Epoch 527/1000
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0339 - mae: 0.1388 - val_loss: 0.1441 - val_mae: 0.2068
# Epoch 528/1000
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0211 - mae: 0.1061 - val_loss: 0.1335 - val_mae: 0.1962
# Epoch 529/1000
# 23/23 [==============================] - 0s 15ms/step - loss: 0.0224 - mae: 0.1110 - val_loss: 0.2295 - val_mae: 0.2966
# Epoch 530/1000
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0163 - mae: 0.0924 - val_loss: 0.1151 - val_mae: 0.1791
# Epoch 531/1000
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0178 - mae: 0.0941 - val_loss: 0.1300 - val_mae: 0.2031
# Epoch 532/1000
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0251 - mae: 0.1217 - val_loss: 0.2145 - val_mae: 0.2798
# Epoch 533/1000
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0150 - mae: 0.0908 - val_loss: 0.0657 - val_mae: 0.1526
# Epoch 534/1000
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0132 - mae: 0.0810 - val_loss: 0.1407 - val_mae: 0.1954

# %% [markdown]
# # チューニング結果確認

# %%
import pandas as pd

def plot_history(history:dict):
    history_df = pd.DataFrame(history)
    
    loss_df = history_df[["loss", "val_loss"]]
    loss_df.plot()
    plt.xlabel("epochs")
    plt.ylabel("Loss")
    # plt.ylim(0., 5.)
    plt.show()

    acc_df = history_df[["mae", "val_mae"]]
    acc_df.plot()
    plt.xlabel("epochs")
    plt.ylabel("MeanAbsoluteError")
    plt.show()

# %%
plot_history(best_history.history)

# %%
Y_train_pred = model.predict({'pointCloud':X_pc_train, 'meta':X_meta_train})
Y_test_pred = model.predict({'pointCloud':X_pc_test, 'meta':X_meta_test})
# Out:
# 23/23 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step

# %%
np.var(y_test)
# Out:
# 0.588685784208906

# %%
test_mse, test_mae = model.evaluate({'pointCloud':X_pc_test, 'meta':X_meta_test}, y_test, verbose=0)

print(test_mse)

print(test_mae)
# Out:
# 1.2118510007858276
# 0.8961325883865356

# %% [markdown]
# # いよいよ手詰まり状態
#
# **残された手段**
#
# *   点群データを調節
#  *   現在、1点群あたりの点の数は2048個に統一
#  *   点群データの作り方もいろいろある
#  *   モデルから人体モデルだけ取り除く（現状、全点群のうち人体表面の頂点が多くを占める）
#  *   エアコン・換気口を構成する頂点は必ずサンプリング
# *   点群を諦め、部屋のサイズを説明変数（入力）に加える
#  *   ニューラルネットワークすらも諦め、重回帰へ（線形・非線形）
# *   座っている位置と立っている位置とで観測飛沫数データを足し算した場合に分散は大きくなるだろうか（要確認）
# * RNN
# * 微分方程式を機械学習で解く
# * 感染リスク定義見直し
# * 分類問題へ
# *
#
# いずれも大きな効果はあまり期待できそうにない・・・
