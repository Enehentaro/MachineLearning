# %% [markdown]
# # 環境構築
#
#
#
# *   Pythonモジュールへのパス追加

# %%
# !pwd
# Out:
# /mnt/MachineLearning

# %%
import sys
sys.path.append('/mnt/MachineLearning/modules')

# %%
# %matplotlib inline
import os
import glob
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy import interpolate
import show_mod

# %% [markdown]
# # 前処理

# %%
#読み込むデータのパスの設定

data_path = './data'
input_list = glob.glob(data_path+"/*"+"/inputdata.csv")

input_list
# Out:
# ['./data/office1/inputdata.csv',
#  './data/office10/inputdata.csv',
#  './data/office15/inputdata.csv',
#  './data/office16/inputdata.csv',
#  './data/office2/inputdata.csv',
#  './data/office22/inputdata.csv',
#  './data/office28/inputdata.csv',
#  './data/office3/inputdata.csv',
#  './data/office7/inputdata.csv']

# %%
#input(空調条件等)の読み込み
df_input = None

for input_fname in input_list:
    df_read = pd.read_csv(input_fname, index_col="case_name")
    if df_input is None:
        df_input = df_read
    else:
        df_input = pd.concat([df_input, df_read])

df_input
# Out:
#                       aircon  ventilation exhaust    1_x   1_y    1_z  \
# case_name
# office1_960_164_aout     960          164       a  4.760  2.18  1.255
# office1_0_205_aout         0          205       a  4.760  2.18  1.255
# office1_660_41_bout      660           41       b  4.760  2.18  1.255
# office1_960_82_bout      960           82       b  4.760  2.18  1.255
# office1_960_205_bout     960          205       b  4.760  2.18  1.255
# ...                      ...          ...     ...    ...   ...    ...
# office7_960_82_bout      960           82       b  1.266  2.29  1.255
# office7_660_0            660            0     off  1.266  2.29  1.255
# office7_360_246_aout     360          246       a  1.266  2.29  1.255
# office7_960_0            960            0     off  1.266  2.29  1.255
# office7_960_246_bout     960          246       b  1.266  2.29  1.255
#
#                       1_angle    2_x    2_y    2_z  ...    4_z  4_angle  \
# case_name                                           ...
# office1_960_164_aout    180.0  3.285  3.160  1.255  ...  1.255     90.0
# office1_0_205_aout      180.0  3.285  3.160  1.255  ...  1.255     90.0
# office1_660_41_bout     180.0  3.285  3.160  1.255  ...  1.255     90.0
# office1_960_82_bout     180.0  3.285  3.160  1.255  ...  1.255     90.0
# office1_960_205_bout    180.0  3.285  3.160  1.255  ...  1.255     90.0
# ...                       ...    ...    ...    ...  ...    ...      ...
# office7_960_82_bout       0.0  3.140  3.059  1.255  ...  1.255     90.0
# office7_660_0             0.0  3.140  3.059  1.255  ...  1.255     90.0
# office7_360_246_aout      0.0  3.140  3.059  1.255  ...  1.255     90.0
# office7_960_0             0.0  3.140  3.059  1.255  ...  1.255     90.0
# office7_960_246_bout      0.0  3.140  3.059  1.255  ...  1.255     90.0
#
#                         5_x    5_y    5_z  5_angle  office_size_x  \
# case_name
# office1_960_164_aout  2.885  1.241  1.255     90.0            6.0
# office1_0_205_aout    2.885  1.241  1.255     90.0            6.0
# office1_660_41_bout   2.885  1.241  1.255     90.0            6.0
# office1_960_82_bout   2.885  1.241  1.255     90.0            6.0
# office1_960_205_bout  2.885  1.241  1.255     90.0            6.0
# ...                     ...    ...    ...      ...            ...
# office7_960_82_bout   2.760  1.141  1.255     90.0            9.0
# office7_660_0         2.760  1.141  1.255     90.0            9.0
# office7_360_246_aout  2.760  1.141  1.255     90.0            9.0
# office7_960_0         2.760  1.141  1.255     90.0            9.0
# office7_960_246_bout  2.760  1.141  1.255     90.0            9.0
#
#                       office_size_y  aircon_position_x  aircon_position_y
# case_name
# office1_960_164_aout            5.5                3.0               2.75
# office1_0_205_aout              5.5                3.0               2.75
# office1_660_41_bout             5.5                3.0               2.75
# office1_960_82_bout             5.5                3.0               2.75
# office1_960_205_bout            5.5                3.0               2.75
# ...                             ...                ...                ...
# office7_960_82_bout             4.0                4.5               2.00
# office7_660_0                   4.0                4.5               2.00
# office7_360_246_aout            4.0                4.5               2.00
# office7_960_0                   4.0                4.5               2.00
# office7_960_246_bout            4.0                4.5               2.00
#
# [263 rows x 27 columns]

# %%
#空調条件のみ抽出
df_meta = df_input.loc[:, ['aircon', 'ventilation', 'exhaust']]

df_meta
# Out:
#                       aircon  ventilation exhaust
# case_name
# office1_960_164_aout     960          164       a
# office1_0_205_aout         0          205       a
# office1_660_41_bout      660           41       b
# office1_960_82_bout      960           82       b
# office1_960_205_bout     960          205       b
# ...                      ...          ...     ...
# office7_960_82_bout      960           82       b
# office7_660_0            660            0     off
# office7_360_246_aout     360          246       a
# office7_960_0            960            0     off
# office7_960_246_bout     960          246       b
#
# [263 rows x 3 columns]

# %%
#排気口位置a,b,offをダミー変数化

df_meta = pd.get_dummies(df_meta, columns=['exhaust'])
# dummies = pd.get_dummies(df_input['exhaust'])
# df_input.drop("exhaust", axis=1, inplace=True)
# df_input = pd.concat([df_input, dummies], axis=1)
# df_input = df_input.reindex(columns=['aircon','ventilation','exhaust_a','b','off'
#           ,'1_x','1_y','1_z','1_angle','2_x','2_y','2_z','2_angle','3_x','3_y','3_z','3_angle'
#           ,'4_x','4_y','4_z','4_angle','5_x','5_y','5_z','5_angle',"office_size_x","office_size_y"
#           ,"aircon_position_x","aircon_position_y"])

df_meta
# Out:
#                       aircon  ventilation  exhaust_a  exhaust_b  exhaust_off
# case_name
# office1_960_164_aout     960          164          1          0            0
# office1_0_205_aout         0          205          1          0            0
# office1_660_41_bout      660           41          0          1            0
# office1_960_82_bout      960           82          0          1            0
# office1_960_205_bout     960          205          0          1            0
# ...                      ...          ...        ...        ...          ...
# office7_960_82_bout      960           82          0          1            0
# office7_660_0            660            0          0          0            1
# office7_360_246_aout     360          246          1          0            0
# office7_960_0            960            0          0          0            1
# office7_960_246_bout     960          246          0          1            0
#
# [263 rows x 5 columns]

# %%
df_count = pd.read_csv("./CountResults/sitting/count_from2sec_patientAverage.csv", index_col="casename")

df_count
# Out:
#                       num_drop  volume[ml]         RoI
# casename
# office2_0_0             6739.4    0.000067  204.224242
# office2_0_164_aout      7865.4    0.000063  238.345455
# office2_0_164_bout      6049.8    0.000062  183.327273
# office2_0_246_aout      7934.4    0.000050  240.436364
# office2_0_246_bout      7662.0    0.000082  232.181818
# ...                        ...         ...         ...
# office3_960_164_bout    5117.4    0.000075  155.072727
# office3_960_246_aout    4428.0    0.000073  134.181818
# office3_960_246_bout    3890.0    0.000066  117.878788
# office3_960_82_aout     5221.2    0.000072  158.218182
# office3_960_82_bout     5280.8    0.000053  160.024242
#
# [263 rows x 3 columns]

# %%
# df_meta.join(df_count)
df_total = pd.merge(df_meta, df_count, left_index=True, right_index=True)

df_total
# Out:
#                       aircon  ventilation  exhaust_a  exhaust_b  exhaust_off  \
# office1_960_164_aout     960          164          1          0            0
# office1_0_205_aout         0          205          1          0            0
# office1_660_41_bout      660           41          0          1            0
# office1_960_82_bout      960           82          0          1            0
# office1_960_205_bout     960          205          0          1            0
# ...                      ...          ...        ...        ...          ...
# office7_960_82_bout      960           82          0          1            0
# office7_660_0            660            0          0          0            1
# office7_360_246_aout     360          246          1          0            0
# office7_960_0            960            0          0          0            1
# office7_960_246_bout     960          246          0          1            0
#
#                       num_drop  volume[ml]         RoI
# office1_960_164_aout    5203.0    0.000049  157.666667
# office1_0_205_aout      7809.8    0.000076  236.660606
# office1_660_41_bout     5928.6    0.000046  179.654545
# office1_960_82_bout     6454.6    0.000083  195.593939
# office1_960_205_bout    5522.4    0.000056  167.345455
# ...                        ...         ...         ...
# office7_960_82_bout     7550.2    0.000107  209.727778
# office7_660_0           6621.8    0.000080  183.938889
# office7_360_246_aout    6474.2    0.000081  179.838889
# office7_960_0           7348.4    0.000095  204.122222
# office7_960_246_bout    7408.4    0.000102  205.788889
#
# [263 rows x 8 columns]

# %%
import seaborn as sns

sns.pairplot(df_total)

# %%
from sklearn import preprocessing

#入力データの標準化
stdscaler = preprocessing.StandardScaler()
stdscaler.fit(df_total)
df_total_tf = stdscaler.transform(df_total)

df_total_standardized = pd.DataFrame(df_total_tf, index=df_total.index, columns=df_total.columns)
df_total_standardized

# df_input_std = df_input.copy()
# for i in range(int(input_std.shape[1])):
#     df_input_std.iloc[:, i] = input_std[:, i]
# Out:
#                         aircon  ventilation  exhaust_a  exhaust_b  \
# office1_960_164_aout  1.261546     0.294952   1.143249  -0.874700
# office1_0_205_aout   -1.380856     0.785916   1.143249  -0.874700
# office1_660_41_bout   0.435795    -1.177940  -0.874700   1.143249
# office1_960_82_bout   1.261546    -0.686976  -0.874700   1.143249
# office1_960_205_bout  1.261546     0.785916  -0.874700   1.143249
# ...                        ...          ...        ...        ...
# office7_960_82_bout   1.261546    -0.686976  -0.874700   1.143249
# office7_660_0         0.435795    -1.668904  -0.874700  -0.874700
# office7_360_246_aout -0.389955     1.276880   1.143249  -0.874700
# office7_960_0         1.261546    -1.668904  -0.874700  -0.874700
# office7_960_246_bout  1.261546     1.276880  -0.874700   1.143249
#
#                       exhaust_off  num_drop  volume[ml]       RoI
# office1_960_164_aout    -0.391802 -0.950160   -1.018438  0.057732
# office1_0_205_aout      -0.391802  1.621106    0.595029  1.999648
# office1_660_41_bout     -0.391802 -0.234450   -1.226587  0.598262
# office1_960_82_bout     -0.391802  0.284379    0.977896  0.990102
# office1_960_205_bout    -0.391802 -0.635113   -0.585326  0.295666
# ...                           ...       ...         ...       ...
# office7_960_82_bout     -0.391802  1.365045    2.398745  1.337555
# office7_660_0            2.552310  0.449300    0.818117  0.703584
# office7_360_246_aout    -0.391802  0.303712    0.859225  0.602794
# office7_960_0            2.552310  1.165996    1.690738  1.199753
# office7_960_246_bout    -0.391802  1.225178    2.115534  1.240725
#
# [263 rows x 8 columns]

# %%
df_meta_standardized = df_total_standardized[["aircon", "ventilation", "exhaust_a", "exhaust_b", "exhaust_off"]]

df_RoI_standardized = df_total_standardized["RoI"]

# %%
# import numpy as np
# import pointCloud_sampling as pcs

# # rng = np.random.default_rng()

# #予め点群をサンプリングしておいたものを取得
# sampledPointCloud_dict = pcs.read_sampledPointCloud('/content/drive/MyDrive/ML/PointNetTrial/data/pointCloud_sampled')

# sampledPointCloud_dict
# Out:
# {'office2': array([[2.832 , 4.588 , 1.263 ],
#         [3.1   , 1.55  , 0.4833],
#         [2.709 , 3.093 , 1.244 ],
#         ...,
#         [2.759 , 3.36  , 0.48  ],
#         [4.88  , 2.81  , 1.264 ],
#         [4.204 , 1.661 , 0.75  ]], dtype=float32),
#  'office1': array([[1.107 , 2.073 , 0.7   ],
#         [3.351 , 3.223 , 1.347 ],
#         [3.775 , 2.427 , 0.5866],
#         ...,
#         [3.429 , 2.181 , 0.    ],
#         [2.571 , 2.373 , 0.05  ],
#         [3.251 , 3.485 , 0.8337]], dtype=float32),
#  'office16': array([[6.079 , 3.707 , 1.014 ],
#         [2.294 , 5.    , 2.212 ],
#         [5.793 , 1.455 , 1.233 ],
#         ...,
#         [3.407 , 0.6372, 0.    ],
#         [4.553 , 1.361 , 1.168 ],
#         [6.197 , 3.81  , 0.5341]], dtype=float32),
#  'office22': array([[3.693 , 3.918 , 0.1951],
#         [5.5   , 2.623 , 0.3624],
#         [5.201 , 4.189 , 0.8347],
#         ...,
#         [5.507 , 2.542 , 0.4169],
#         [4.744 , 2.955 , 0.7   ],
#         [2.534 , 3.035 , 0.    ]], dtype=float32),
#  'office7': array([[4.668 , 3.155 , 1.266 ],
#         [3.197 , 3.118 , 1.239 ],
#         [2.2   , 2.722 , 0.75  ],
#         ...,
#         [4.257 , 2.125 , 0.7   ],
#         [0.    , 1.027 , 0.9922],
#         [3.213 , 3.2   , 1.445 ]], dtype=float32),
#  'office10': array([[3.094 , 4.017 , 1.224 ],
#         [4.556 , 3.989 , 1.243 ],
#         [2.588 , 2.189 , 0.48  ],
#         ...,
#         [2.567 , 2.027 , 0.8228],
#         [1.115 , 3.099 , 1.29  ],
#         [1.941 , 3.65  , 0.05  ]], dtype=float32),
#  'office28': array([[2.809 , 5.035 , 0.8685],
#         [4.488 , 4.825 , 1.253 ],
#         [1.542 , 3.927 , 0.3949],
#         ...,
#         [5.05  , 4.299 , 0.2216],
#         [7.323 , 2.361 , 0.    ],
#         [4.55  , 2.751 , 0.9646]], dtype=float32),
#  'office15': array([[2.002 , 4.404 , 0.7   ],
#         [1.947 , 2.25  , 0.3741],
#         [1.093 , 4.655 , 1.289 ],
#         ...,
#         [1.529 , 3.435 , 0.4161],
#         [3.064 , 2.508 , 1.218 ],
#         [1.57  , 3.878 , 0.75  ]], dtype=float32),
#  'office3': array([[0.2163, 3.612 , 0.    ],
#         [4.915 , 3.894 , 1.452 ],
#         [5.3   , 0.45  , 0.169 ],
#         ...,
#         [5.47  , 0.7804, 0.1317],
#         [5.157 , 2.651 , 0.    ],
#         [4.937 , 3.604 , 0.9034]], dtype=float32)}

# %%
import os
import random
import numpy as np
import json
import glob
from stl import mesh
from enum import Enum, auto

# 列挙型の定義
class OfficePart(Enum):
    aircon = auto()
    airvent = auto()
    body = auto()
    room = auto()
    desks = auto()


"""
データの前処理

オフィスモデル（STLファイル）を読み込み、点群情報のみ取り出し、
ランダムサンプリングで指定個の点群(ndarray)にする。
"""
officemodel_path = 'OfficeModel/model_origin'
# office_list = os.listdir(officemodel_path)
case_list = [s.replace('office', 'case') for s in os.listdir(data_path)]
# office_list = ['office1', 'office2', 'office3', 'office7', 'office10', 'office15', 'office16', 'office22', 'office28']
# print(office_list)

# 列挙型のメンバーの列挙
for part in OfficePart:
    print(part)
    
NUM_POINTS = 2048

sampledPointCloud_dict = {}
for casename in case_list:
    officename = casename.replace('case', 'office') 
    pc_dict = {}
    for part in OfficePart:
        path = officemodel_path + '/' + casename + '/' + part.name
        # print(path)
        stl_list = glob.glob(path + "/*.stl")
        print(stl_list)
        pc_list = []
        for stlfname in stl_list:
            for mesh_read in mesh.Mesh.from_multi_file(stlfname):
                points = mesh_read.points.reshape([-1, 3])
                pc_list.append(points)

        points_concat = np.concatenate(pc_list)
        points_concat = np.unique(points_concat, axis=0)
        pc_dict[part] = points_concat.copy()
                        

    pc_aircon = pc_dict[OfficePart.aircon]
    pc_airvent = pc_dict[OfficePart.airvent]
    pc_room = pc_dict[OfficePart.room]
    pc_base = np.concatenate([pc_aircon, pc_airvent, pc_room])
    num_sampling = NUM_POINTS - len(pc_base)

#     pc_forSampling = np.concatenate([pc_dict[OfficePart.body], pc_dict[OfficePart.desks]])
# #     pc_forSampling = pc_dict[OfficePart.desks]
#     print(f'#sampling {num_sampling} from {len(pc_forSampling)}', )
#     rand_list = random.sample(range(len(pc_forSampling)), k=num_sampling)
#     pc_sampled = pc_forSampling[rand_list, :]
    
    num_sampling_body = num_sampling // 2
    num_sampling_desks = num_sampling - num_sampling_body
    
    print("num_sampling_body = ", num_sampling_body)
    pc_body = pc_dict[OfficePart.body]
    rand_list = random.sample(range(len(pc_body)), k=num_sampling_body)
    pc_sampled_body = pc_body[rand_list, :]
    
    print("num_sampling_desks = ", num_sampling_desks)
    pc_desks = pc_dict[OfficePart.desks]
    rand_list = random.sample(range(len(pc_desks)), k=num_sampling_desks)
    pc_sampled_desks = pc_desks[rand_list, :]
    
    
#     pointCloud = np.concatenate([pc_base, pc_sampled])
    pointCloud = np.concatenate([pc_base, pc_sampled_body, pc_sampled_desks])
    print(pointCloud.shape)
    sampledPointCloud_dict[officename] = pointCloud
# Out:
# OfficePart.aircon
# OfficePart.airvent
# OfficePart.body
# OfficePart.room
# OfficePart.desks
# ['OfficeModel/model_origin/case1/aircon/aircon_body.stl', 'OfficeModel/model_origin/case1/aircon/aircon_inlets.stl', 'OfficeModel/model_origin/case1/aircon/aircon_outlet.stl']
# ['OfficeModel/model_origin/case1/airvent/20210812_airvent_a.stl', 'OfficeModel/model_origin/case1/airvent/airvent_b.stl']
# ['OfficeModel/model_origin/case1/body/20210810_bodies.stl']
# ['OfficeModel/model_origin/case1/room/20210810_office_bottom.stl', 'OfficeModel/model_origin/case1/room/20210810_office_side1.stl', 'OfficeModel/model_origin/case1/room/20210810_office_side2.stl', 'OfficeModel/model_origin/case1/room/20210810_office_side3.stl', 'OfficeModel/model_origin/case1/room/20210810_office_top.stl', 'OfficeModel/model_origin/case1/room/20210812_office_side4.stl']
# ['OfficeModel/model_origin/case1/desks/20210810_desks.stl']
# num_sampling_body =  720
# num_sampling_desks =  720
# (2048, 3)
# ['OfficeModel/model_origin/case10/aircon/20210812_aircon_inlets_model3.stl', 'OfficeModel/model_origin/case10/aircon/aircon_body_model3.stl', 'OfficeModel/model_origin/case10/aircon/aircon_outlet_model3.stl']
# ['OfficeModel/model_origin/case10/airvent/20210812_airvent_a_model3.stl', 'OfficeModel/model_origin/case10/airvent/20210812_airvent_b_model3.stl']
# ['OfficeModel/model_origin/case10/body/20210812_bodies_case10.stl']
# ['OfficeModel/model_origin/case10/room/20210812_office_bottom_model3.stl', 'OfficeModel/model_origin/case10/room/20210812_office_side1_model3.stl', 'OfficeModel/model_origin/case10/room/20210812_office_side2_model3.stl', 'OfficeModel/model_origin/case10/room/20210812_office_side3_model3.stl', 'OfficeModel/model_origin/case10/room/20210812_office_side4_model3.stl', 'OfficeModel/model_origin/case10/room/20210812_office_top_model3.stl']
# ['OfficeModel/model_origin/case10/desks/20210812_desks_case10.stl']
# num_sampling_body =  720
# num_sampling_desks =  720
# (2048, 3)
# ['OfficeModel/model_origin/case15/aircon/20210812_aircon_inlets_model3.stl', 'OfficeModel/model_origin/case15/aircon/aircon_body_model3.stl', 'OfficeModel/model_origin/case15/aircon/aircon_outlet_model3.stl']
# ['OfficeModel/model_origin/case15/airvent/20210812_airvent_a_model3.stl', 'OfficeModel/model_origin/case15/airvent/20210812_airvent_b_model3.stl']
# ['OfficeModel/model_origin/case15/body/20210812_bodies_case15.stl']
# ['OfficeModel/model_origin/case15/room/20210812_office_bottom_model3.stl', 'OfficeModel/model_origin/case15/room/20210812_office_side1_model3.stl', 'OfficeModel/model_origin/case15/room/20210812_office_side2_model3.stl', 'OfficeModel/model_origin/case15/room/20210812_office_side3_model3.stl', 'OfficeModel/model_origin/case15/room/20210812_office_side4_model3.stl', 'OfficeModel/model_origin/case15/room/20210812_office_top_model3.stl']
# ['OfficeModel/model_origin/case15/desks/20210812_desks_case15.stl']
# num_sampling_body =  720
# num_sampling_desks =  720
# (2048, 3)
# ['OfficeModel/model_origin/case16/aircon/20210812_aircon_inlets_model4.stl', 'OfficeModel/model_origin/case16/aircon/aircon_body_model4.stl', 'OfficeModel/model_origin/case16/aircon/aircon_outlet_model4.stl']
# ['OfficeModel/model_origin/case16/airvent/20210812_airvent_a_model4.stl', 'OfficeModel/model_origin/case16/airvent/20210812_airvent_b_model4.stl']
# ['OfficeModel/model_origin/case16/body/20210812_bodies_case16.stl']
# ['OfficeModel/model_origin/case16/room/20210812_office_bottom_model4.stl', 'OfficeModel/model_origin/case16/room/20210812_office_side1_model4.stl', 'OfficeModel/model_origin/case16/room/20210812_office_side2_model4.stl', 'OfficeModel/model_origin/case16/room/20210812_office_side3_model4.stl', 'OfficeModel/model_origin/case16/room/20210812_office_side4_model4.stl', 'OfficeModel/model_origin/case16/room/20210812_office_top_model4.stl']
# ['OfficeModel/model_origin/case16/desks/20210812_desks_case16.stl']
# num_sampling_body =  720
# num_sampling_desks =  720
# (2048, 3)
# ['OfficeModel/model_origin/case2/aircon/aircon_body.stl', 'OfficeModel/model_origin/case2/aircon/aircon_inlets.stl', 'OfficeModel/model_origin/case2/aircon/aircon_outlet.stl']
# ['OfficeModel/model_origin/case2/airvent/20210812_airvent_a.stl', 'OfficeModel/model_origin/case2/airvent/airvent_b.stl']
# ['OfficeModel/model_origin/case2/body/20210812_bodies_case2.stl']
# ['OfficeModel/model_origin/case2/room/20210810_office_bottom.stl', 'OfficeModel/model_origin/case2/room/20210810_office_side1.stl', 'OfficeModel/model_origin/case2/room/20210810_office_side2.stl', 'OfficeModel/model_origin/case2/room/20210810_office_side3.stl', 'OfficeModel/model_origin/case2/room/20210810_office_top.stl', 'OfficeModel/model_origin/case2/room/20210812_office_side4.stl']
# ['OfficeModel/model_origin/case2/desks/20210812_desks_case2.stl']
# num_sampling_body =  720
# num_sampling_desks =  720
# (2048, 3)
# ['OfficeModel/model_origin/case22/aircon/20210812_aircon_inlets_model5.stl', 'OfficeModel/model_origin/case22/aircon/aircon_body_model5.stl', 'OfficeModel/model_origin/case22/aircon/aircon_outlet_model5.stl']
# ['OfficeModel/model_origin/case22/airvent/20210812_airvent_a_model5.stl', 'OfficeModel/model_origin/case22/airvent/20210812_airvent_b_model5.stl']
# ['OfficeModel/model_origin/case22/body/20210812_bodies_case22.stl']
# ['OfficeModel/model_origin/case22/room/20210812_office_bottom_model5.stl', 'OfficeModel/model_origin/case22/room/20210812_office_side1_model5.stl', 'OfficeModel/model_origin/case22/room/20210812_office_side2_model5.stl', 'OfficeModel/model_origin/case22/room/20210812_office_side3_model5.stl', 'OfficeModel/model_origin/case22/room/20210812_office_side4_model5.stl', 'OfficeModel/model_origin/case22/room/20210812_office_top_model5.stl']
# ['OfficeModel/model_origin/case22/desks/20210812_desks_case22.stl']
# num_sampling_body =  688
# num_sampling_desks =  688
# (2048, 3)
# ['OfficeModel/model_origin/case28/aircon/20210812_aircon_inlets_model6.stl', 'OfficeModel/model_origin/case28/aircon/aircon_body_model6.stl', 'OfficeModel/model_origin/case28/aircon/aircon_outlet_model6.stl']
# ['OfficeModel/model_origin/case28/airvent/20210812_airvent_a_model6.stl', 'OfficeModel/model_origin/case28/airvent/20210812_airvent_b_model6.stl']
# ['OfficeModel/model_origin/case28/body/20210812_bodies_case28.stl']
# ['OfficeModel/model_origin/case28/room/20210812_office_bottom_model6.stl', 'OfficeModel/model_origin/case28/room/20210812_office_side1_model6.stl', 'OfficeModel/model_origin/case28/room/20210812_office_side2_model6.stl', 'OfficeModel/model_origin/case28/room/20210812_office_side3_model6.stl', 'OfficeModel/model_origin/case28/room/20210812_office_side4_model6.stl', 'OfficeModel/model_origin/case28/room/20210812_office_top_model6.stl']
# ['OfficeModel/model_origin/case28/desks/20210812_desks_case28.stl']
# num_sampling_body =  691
# num_sampling_desks =  691
# (2048, 3)
# ['OfficeModel/model_origin/case3/aircon/aircon_body.stl', 'OfficeModel/model_origin/case3/aircon/aircon_inlets.stl', 'OfficeModel/model_origin/case3/aircon/aircon_outlet.stl']
# ['OfficeModel/model_origin/case3/airvent/20210812_airvent_a.stl', 'OfficeModel/model_origin/case3/airvent/airvent_b.stl']
# ['OfficeModel/model_origin/case3/body/20210812_bodies_case3.stl']
# ['OfficeModel/model_origin/case3/room/20210810_office_bottom.stl', 'OfficeModel/model_origin/case3/room/20210810_office_side1.stl', 'OfficeModel/model_origin/case3/room/20210810_office_side2.stl', 'OfficeModel/model_origin/case3/room/20210810_office_side3.stl', 'OfficeModel/model_origin/case3/room/20210810_office_top.stl', 'OfficeModel/model_origin/case3/room/20210812_office_side4.stl']
# ['OfficeModel/model_origin/case3/desks/20210812_desks_case3.stl']
# num_sampling_body =  720
# num_sampling_desks =  720
# (2048, 3)
# ['OfficeModel/model_origin/case7/aircon/20210812_aircon_inlets_model2.stl', 'OfficeModel/model_origin/case7/aircon/aircon_body_model2.stl', 'OfficeModel/model_origin/case7/aircon/aircon_outlet_model2.stl']
# ['OfficeModel/model_origin/case7/airvent/20210812_airvent_a_model2.stl', 'OfficeModel/model_origin/case7/airvent/20210812_airvent_b_model2.stl']
# ['OfficeModel/model_origin/case7/body/20210812_bodies_case7.stl']
# ['OfficeModel/model_origin/case7/room/20210812_office_bottom_model2.stl', 'OfficeModel/model_origin/case7/room/20210812_office_side1_model2.stl', 'OfficeModel/model_origin/case7/room/20210812_office_side2_model2.stl', 'OfficeModel/model_origin/case7/room/20210812_office_side3_model2.stl', 'OfficeModel/model_origin/case7/room/20210812_office_side4_model2.stl', 'OfficeModel/model_origin/case7/room/20210812_office_top_model2.stl']
# ['OfficeModel/model_origin/case7/desks/20210812_desks_case7.stl']
# num_sampling_body =  720
# num_sampling_desks =  720
# (2048, 3)

# %%
from matplotlib import pyplot as plt

def plot3d_points(point_cloud):
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(projection="3d")
    ax.scatter(point_cloud[:, 0], point_cloud[:, 1], point_cloud[:, 2], alpha=0.4, s=2)
    # ax.set_axis_off()
    plt.show()
    
plot3d_points(sampledPointCloud_dict['office10'])

# %%
import numpy as np
'''
点群シャッフルによるデータ増強
'''
rng = np.random.default_rng()

pointCloud_augumented_dict = {}
for office_name, pointCloud in sampledPointCloud_dict.items():
    pc_list = []
    for i in range(4):
        pc = pointCloud.copy()

        if i >= 1:
            #点群のシャッフル
            rng.shuffle(pc)

        pc_list.append(pc)

    pointCloud_augumented_dict[office_name] = pc_list

pointCloud_augumented_dict
# Out:
# {'office1': [array([[2.5   , 2.25  , 2.6   ],
#          [2.5   , 2.375 , 2.6   ],
#          [2.5   , 2.45  , 2.6   ],
#          ...,
#          [1.925 , 1.525 , 0.5375],
#          [3.3   , 3.25  , 0.05  ],
#          [2.035 , 3.485 , 0.96  ]], dtype=float32),
#   array([[2.583533 , 3.05     , 2.566467 ],
#          [3.3      , 3.133533 , 2.566467 ],
#          [2.035488 , 3.254372 , 1.09709  ],
#          ...,
#          [1.925    , 1.741667 , 0.05     ],
#          [3.3      , 2.3503   , 2.5497   ],
#          [3.825    , 1.5      , 0.2833333]], dtype=float32),
#   array([[4.656392 , 2.240756 , 0.7325774],
#          [2.6003   , 3.05     , 2.5497   ],
#          [3.3      , 2.4      , 2.5375   ],
#          ...,
#          [1.263256 , 1.234858 , 0.8361718],
#          [3.35     , 2.45     , 2.566467 ],
#          [1.607448 , 1.022934 , 1.12066  ]], dtype=float32),
#   array([[2.85     , 1.15     , 0.265    ],
#          [3.725    , 2.225    , 0.2833333],
#          [2.566167 , 3.05     , 2.6      ],
#          ...,
#          [2.7      , 3.145455 , 2.545455 ],
#          [1.767384 , 3.230094 , 0.9524003],
#          [1.948179 , 3.345538 , 0.657453 ]], dtype=float32)],
#  'office10': [array([[3.       , 2.5      , 2.6      ],
#          [3.       , 2.625    , 2.6      ],
#          [3.       , 2.7      , 2.6      ],
#          ...,
#          [3.401667 , 2.275    , 0.7      ],
#          [0.975    , 3.1      , 0.6733333],
#          [2.635    , 3.1875   , 0.05     ]], dtype=float32),
#   array([[3.866767 , 3.3      , 2.6      ],
#          [4.795    , 4.285    , 0.745    ],
#          [4.830638 , 4.057806 , 0.8754651],
#          ...,
#          [3.32     , 3.3      , 2.6      ],
#          [3.8      , 3.1      , 2.6      ],
#          [3.205    , 4.285    , 0.6733333]], dtype=float32),
#   array([[3.685   , 2.415   , 0.75    ],
#          [5.085   , 2.325   , 0.7     ],
#          [0.925   , 3.03    , 0.53    ],
#          ...,
#          [3.685   , 3.305   , 0.75    ],
#          [5.085   , 3.165   , 0.75    ],
#          [3.8     , 2.640909, 2.509091]], dtype=float32),
#   array([[4.263941 , 1.811421 , 0.6114154],
#          [2.76     , 2.       , 0.3725   ],
#          [4.851667 , 2.275    , 0.7      ],
#          ...,
#          [2.958564 , 4.053843 , 0.6769962],
#          [1.108231 , 2.867218 , 0.7073165],
#          [3.16     , 4.       , 0.265    ]], dtype=float32)],
#  'office15': [array([[3.       , 2.5      , 2.6      ],
#          [3.       , 2.625    , 2.6      ],
#          [3.       , 2.7      , 2.6      ],
#          ...,
#          [0.94     , 1.87     , 0.6733333],
#          [1.7125   , 4.2      , 0.7      ],
#          [2.0375   , 2.35     , 0.05     ]], dtype=float32),
#   array([[2.2      , 2.75     , 0.375    ],
#          [3.68     , 2.7      , 2.6      ],
#          [3.41668  , 4.107955 , 0.3333365],
#          ...,
#          [2.89     , 3.93     , 0.96     ],
#          [2.89     , 2.445    , 0.48     ],
#          [3.125    , 2.525    , 0.265    ]], dtype=float32),
#   array([[3.074421 , 4.040874 , 1.113345 ],
#          [1.55     , 3.75     , 0.7      ],
#          [3.078    , 2.34     , 0.53     ],
#          ...,
#          [1.272    , 1.59     , 0.48     ],
#          [1.110286 , 1.867161 , 1.301092 ],
#          [1.014505 , 1.742947 , 0.6963945]], dtype=float32),
#   array([[3.8      , 3.386364 , 2.536364 ],
#          [3.8      , 2.65     , 2.5375   ],
#          [2.984    , 3.79     , 0.48     ],
#          ...,
#          [0.       , 6.       , 2.6      ],
#          [3.133833 , 3.3      , 2.516167 ],
#          [1.266534 , 3.23257  , 0.7094182]], dtype=float32)],
#  'office16': [array([[4.      , 2.      , 2.6     ],
#          [4.      , 2.125   , 2.6     ],
#          [4.      , 2.2     , 2.6     ],
#          ...,
#          [8.06    , 2.705   , 0.48    ],
#          [4.73    , 3.81    , 0.48    ],
#          [6.066667, 3.2     , 0.7     ]], dtype=float32),
#   array([[4.612011 , 3.200167 , 0.2777051],
#          [7.41215  , 2.644486 , 0.5774363],
#          [5.739999 , 1.759385 , 0.7038524],
#          ...,
#          [7.2875   , 1.875    , 0.05     ],
#          [4.505    , 1.76     , 0.48     ],
#          [6.367157 , 3.447027 , 0.7284787]], dtype=float32),
#   array([[4.917067 , 2.8      , 2.567067 ],
#          [4.572438 , 1.449708 , 0.6748077],
#          [5.033333 , 1.85     , 0.05     ],
#          ...,
#          [4.59     , 3.666    , 0.48     ],
#          [4.2      , 2.068182 , 2.581818 ],
#          [4.2      , 2.0997   , 2.566467 ]], dtype=float32),
#   array([[4.425   , 1.475   , 0.336667],
#          [4.0997  , 2.8     , 2.566467],
#          [7.696667, 2.285   , 0.53    ],
#          ...,
#          [4.85    , 2.2     , 2.5875  ],
#          [4.8     , 2.15    , 2.5875  ],
#          [4.87    , 3.76    , 0.673333]], dtype=float32)],
#  'office2': [array([[2.5     , 2.25    , 2.6     ],
#          [2.5     , 2.375   , 2.6     ],
#          [2.5     , 2.45    , 2.6     ],
#          ...,
#          [4.233333, 2.2     , 0.7     ],
#          [4.291667, 2.25    , 0.75    ],
#          [4.525   , 2.405556, 0.75    ]], dtype=float32),
#   array([[2.625    , 3.05     , 2.6      ],
#          [3.35     , 3.05     , 2.5      ],
#          [3.35     , 3.05     , 2.5375   ],
#          ...,
#          [4.663359 , 4.243979 , 0.6518211],
#          [2.825    , 4.125    , 2.6      ],
#          [3.94888  , 1.167533 , 0.9839677]], dtype=float32),
#   array([[2.744067 , 4.448505 , 1.042991 ],
#          [4.984665 , 2.855226 , 0.7588638],
#          [2.725494 , 4.364019 , 1.071451 ],
#          ...,
#          [4.473212 , 4.392262 , 0.297666 ],
#          [4.15     , 2.25     , 0.05     ],
#          [2.55     , 2.65     , 2.6      ]], dtype=float32),
#   array([[3.5      , 2.5      , 2.6      ],
#          [4.3125   , 3.25     , 0.05     ],
#          [4.905181 , 4.338877 , 0.7799323],
#          ...,
#          [4.984002 , 2.816721 , 1.169453 ],
#          [0.       , 0.       , 0.       ],
#          [4.375971 , 2.545704 , 0.1595385]], dtype=float32)],
#  'office22': [array([[3.85     , 2.75     , 2.6      ],
#          [3.85     , 2.875    , 2.6      ],
#          [3.85     , 2.95     , 2.6      ],
#          ...,
#          [2.85     , 3.766667 , 0.5166667],
#          [3.55     , 3.25     , 0.2125   ],
#          [5.41     , 2.04     , 0.8166667]], dtype=float32),
#   array([[4.1      , 2.196667 , 0.48     ],
#          [5.796652 , 2.403183 , 0.7863184],
#          [4.05     , 2.9      , 2.5      ],
#          ...,
#          [3.990909 , 3.55     , 2.509091 ],
#          [5.7      , 3.533333 , 0.05     ],
#          [5.24     , 4.56     , 0.8525   ]], dtype=float32),
#   array([[4.9      , 3.016667 , 0.2833333],
#          [3.759383 , 3.950519 , 0.3664187],
#          [3.55     , 3.3      , 0.7      ],
#          ...,
#          [3.5      , 2.783333 , 0.05     ],
#          [4.85     , 3.35     , 2.6      ],
#          [4.85     , 3.125    , 2.6      ]], dtype=float32),
#   array([[3.607683 , 4.418073 , 0.5731122],
#          [3.50978  , 4.383348 , 1.384244 ],
#          [5.41     , 2.353333 , 0.48     ],
#          ...,
#          [3.55     , 2.816667 , 0.7      ],
#          [4.05     , 2.9      , 2.5875   ],
#          [5.494062 , 2.625541 , 0.4836985]], dtype=float32)],
#  'office28': [array([[4.35     , 2.5      , 2.6      ],
#          [4.35     , 2.625    , 2.6      ],
#          [4.35     , 2.7      , 2.6      ],
#          ...,
#          [5.05     , 3.775    , 0.5375   ],
#          [3.7      , 3.125    , 0.4833333],
#          [2.25     , 3.308333 , 0.75     ]], dtype=float32),
#   array([[1.581951 , 3.940321 , 0.2527234],
#          [2.2      , 4.45     , 0.2666667],
#          [5.15     , 3.383533 , 2.6      ],
#          ...,
#          [2.847393 , 2.597173 , 0.8767467],
#          [5.35     , 2.5      , 2.6      ],
#          [4.55     , 2.582933 , 2.583233 ]], dtype=float32),
#   array([[5.15    , 3.35    , 2.5497  ],
#          [3.65    , 3.541667, 0.05    ],
#          [4.5     , 4.565   , 0.53    ],
#          ...,
#          [2.985801, 2.758556, 1.266844],
#          [4.627892, 4.917978, 1.153311],
#          [4.272453, 4.433664, 0.588793]], dtype=float32),
#   array([[5.2      , 2.7      , 2.5497   ],
#          [4.554749 , 2.804502 , 0.6229589],
#          [5.281818 , 2.7      , 2.581818 ],
#          ...,
#          [5.15     , 2.566767 , 2.583233 ],
#          [4.79     , 2.65     , 2.6      ],
#          [1.019399 , 3.942175 , 1.075532 ]], dtype=float32)],
#  'office3': [array([[2.5      , 2.25     , 2.6      ],
#          [2.5      , 2.375    , 2.6      ],
#          [2.5      , 2.45     , 2.6      ],
#          ...,
#          [1.31     , 0.62     , 0.8166667],
#          [4.975    , 2.425    , 0.48     ],
#          [5.25     , 4.0625   , 0.7      ]], dtype=float32),
#   array([[1.183638 , 0.3490601, 1.062603 ],
#          [4.81378  , 3.851801 , 1.373789 ],
#          [1.26     , 0.55     , 0.53     ],
#          ...,
#          [0.6072717, 1.799088 , 0.1613248],
#          [3.366767 , 3.05     , 2.5497   ],
#          [0.6572427, 0.716789 , 0.5901658]], dtype=float32),
#   array([[5.323402 , 2.522428 , 0.5006172],
#          [3.3      , 3.1503   , 2.6      ],
#          [0.7809775, 2.093996 , 0.6955576],
#          ...,
#          [5.625    , 1.4      , 0.05     ],
#          [0.9466667, 0.48     , 0.53     ],
#          [5.483333 , 1.45     , 0.05     ]], dtype=float32),
#   array([[4.941642 , 3.796732 , 0.8357254],
#          [1.23476  , 0.5501352, 0.9091379],
#          [4.69     , 2.19     , 0.96     ],
#          ...,
#          [0.9099179, 0.5256441, 0.672611 ],
#          [1.048856 , 0.6487931, 1.011963 ],
#          [4.975    , 2.375    , 0.1575   ]], dtype=float32)],
#  'office7': [array([[4.       , 1.5      , 2.6      ],
#          [4.       , 1.625    , 2.6      ],
#          [4.       , 1.7      , 2.6      ],
#          ...,
#          [4.67     , 3.385    , 0.48     ],
#          [3.08     , 3.335    , 0.8166667],
#          [4.13     , 1.335    , 0.53     ]], dtype=float32),
#   array([[4.05    , 1.9     , 2.6     ],
#          [4.4     , 1.375   , 0.75    ],
#          [4.2     , 1.633233, 2.516767],
#          ...,
#          [4.85    , 1.7     , 2.583233],
#          [4.9003  , 1.7     , 2.6     ],
#          [4.116467, 1.7     , 2.583233]], dtype=float32),
#   array([[4.477087 , 3.28251  , 0.8885449],
#          [2.597794 , 1.37402  , 0.3764767],
#          [3.7      , 2.825    , 0.7      ],
#          ...,
#          [4.575    , 3.15     , 0.1933333],
#          [4.178897 , 1.216231 , 0.6210251],
#          [5.05     , 2.775    , 0.2666667]], dtype=float32),
#   array([[1.241297 , 2.432485 , 0.5813248],
#          [1.12386  , 2.519488 , 1.138234 ],
#          [4.0997   , 2.3      , 2.6      ],
#          ...,
#          [2.944394 , 1.0716   , 0.9120755],
#          [4.32     , 2.45     , 2.6      ],
#          [4.066667 , 1.425    , 0.7      ]], dtype=float32)]}

# %%
'''
点群データ増強に合わせて、メタデータや感染リスク分布のデータも複製して増やす
'''
case_index_list = list(df_total.index)


case_index_augumented_list = []

pointCloudArray_list = []
metaArray_list = []

RoI_list = []

for case_index in case_index_list:
    office_name = case_index.split('_', maxsplit=1)[0]
    pc_list = pointCloud_augumented_dict[office_name]
    for augumentID, pointCloud in enumerate(pc_list):
        case_index_augumented_list.append(case_index + '-' + str(augumentID))
        pointCloudArray_list.append(pointCloud)
        metaArray_list.append(df_meta_standardized.loc[case_index])
        RoI_list.append(df_RoI_standardized.loc[case_index])

case_index_array = np.array(case_index_augumented_list)
metaArray = np.array(metaArray_list)
RoIArray = np.array(RoI_list)

pointCloudArray = np.array(pointCloudArray_list)

# %%
print(pointCloudArray.max())
pointCloudArray /= pointCloudArray.max() #Normalization
print(pointCloudArray.max())
# Out:
# 9.5
# 1.0

# %%
print(case_index_array.shape)

print(pointCloudArray.shape)
print(metaArray.shape)

print(RoIArray.shape)
# Out:
# (1052,)
# (1052, 2048, 3)
# (1052, 5)
# (1052,)

# %%
plot3d_points(pointCloudArray[0, :,:])

# %%
plot3d_points(sampledPointCloud_dict["office7"])

# %% [markdown]
# # モデル実装

# %%
from tensorflow.python.client import device_lib; print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9622499177811939915
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 9833938944
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 10190316827539546501
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:06:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]
# 2022-10-09 03:32:41.224115: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-09 03:32:41.708383: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1553] Created device /device:GPU:0 with 9378 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:06:00.0, compute capability: 8.6

# %%
from tensorflow import keras
from PointNet import conv_bn, dense_bn


def permutation_invariant_network_builder(hp, inputs):
    """
    順序不変性（PointNetからtnetを除去したもの）モデルビルダー関数

    ハイパーパラメータを引数にとる（チューニング用）
    """

    x = inputs
    
    hp_conv_layers_1 = hp.Int('conv_bn_layers', min_value = 1, max_value = 4, step = 1)
    for i in range(hp_conv_layers_1):
        hp_filters = hp.Int(f'filters_bn-{i}', min_value = 32, max_value = 512, step = 32)
        x = conv_bn(x, hp_filters)
    
    x = keras.layers.GlobalMaxPooling1D()(x)
    
    # Tune the dropout rate for the optimizer 
#     hp_dropout_rate = hp.Choice('dropout_rate', values = [0.3, 0.5, 0.9])
    
    hp_dense_layers = hp.Int('dense_bn_layers', min_value = 0, max_value = 4, step = 1)
    for i in range(hp_dense_layers):
        hp_units = hp.Int(f'units_bn_{i}', min_value = 32, max_value = 512, step = 32)
        x = dense_bn(x, hp_units)
#         x = keras.layers.Dropout(hp_dropout_rate)(x)

    hp_features = hp.Int('features', min_value = 4, max_value = 64, step = 4)
    features = keras.layers.Dense(hp_features)(x)
    hp_activation_pn = hp.Choice('activation_pn', values = ["None", "ReLU", "LeakyReLU", "ELU", "BatchNormalization"]) 
    if hp_activation_pn == "ReLU":
        features = keras.layers.ReLU()(features)
    elif hp_activation_pn == "LeakyReLU":
        features = keras.layers.LeakyReLU()(features)
    elif hp_activation_pn == "ELU":
        features = keras.layers.ELU()(features)
    elif hp_activation_pn == "BatchNormalization":
        features = keras.layers.BatchNormalization()(features)

    return features

# %%
NUM_POINTS = pointCloudArray.shape[1]

def total_model_builder(hp):
    """
    感染リスク分布予測モデル

    順序不変性モデルに、メタデータ（空調条件）を合流させ、
    転置畳み込みで感染リスク分布を出力する。

    KerasTunerから呼び出され、ハイパーパラメータをチューニングする
    """
    input_pointCloud = keras.Input(shape=(NUM_POINTS, 3), name='pointCloud')
    input_meta = keras.Input(shape=(metaArray.shape[1], ), name='meta')

    features_pc = permutation_invariant_network_builder(hp, input_pointCloud)
    
    features = keras.layers.Concatenate()([features_pc, input_meta])

    x = features
    
    hp_dense_layers = hp.Int('dense_layers', min_value = 0, max_value = 4, step = 1)
    hp_activation = hp.Choice('activation', values = ["ReLU", "LeakyReLU", "ELU"]) 
    
    for i in range(hp_dense_layers):
        hp_units = hp.Int(f'units-{i}', min_value = 32, max_value = 512, step = 32)
        x = keras.layers.Dense(hp_units)(x)
        if hp_activation == "ReLU":
            x = keras.layers.ReLU()(x)
        elif hp_activation == "LeakyReLU":
            x = keras.layers.LeakyReLU()(x)
        elif hp_activation == "ELU":
            x = keras.layers.ELU()(x)

    
    outputs = keras.layers.Dense(1)(x)

    hp_learning_rate = hp.Choice('learning_rate', values = [1e-2, 1e-3, 1e-4]) 
    model = keras.Model(inputs=[input_pointCloud, input_meta], outputs=outputs, name="predictionnet")
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
#         optimizer=keras.optimizers.RMSprop(learning_rate=hp_learning_rate),
        loss='mse',
        metrics=['mae']
        )

    return model

# %% [markdown]
# # チューニング

# %%
'''
特定のofficeだけ、テスト用にとっておく。
学習にも、チューニング中の検証にも使わない。
'''

office_for_test = 'office10'
fit_ID = []
test_ID = []

for (ID, case_index) in enumerate(case_index_augumented_list):
    if office_for_test + '_' not in case_index:
        fit_ID.append(ID)
    else:
        test_ID.append(ID)

print(case_index_array[test_ID])
        
case_index_fit = case_index_array[fit_ID]
X_pc_fit = pointCloudArray[fit_ID]
X_meta_fit = metaArray[fit_ID]
y_fit = RoIArray[fit_ID]

case_index_test = case_index_array[test_ID]
X_pc_test = pointCloudArray[test_ID]
X_meta_test = metaArray[test_ID]
y_test = RoIArray[test_ID]
# Out:
# ['office10_360_164_bout-0' 'office10_360_164_bout-1'
#  'office10_360_164_bout-2' 'office10_360_164_bout-3'
#  'office10_660_246_aout-0' 'office10_660_246_aout-1'
#  'office10_660_246_aout-2' 'office10_660_246_aout-3'
#  'office10_660_82_bout-0' 'office10_660_82_bout-1'
#  'office10_660_82_bout-2' 'office10_660_82_bout-3'
#  'office10_660_82_aout-0' 'office10_660_82_aout-1'
#  'office10_660_82_aout-2' 'office10_660_82_aout-3'
#  'office10_660_164_bout-0' 'office10_660_164_bout-1'
#  'office10_660_164_bout-2' 'office10_660_164_bout-3'
#  'office10_0_164_aout-0' 'office10_0_164_aout-1' 'office10_0_164_aout-2'
#  'office10_0_164_aout-3' 'office10_0_82_aout-0' 'office10_0_82_aout-1'
#  'office10_0_82_aout-2' 'office10_0_82_aout-3' 'office10_660_164_aout-0'
#  'office10_660_164_aout-1' 'office10_660_164_aout-2'
#  'office10_660_164_aout-3' 'office10_660_246_bout-0'
#  'office10_660_246_bout-1' 'office10_660_246_bout-2'
#  'office10_660_246_bout-3' 'office10_360_246_bout-0'
#  'office10_360_246_bout-1' 'office10_360_246_bout-2'
#  'office10_360_246_bout-3' 'office10_960_82_aout-0'
#  'office10_960_82_aout-1' 'office10_960_82_aout-2'
#  'office10_960_82_aout-3' 'office10_360_82_bout-0'
#  'office10_360_82_bout-1' 'office10_360_82_bout-2'
#  'office10_360_82_bout-3' 'office10_360_82_aout-0'
#  'office10_360_82_aout-1' 'office10_360_82_aout-2'
#  'office10_360_82_aout-3' 'office10_0_0-0' 'office10_0_0-1'
#  'office10_0_0-2' 'office10_0_0-3' 'office10_960_164_bout-0'
#  'office10_960_164_bout-1' 'office10_960_164_bout-2'
#  'office10_960_164_bout-3' 'office10_0_246_aout-0' 'office10_0_246_aout-1'
#  'office10_0_246_aout-2' 'office10_0_246_aout-3' 'office10_360_164_aout-0'
#  'office10_360_164_aout-1' 'office10_360_164_aout-2'
#  'office10_360_164_aout-3' 'office10_360_0-0' 'office10_360_0-1'
#  'office10_360_0-2' 'office10_360_0-3' 'office10_0_82_bout-0'
#  'office10_0_82_bout-1' 'office10_0_82_bout-2' 'office10_0_82_bout-3'
#  'office10_960_246_aout-0' 'office10_960_246_aout-1'
#  'office10_960_246_aout-2' 'office10_960_246_aout-3'
#  'office10_960_164_aout-0' 'office10_960_164_aout-1'
#  'office10_960_164_aout-2' 'office10_960_164_aout-3'
#  'office10_0_164_bout-0' 'office10_0_164_bout-1' 'office10_0_164_bout-2'
#  'office10_0_164_bout-3' 'office10_0_246_bout-0' 'office10_0_246_bout-1'
#  'office10_0_246_bout-2' 'office10_0_246_bout-3' 'office10_960_82_bout-0'
#  'office10_960_82_bout-1' 'office10_960_82_bout-2'
#  'office10_960_82_bout-3' 'office10_660_0-0' 'office10_660_0-1'
#  'office10_660_0-2' 'office10_660_0-3' 'office10_360_246_aout-0'
#  'office10_360_246_aout-1' 'office10_360_246_aout-2'
#  'office10_360_246_aout-3' 'office10_960_0-0' 'office10_960_0-1'
#  'office10_960_0-2' 'office10_960_0-3' 'office10_960_246_bout-0'
#  'office10_960_246_bout-1' 'office10_960_246_bout-2'
#  'office10_960_246_bout-3']

# %%
from k_cross_split import get_k_cross_ID_list

'''
チューニングに使うデータを，学習用と検証用に分ける
'''

data_size = len(X_pc_fit)
k = 4
print('data_size =', data_size)
print('k =', k)

#k分割交差検証用の関数だが、ここでは単に訓練データと検証データの分割目的で使う
k_cross_ID_list = get_k_cross_ID_list(data_size, k)

(train_ID, val_ID) = k_cross_ID_list[0]
print(train_ID)
print(val_ID)

X_pc_train = X_pc_fit[train_ID]
X_meta_train = X_meta_fit[train_ID]
y_train = y_fit[train_ID]

X_pc_val = X_pc_fit[val_ID]
X_meta_val = X_meta_fit[val_ID]
y_val = y_fit[val_ID]
# Out:
# data_size = 940
# k = 4
# [281, 884, 338, 513, 694, 14, 376, 465, 314, 13, 507, 265, 343, 618, 183, 215, 524, 192, 259, 229, 864, 720, 715, 471, 470, 593, 480, 71, 777, 386, 512, 411, 514, 258, 772, 905, 143, 365, 824, 318, 56, 267, 300, 325, 770, 839, 787, 778, 742, 324, 275, 311, 63, 438, 48, 414, 662, 494, 407, 616, 803, 462, 667, 761, 101, 27, 606, 248, 23, 370, 822, 293, 458, 433, 645, 33, 444, 460, 373, 706, 843, 601, 263, 876, 115, 504, 666, 2, 350, 431, 191, 142, 408, 815, 256, 165, 257, 811, 745, 128, 928, 396, 145, 331, 354, 813, 104, 442, 364, 17, 605, 54, 359, 447, 459, 435, 77, 87, 223, 909, 468, 927, 172, 307, 173, 327, 590, 709, 204, 536, 292, 315, 567, 657, 412, 422, 134, 672, 40, 638, 595, 722, 28, 625, 525, 586, 423, 539, 390, 823, 467, 866, 356, 853, 290, 452, 202, 885, 488, 750, 580, 193, 501, 243, 697, 555, 398, 446, 31, 236, 725, 176, 218, 132, 329, 612, 18, 111, 15, 597, 80, 840, 516, 868, 886, 660, 457, 205, 323, 656, 841, 573, 198, 140, 515, 374, 427, 791, 783, 120, 895, 557, 621, 136, 240, 903, 904, 756, 604, 403, 503, 780, 486, 727, 139, 531, 896, 838, 4, 285, 808, 576, 734, 7, 186, 882, 726, 335, 295, 413, 75, 691, 428, 58, 878, 282, 519, 74, 29, 865, 310, 39, 650, 544, 137, 854, 41, 52, 692, 188, 64, 900, 797, 740, 708, 158, 123, 753, 116, 863, 92, 594, 711, 426, 171, 225, 432, 902, 38, 929, 119, 189, 200, 83, 776, 451, 481, 340, 820, 261, 790, 585, 10, 732, 475, 640, 542, 391, 773, 70, 675, 685, 921, 78, 664, 131, 441, 793, 923, 393, 910, 718, 319, 860, 170, 69, 461, 464, 560, 179, 617, 32, 36, 42, 581, 185, 262, 679, 521, 286, 153, 382, 291, 751, 68, 631, 1, 112, 912, 19, 875, 419, 445, 788, 301, 889, 400, 757, 212, 220, 752, 935, 302, 349, 505, 673, 96, 72, 454, 737, 862, 654, 81, 799, 592, 532, 416, 915, 196, 508, 888, 744, 781, 224, 162, 852, 807, 117, 334, 529, 630, 913, 893, 26, 646, 614, 833, 415, 73, 765, 206, 551, 141, 526, 748, 88, 12, 669, 228, 368, 719, 135, 569, 937, 362, 818, 360, 769, 543, 355, 858, 547, 439, 150, 169, 796, 518, 296, 801, 795, 871, 626, 651, 728, 565, 517, 437, 548, 798, 328, 44, 920, 587, 299, 167, 689, 251, 425, 733, 710, 930, 84, 681, 332, 538, 677, 566, 870, 851, 409, 821, 687, 138, 62, 899, 835, 159, 589, 233, 34, 82, 628, 379, 95, 232, 320, 738, 174, 177, 747, 496, 297, 816, 541, 596, 344, 235, 479, 456, 699, 5, 779, 316, 511, 623, 380, 674, 812, 242, 688, 181, 244, 352, 317, 289, 79, 108, 782, 484, 762, 922, 175, 9, 502, 366, 98, 466, 266, 250, 610, 897, 49, 746, 237, 351, 608, 933, 180, 828, 693, 907, 892, 347, 113, 848, 21, 214, 603, 389, 333, 890, 825, 894, 749, 498, 829, 832, 53, 668, 774, 358, 127, 556, 8, 497, 126, 644, 754, 100, 283, 216, 898, 700, 931, 856, 869, 337, 94, 867, 404, 278, 222, 369, 695, 322, 599, 160, 522, 231, 114, 383, 552, 268, 792, 247, 147, 190, 925, 455, 758, 420, 11, 90, 371, 353, 549, 377, 874, 880, 495, 443, 743, 724, 272, 61, 166, 434, 279, 424, 775, 647, 665, 157, 339, 712, 550, 6, 591, 260, 239, 308, 20, 682, 85, 378, 842, 533, 579, 717, 312, 701, 588, 107, 86, 367, 43, 146, 755, 154, 627, 168, 553, 195, 226, 678, 221, 37, 129, 655, 879, 600, 683, 535, 309, 523, 230, 118, 124, 804, 916, 208, 429, 219, 436, 164, 739, 607, 375, 764, 410, 405, 161, 46, 562, 814, 926, 35, 891, 613, 16, 639, 284, 506, 873, 399, 648, 575, 652, 611, 0, 194, 184, 210, 846, 908, 534, 306, 730, 859, 305, 276, 110, 65, 326, 759, 103, 238, 133, 50, 207, 690, 643, 397, 105, 482, 346, 478, 766, 321, 809, 684, 698, 598, 671, 703]
# [520, 303, 936, 554, 545, 670, 47, 155, 253, 800, 122, 156, 178, 649, 702, 402, 794, 330, 834, 849, 705, 91, 217, 121, 298, 89, 636, 578, 570, 197, 704, 658, 620, 254, 584, 30, 934, 463, 421, 784, 357, 924, 109, 51, 857, 450, 345, 574, 490, 187, 563, 270, 831, 686, 252, 855, 847, 826, 392, 572, 883, 528, 850, 624, 582, 723, 877, 767, 241, 635, 227, 491, 448, 66, 487, 642, 245, 271, 163, 304, 729, 568, 583, 125, 932, 641, 45, 836, 472, 363, 273, 602, 99, 201, 837, 918, 735, 830, 485, 736, 22, 106, 182, 60, 707, 537, 430, 819, 577, 637, 500, 731, 827, 394, 492, 561, 633, 418, 716, 881, 336, 696, 269, 901, 806, 805, 277, 209, 530, 213, 372, 246, 615, 57, 771, 844, 406, 55, 763, 713, 632, 558, 440, 911, 361, 287, 938, 872, 861, 629, 280, 785, 24, 203, 634, 211, 384, 76, 148, 786, 3, 144, 571, 401, 789, 676, 102, 234, 149, 152, 477, 255, 653, 387, 489, 93, 130, 473, 499, 680, 564, 476, 294, 381, 906, 810, 510, 249, 274, 151, 264, 721, 546, 559, 67, 622, 483, 527, 313, 663, 59, 939, 887, 449, 714, 817, 288, 493, 845, 914, 385, 919, 741, 661, 417, 25, 348, 469, 509, 768, 342, 341, 97, 802, 619, 659, 540, 395, 199, 760, 609, 917, 453, 388, 474]

# %%
import IPython
import keras_tuner as kt

# %%
import shutil
import datetime

# if os.path.exists(output_dir):
#     shutil.rmtree(output_dir)

projectName = 'trial' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# projectName = "trial20221004-023343"
print("projectName : " + projectName)

output_dir = './KerasTuner_log'

# if os.path.exists(output_dir):
#     shutil.rmtree(output_dir)

tuner = kt.Hyperband(total_model_builder,
                     objective = 'val_loss', 
                     max_epochs = 1000,
                    #  factor = 3,
                     directory = output_dir,
                     project_name = projectName
                     )
# Out:
# projectName : trial20221015-100037

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping

logdir = os.path.join("tblogs", projectName)
tensorboard_cb = keras.callbacks.TensorBoard(log_dir=logdir, histogram_freq=1)

print("logdir : ", logdir)

class ClearTrainingOutput(tf.keras.callbacks.Callback):
    def on_train_end(*args, **kwargs):
        IPython.display.clear_output(wait = True)

estop_tuning =  EarlyStopping(monitor='val_loss', min_delta=0.0, patience=40)
# Out:
# logdir :  tblogs/trial20221015-100037

# %%
# case_index_train = case_index_array[train_ID]
# case_index_test = case_index_array[test_ID]

# %%
# tuner.search({'pointCloud':X_pc_train, 'meta':X_meta_train}, Y_train,
#              epochs = 40,
#              validation_data = ({'pointCloud':X_pc_test, 'meta':X_meta_test}, Y_test),
#              callbacks = [ClearTrainingOutput()])

# %%
tuner.search({'pointCloud':X_pc_train, 'meta':X_meta_train}, y_train,
             epochs = 1000,
             validation_data = ({'pointCloud':X_pc_val, 'meta':X_meta_val}, y_val),
             # callbacks = [tensorboard_cb, estop_tuning, ClearTrainingOutput()])
             callbacks = [estop_tuning, ClearTrainingOutput(), tensorboard_cb])
# Out:
# Trial 2074 Complete [00h 00m 19s]
# val_loss: 8115976.0
#
# Best val_loss So Far: 0.06716924905776978
# Total elapsed time: 05h 23m 38s
# INFO:tensorflow:Oracle triggered exit

# %% [markdown]
# #memo
#
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0385s vs `on_train_batch_end` time: 0.0630s). Check your callbacks.

# %%
# %load_ext tensorboard
# %tensorboard  --logdir $logdir
# Out:
#       <iframe id="tensorboard-frame-662fbfa361b769ed" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-662fbfa361b769ed");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# function ClickConnect(){
#   console.log("60sごとに再接続");
#   document.querySelector("colab-connect-button").click()
# }
# setInterval(ClickConnect,1000*60);

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in ./KerasTuner_log/trial20221015-100037
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x7f071d97a070>
# Trial summary
# Hyperparameters:
# conv_bn_layers: 2
# filters_bn-0: 96
# dense_bn_layers: 0
# features: 64
# activation_pn: ReLU
# dense_layers: 3
# activation: ReLU
# learning_rate: 0.001
# filters_bn-1: 96
# units_bn_0: 416
# units-0: 480
# units_bn_1: 160
# units_bn_2: 256
# units-1: 288
# filters_bn-2: 288
# units-2: 448
# filters_bn-3: 224
# units_bn_3: 352
# units-3: 352
# tuner/epochs: 1000
# tuner/initial_epoch: 334
# tuner/bracket: 5
# tuner/round: 5
# tuner/trial_id: 1733
# Score: 0.06716924905776978
# Trial summary
# Hyperparameters:
# conv_bn_layers: 2
# filters_bn-0: 96
# dense_bn_layers: 0
# features: 64
# activation_pn: ReLU
# dense_layers: 3
# activation: ReLU
# learning_rate: 0.001
# filters_bn-1: 96
# units_bn_0: 416
# units-0: 480
# units_bn_1: 160
# units_bn_2: 256
# units-1: 288
# filters_bn-2: 288
# units-2: 448
# filters_bn-3: 224
# units_bn_3: 352
# units-3: 352
# tuner/epochs: 334
# tuner/initial_epoch: 112
# tuner/bracket: 5
# tuner/round: 4
# tuner/trial_id: 1721
# Score: 0.07813175022602081
# Trial summary
# Hyperparameters:
# conv_bn_layers: 3
# filters_bn-0: 224
# dense_bn_layers: 0
# features: 28
# activation_pn: LeakyReLU
# dense_layers: 2
# activation: ReLU
# learning_rate: 0.001
# filters_bn-1: 64
# units_bn_0: 128
# units-0: 320
# units_bn_1: 96
# units_bn_2: 384
# units-1: 448
# filters_bn-2: 448
# units-2: 96
# filters_bn-3: 224
# units_bn_3: 288
# units-3: 64
# tuner/epochs: 334
# tuner/initial_epoch: 112
# tuner/bracket: 6
# tuner/round: 5
# tuner/trial_id: 1243
# Score: 0.08047018200159073
# Trial summary
# Hyperparameters:
# conv_bn_layers: 3
# filters_bn-0: 288
# dense_bn_layers: 0
# features: 16
# activation_pn: None
# dense_layers: 4
# activation: LeakyReLU
# learning_rate: 0.0001
# filters_bn-1: 288
# units_bn_0: 256
# units-0: 256
# units_bn_1: 448
# units_bn_2: 160
# units-1: 416
# filters_bn-2: 352
# units-2: 224
# filters_bn-3: 352
# units_bn_3: 224
# units-3: 288
# tuner/epochs: 1000
# tuner/initial_epoch: 334
# tuner/bracket: 4
# tuner/round: 4
# tuner/trial_id: 1932
# Score: 0.10560674220323563
# Trial summary
# Hyperparameters:
# conv_bn_layers: 3
# filters_bn-0: 32
# dense_bn_layers: 0
# features: 28
# activation_pn: ELU
# dense_layers: 3
# activation: ReLU
# learning_rate: 0.0001
# filters_bn-1: 480
# units_bn_0: 288
# units-0: 224
# units_bn_1: 256
# units_bn_2: 448
# units-1: 480
# filters_bn-2: 448
# units-2: 160
# filters_bn-3: 512
# units_bn_3: 288
# units-3: 288
# tuner/epochs: 1000
# tuner/initial_epoch: 334
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 2039
# Score: 0.11458523571491241
# Trial summary
# Hyperparameters:
# conv_bn_layers: 2
# filters_bn-0: 192
# dense_bn_layers: 0
# features: 4
# activation_pn: None
# dense_layers: 3
# activation: ReLU
# learning_rate: 0.0001
# filters_bn-1: 384
# units_bn_0: 96
# units-0: 64
# units_bn_1: 512
# units_bn_2: 384
# units-1: 288
# filters_bn-2: 416
# units-2: 480
# filters_bn-3: 480
# units_bn_3: 416
# units-3: 128
# tuner/epochs: 1000
# tuner/initial_epoch: 334
# tuner/bracket: 4
# tuner/round: 4
# tuner/trial_id: 1928
# Score: 0.1181415393948555
# Trial summary
# Hyperparameters:
# conv_bn_layers: 2
# filters_bn-0: 192
# dense_bn_layers: 0
# features: 4
# activation_pn: None
# dense_layers: 3
# activation: ReLU
# learning_rate: 0.0001
# filters_bn-1: 384
# units_bn_0: 96
# units-0: 64
# units_bn_1: 512
# units_bn_2: 384
# units-1: 288
# filters_bn-2: 416
# units-2: 480
# filters_bn-3: 480
# units_bn_3: 416
# units-3: 128
# tuner/epochs: 112
# tuner/initial_epoch: 38
# tuner/bracket: 4
# tuner/round: 2
# tuner/trial_id: 1871
# Score: 0.1310099959373474
# Trial summary
# Hyperparameters:
# conv_bn_layers: 2
# filters_bn-0: 96
# dense_bn_layers: 0
# features: 64
# activation_pn: ReLU
# dense_layers: 3
# activation: ReLU
# learning_rate: 0.001
# filters_bn-1: 96
# units_bn_0: 416
# units-0: 480
# units_bn_1: 160
# units_bn_2: 256
# units-1: 288
# filters_bn-2: 288
# units-2: 448
# filters_bn-3: 224
# units_bn_3: 352
# units-3: 352
# tuner/epochs: 112
# tuner/initial_epoch: 38
# tuner/bracket: 5
# tuner/round: 3
# tuner/trial_id: 1686
# Score: 0.1369984745979309
# Trial summary
# Hyperparameters:
# conv_bn_layers: 3
# filters_bn-0: 224
# dense_bn_layers: 0
# features: 28
# activation_pn: LeakyReLU
# dense_layers: 2
# activation: ReLU
# learning_rate: 0.001
# filters_bn-1: 64
# units_bn_0: 128
# units-0: 320
# units_bn_1: 96
# units_bn_2: 384
# units-1: 448
# filters_bn-2: 448
# units-2: 96
# filters_bn-3: 224
# units_bn_3: 288
# units-3: 64
# tuner/epochs: 112
# tuner/initial_epoch: 38
# tuner/bracket: 6
# tuner/round: 4
# tuner/trial_id: 1207
# Score: 0.14856022596359253
# Trial summary
# Hyperparameters:
# conv_bn_layers: 3
# filters_bn-0: 384
# dense_bn_layers: 0
# features: 20
# activation_pn: ReLU
# dense_layers: 2
# activation: ReLU
# learning_rate: 0.001
# filters_bn-1: 32
# units_bn_0: 448
# units-0: 320
# units_bn_1: 416
# units_bn_2: 128
# units-1: 224
# filters_bn-2: 352
# units-2: 128
# filters_bn-3: 32
# units_bn_3: 192
# units-3: 64
# tuner/epochs: 112
# tuner/initial_epoch: 38
# tuner/bracket: 6
# tuner/round: 4
# tuner/trial_id: 1231
# Score: 0.15632951259613037

# %%
# Get the optimal hyperparameters
# best_hps = tuner.get_best_hyperparameters(num_trials = 1)[0]
best_hps = tuner.get_best_hyperparameters()[0]

# best_conv_layers =best_hps.get('conv_bn_layers')
# print('best_conv_bn_layers = ', best_conv_layers)
# for i in range(best_conv_layers):
#     print(best_hps.get(f'filters_bn-{i}'))
    
# best_dense_layers =best_hps.get('dense_bn_layers')
# print('best_dense_layers = ', best_dense_layers)
# for i in range(best_dense_layers):
#     print(best_hps.get(f'units_bn_{i}'))

# print('best_features = ', best_hps.get('features'))
    
# print('best_learning_rate = ', best_hps.get('learning_rate'))

# %%
# Build the model with the optimal hyperparameters
model = tuner.hypermodel.build(best_hps)

keras.utils.plot_model(model, show_shapes=True)

# %%
from tensorflow.keras.callbacks import EarlyStopping

estop =  EarlyStopping(monitor='val_loss', min_delta=0.0, patience=100)

best_history = model.fit(
    {'pointCloud':X_pc_train, 'meta':X_meta_train}, y_train,
    batch_size = 20,
    epochs = 1000,
    validation_data = ({'pointCloud':X_pc_val, 'meta':X_meta_val}, y_val),
    callbacks=[estop]
)
# Out:
# Epoch 1/1000
# 36/36 [==============================] - 2s 15ms/step - loss: 0.9688 - mae: 0.7451 - val_loss: 0.4683 - val_mae: 0.5608
# Epoch 2/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.3419 - mae: 0.4639 - val_loss: 0.2363 - val_mae: 0.3983
# Epoch 3/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.3558 - mae: 0.4822 - val_loss: 0.2734 - val_mae: 0.4234
# Epoch 4/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.2409 - mae: 0.3933 - val_loss: 0.1999 - val_mae: 0.3567
# Epoch 5/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.2252 - mae: 0.3753 - val_loss: 0.2133 - val_mae: 0.3669
# Epoch 6/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.2513 - mae: 0.4078 - val_loss: 0.1979 - val_mae: 0.3654
# Epoch 7/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1894 - mae: 0.3486 - val_loss: 0.1605 - val_mae: 0.3030
# Epoch 8/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.1702 - mae: 0.3254 - val_loss: 0.1606 - val_mae: 0.3220
# Epoch 9/1000
# 36/36 [==============================] - 0s 11ms/step - loss: 0.1778 - mae: 0.3312 - val_loss: 0.1546 - val_mae: 0.3055
# Epoch 10/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1686 - mae: 0.3211 - val_loss: 0.2220 - val_mae: 0.3657
# Epoch 11/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.1739 - mae: 0.3276 - val_loss: 0.1684 - val_mae: 0.3221
# Epoch 12/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.1574 - mae: 0.3149 - val_loss: 0.2166 - val_mae: 0.3868
# Epoch 13/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.1247 - mae: 0.2728 - val_loss: 0.1988 - val_mae: 0.3586
# Epoch 14/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1173 - mae: 0.2676 - val_loss: 0.1484 - val_mae: 0.2995
# Epoch 15/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.1272 - mae: 0.2754 - val_loss: 0.1822 - val_mae: 0.3460
# Epoch 16/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.1168 - mae: 0.2634 - val_loss: 0.1367 - val_mae: 0.2934
# Epoch 17/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.1214 - mae: 0.2655 - val_loss: 0.1085 - val_mae: 0.2479
# Epoch 18/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1178 - mae: 0.2678 - val_loss: 0.1191 - val_mae: 0.2530
# Epoch 19/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.1241 - mae: 0.2710 - val_loss: 0.1647 - val_mae: 0.3200
# Epoch 20/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.1242 - mae: 0.2757 - val_loss: 0.1589 - val_mae: 0.3018
# Epoch 21/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1171 - mae: 0.2625 - val_loss: 0.1139 - val_mae: 0.2480
# Epoch 22/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0974 - mae: 0.2313 - val_loss: 0.1440 - val_mae: 0.2846
# Epoch 23/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0833 - mae: 0.2138 - val_loss: 0.0917 - val_mae: 0.2220
# Epoch 24/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0893 - mae: 0.2288 - val_loss: 0.1234 - val_mae: 0.2661
# Epoch 25/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.1321 - mae: 0.2837 - val_loss: 0.0960 - val_mae: 0.2322
# Epoch 26/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.1222 - mae: 0.2740 - val_loss: 0.1033 - val_mae: 0.2346
# Epoch 27/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0929 - mae: 0.2308 - val_loss: 0.0866 - val_mae: 0.2233
# Epoch 28/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0767 - mae: 0.2113 - val_loss: 0.1165 - val_mae: 0.2587
# Epoch 29/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0812 - mae: 0.2140 - val_loss: 0.0763 - val_mae: 0.2031
# Epoch 30/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0821 - mae: 0.2160 - val_loss: 0.0605 - val_mae: 0.1891
# Epoch 31/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0753 - mae: 0.2084 - val_loss: 0.0704 - val_mae: 0.2013
# Epoch 32/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0603 - mae: 0.1834 - val_loss: 0.0727 - val_mae: 0.1995
# Epoch 33/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0582 - mae: 0.1818 - val_loss: 0.0475 - val_mae: 0.1560
# Epoch 34/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0504 - mae: 0.1640 - val_loss: 0.0615 - val_mae: 0.1896
# Epoch 35/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0449 - mae: 0.1581 - val_loss: 0.0470 - val_mae: 0.1577
# Epoch 36/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0474 - mae: 0.1566 - val_loss: 0.0473 - val_mae: 0.1705
# Epoch 37/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0377 - mae: 0.1382 - val_loss: 0.0310 - val_mae: 0.1397
# Epoch 38/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0447 - mae: 0.1546 - val_loss: 0.0486 - val_mae: 0.1646
# Epoch 39/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0809 - mae: 0.2197 - val_loss: 0.0483 - val_mae: 0.1760
# Epoch 40/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0456 - mae: 0.1581 - val_loss: 0.1624 - val_mae: 0.2824
# Epoch 41/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0499 - mae: 0.1667 - val_loss: 0.0355 - val_mae: 0.1462
# Epoch 42/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0336 - mae: 0.1359 - val_loss: 0.0309 - val_mae: 0.1413
# Epoch 43/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0289 - mae: 0.1238 - val_loss: 0.0344 - val_mae: 0.1481
# Epoch 44/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0316 - mae: 0.1291 - val_loss: 0.0353 - val_mae: 0.1448
# Epoch 45/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0296 - mae: 0.1273 - val_loss: 0.0244 - val_mae: 0.1218
# Epoch 46/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0275 - mae: 0.1210 - val_loss: 0.0395 - val_mae: 0.1581
# Epoch 47/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0422 - mae: 0.1543 - val_loss: 0.0229 - val_mae: 0.1173
# Epoch 48/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0228 - mae: 0.1080 - val_loss: 0.0455 - val_mae: 0.1682
# Epoch 49/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0220 - mae: 0.1074 - val_loss: 0.0347 - val_mae: 0.1455
# Epoch 50/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0197 - mae: 0.1034 - val_loss: 0.0170 - val_mae: 0.1001
# Epoch 51/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0133 - mae: 0.0838 - val_loss: 0.0133 - val_mae: 0.0887
# Epoch 52/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0177 - mae: 0.0976 - val_loss: 0.0784 - val_mae: 0.2000
# Epoch 53/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0871 - mae: 0.2283 - val_loss: 0.0771 - val_mae: 0.2213
# Epoch 54/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0526 - mae: 0.1757 - val_loss: 0.0573 - val_mae: 0.1827
# Epoch 55/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0276 - mae: 0.1273 - val_loss: 0.0214 - val_mae: 0.1126
# Epoch 56/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0232 - mae: 0.1107 - val_loss: 0.0237 - val_mae: 0.1254
# Epoch 57/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0125 - mae: 0.0839 - val_loss: 0.0096 - val_mae: 0.0747
# Epoch 58/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0090 - mae: 0.0694 - val_loss: 0.0307 - val_mae: 0.1307
# Epoch 59/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0128 - mae: 0.0808 - val_loss: 0.0132 - val_mae: 0.0859
# Epoch 60/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0138 - mae: 0.0856 - val_loss: 0.0131 - val_mae: 0.0854
# Epoch 61/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0091 - mae: 0.0722 - val_loss: 0.0160 - val_mae: 0.0966
# Epoch 62/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0080 - mae: 0.0659 - val_loss: 0.0090 - val_mae: 0.0731
# Epoch 63/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0060 - mae: 0.0574 - val_loss: 0.0114 - val_mae: 0.0818
# Epoch 64/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0060 - mae: 0.0579 - val_loss: 0.0070 - val_mae: 0.0553
# Epoch 65/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0049 - mae: 0.0505 - val_loss: 0.0087 - val_mae: 0.0693
# Epoch 66/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0040 - mae: 0.0463 - val_loss: 0.0066 - val_mae: 0.0575
# Epoch 67/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0043 - mae: 0.0474 - val_loss: 0.0061 - val_mae: 0.0566
# Epoch 68/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0044 - mae: 0.0497 - val_loss: 0.0091 - val_mae: 0.0685
# Epoch 69/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0081 - mae: 0.0659 - val_loss: 0.0090 - val_mae: 0.0737
# Epoch 70/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0139 - mae: 0.0826 - val_loss: 0.0229 - val_mae: 0.1158
# Epoch 71/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0107 - mae: 0.0772 - val_loss: 0.0115 - val_mae: 0.0782
# Epoch 72/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0074 - mae: 0.0625 - val_loss: 0.0068 - val_mae: 0.0585
# Epoch 73/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0056 - mae: 0.0524 - val_loss: 0.0214 - val_mae: 0.1117
# Epoch 74/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0121 - mae: 0.0800 - val_loss: 0.0142 - val_mae: 0.0897
# Epoch 75/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0066 - mae: 0.0601 - val_loss: 0.0417 - val_mae: 0.1248
# Epoch 76/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0100 - mae: 0.0765 - val_loss: 0.0138 - val_mae: 0.0910
# Epoch 77/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0113 - mae: 0.0802 - val_loss: 0.0118 - val_mae: 0.0822
# Epoch 78/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0124 - mae: 0.0791 - val_loss: 0.0104 - val_mae: 0.0761
# Epoch 79/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0065 - mae: 0.0586 - val_loss: 0.0097 - val_mae: 0.0716
# Epoch 80/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0392 - mae: 0.1480 - val_loss: 0.0575 - val_mae: 0.1709
# Epoch 81/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0216 - mae: 0.1084 - val_loss: 0.0196 - val_mae: 0.1056
# Epoch 82/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0629 - mae: 0.1798 - val_loss: 0.0266 - val_mae: 0.1326
# Epoch 83/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0370 - mae: 0.1439 - val_loss: 0.1488 - val_mae: 0.2685
# Epoch 84/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0306 - mae: 0.1354 - val_loss: 0.0311 - val_mae: 0.1346
# Epoch 85/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0190 - mae: 0.1001 - val_loss: 0.0150 - val_mae: 0.0936
# Epoch 86/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0118 - mae: 0.0780 - val_loss: 0.0422 - val_mae: 0.1660
# Epoch 87/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0758 - mae: 0.2071 - val_loss: 0.0781 - val_mae: 0.2032
# Epoch 88/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0304 - mae: 0.1327 - val_loss: 0.0199 - val_mae: 0.1129
# Epoch 89/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0156 - mae: 0.0971 - val_loss: 0.0157 - val_mae: 0.0988
# Epoch 90/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0101 - mae: 0.0780 - val_loss: 0.0160 - val_mae: 0.0982
# Epoch 91/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0092 - mae: 0.0693 - val_loss: 0.0211 - val_mae: 0.1147
# Epoch 92/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0063 - mae: 0.0598 - val_loss: 0.0118 - val_mae: 0.0792
# Epoch 93/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0033 - mae: 0.0433 - val_loss: 0.0057 - val_mae: 0.0519
# Epoch 94/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0031 - mae: 0.0427 - val_loss: 0.0047 - val_mae: 0.0482
# Epoch 95/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0026 - mae: 0.0381 - val_loss: 0.0202 - val_mae: 0.1071
# Epoch 96/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0026 - mae: 0.0379 - val_loss: 0.0064 - val_mae: 0.0604
# Epoch 97/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0022 - mae: 0.0351 - val_loss: 0.0062 - val_mae: 0.0520
# Epoch 98/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0014 - mae: 0.0280 - val_loss: 0.0039 - val_mae: 0.0405
# Epoch 99/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0013 - mae: 0.0258 - val_loss: 0.0072 - val_mae: 0.0598
# Epoch 100/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0014 - mae: 0.0274 - val_loss: 0.0043 - val_mae: 0.0402
# Epoch 101/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0017 - mae: 0.0317 - val_loss: 0.0043 - val_mae: 0.0469
# Epoch 102/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0015 - mae: 0.0285 - val_loss: 0.0055 - val_mae: 0.0528
# Epoch 103/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0017 - mae: 0.0315 - val_loss: 0.0048 - val_mae: 0.0464
# Epoch 104/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0025 - mae: 0.0380 - val_loss: 0.0043 - val_mae: 0.0468
# Epoch 105/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0019 - mae: 0.0334 - val_loss: 0.0085 - val_mae: 0.0661
# Epoch 106/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0040 - mae: 0.0461 - val_loss: 0.0074 - val_mae: 0.0630
# Epoch 107/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0036 - mae: 0.0456 - val_loss: 0.0115 - val_mae: 0.0817
# Epoch 108/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0106 - mae: 0.0773 - val_loss: 0.0081 - val_mae: 0.0669
# Epoch 109/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0054 - mae: 0.0544 - val_loss: 0.0739 - val_mae: 0.1905
# Epoch 110/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0154 - mae: 0.0906 - val_loss: 0.0229 - val_mae: 0.1138
# Epoch 111/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0184 - mae: 0.1023 - val_loss: 0.0179 - val_mae: 0.1020
# Epoch 112/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0137 - mae: 0.0898 - val_loss: 0.0128 - val_mae: 0.0806
# Epoch 113/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0079 - mae: 0.0671 - val_loss: 0.0060 - val_mae: 0.0565
# Epoch 114/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0033 - mae: 0.0435 - val_loss: 0.0053 - val_mae: 0.0524
# Epoch 115/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0018 - mae: 0.0318 - val_loss: 0.0069 - val_mae: 0.0572
# Epoch 116/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0016 - mae: 0.0299 - val_loss: 0.0045 - val_mae: 0.0446
# Epoch 117/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0017 - mae: 0.0304 - val_loss: 0.0036 - val_mae: 0.0428
# Epoch 118/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0020 - mae: 0.0343 - val_loss: 0.0047 - val_mae: 0.0462
# Epoch 119/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0023 - mae: 0.0353 - val_loss: 0.0043 - val_mae: 0.0386
# Epoch 120/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0017 - mae: 0.0306 - val_loss: 0.0044 - val_mae: 0.0398
# Epoch 121/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0017 - mae: 0.0308 - val_loss: 0.0063 - val_mae: 0.0615
# Epoch 122/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0015 - mae: 0.0276 - val_loss: 0.0056 - val_mae: 0.0576
# Epoch 123/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0034 - mae: 0.0421 - val_loss: 0.0061 - val_mae: 0.0585
# Epoch 124/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0041 - mae: 0.0488 - val_loss: 0.0056 - val_mae: 0.0483
# Epoch 125/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0028 - mae: 0.0355 - val_loss: 0.0045 - val_mae: 0.0449
# Epoch 126/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0025 - mae: 0.0368 - val_loss: 0.0074 - val_mae: 0.0558
# Epoch 127/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0023 - mae: 0.0360 - val_loss: 0.0044 - val_mae: 0.0421
# Epoch 128/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0014 - mae: 0.0282 - val_loss: 0.0045 - val_mae: 0.0440
# Epoch 129/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0011 - mae: 0.0256 - val_loss: 0.0062 - val_mae: 0.0559
# Epoch 130/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0014 - mae: 0.0283 - val_loss: 0.0046 - val_mae: 0.0423
# Epoch 131/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0022 - mae: 0.0335 - val_loss: 0.0051 - val_mae: 0.0516
# Epoch 132/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0031 - mae: 0.0426 - val_loss: 0.0063 - val_mae: 0.0582
# Epoch 133/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0022 - mae: 0.0360 - val_loss: 0.0079 - val_mae: 0.0694
# Epoch 134/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0022 - mae: 0.0349 - val_loss: 0.0056 - val_mae: 0.0548
# Epoch 135/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 8.8116e-04 - mae: 0.0228 - val_loss: 0.0036 - val_mae: 0.0389
# Epoch 136/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0013 - mae: 0.0256 - val_loss: 0.0040 - val_mae: 0.0436
# Epoch 137/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0400 - val_loss: 0.0056 - val_mae: 0.0535
# Epoch 138/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0031 - mae: 0.0429 - val_loss: 0.0092 - val_mae: 0.0686
# Epoch 139/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0060 - mae: 0.0439 - val_loss: 0.3438 - val_mae: 0.4262
# Epoch 140/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.5250 - mae: 0.5653 - val_loss: 0.3651 - val_mae: 0.4872
# Epoch 141/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.2353 - mae: 0.3819 - val_loss: 0.1729 - val_mae: 0.3230
# Epoch 142/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.2250 - mae: 0.3758 - val_loss: 0.1724 - val_mae: 0.3286
# Epoch 143/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.1398 - mae: 0.2886 - val_loss: 0.1011 - val_mae: 0.2387
# Epoch 144/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.1177 - mae: 0.2648 - val_loss: 0.1184 - val_mae: 0.2746
# Epoch 145/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.1127 - mae: 0.2613 - val_loss: 0.1026 - val_mae: 0.2483
# Epoch 146/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0939 - mae: 0.2359 - val_loss: 0.0884 - val_mae: 0.2257
# Epoch 147/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0875 - mae: 0.2283 - val_loss: 0.0940 - val_mae: 0.2333
# Epoch 148/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0931 - mae: 0.2340 - val_loss: 0.0759 - val_mae: 0.2086
# Epoch 149/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0712 - mae: 0.2042 - val_loss: 0.0623 - val_mae: 0.1907
# Epoch 150/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0585 - mae: 0.1779 - val_loss: 0.2074 - val_mae: 0.3369
# Epoch 151/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0658 - mae: 0.1975 - val_loss: 0.1390 - val_mae: 0.2648
# Epoch 152/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0608 - mae: 0.1822 - val_loss: 0.0606 - val_mae: 0.1848
# Epoch 153/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0549 - mae: 0.1762 - val_loss: 0.0518 - val_mae: 0.1617
# Epoch 154/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0445 - mae: 0.1569 - val_loss: 0.0597 - val_mae: 0.1943
# Epoch 155/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0375 - mae: 0.1460 - val_loss: 0.0288 - val_mae: 0.1286
# Epoch 156/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0421 - mae: 0.1515 - val_loss: 0.0485 - val_mae: 0.1702
# Epoch 157/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0406 - mae: 0.1445 - val_loss: 0.0349 - val_mae: 0.1445
# Epoch 158/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0213 - mae: 0.1093 - val_loss: 0.0505 - val_mae: 0.1747
# Epoch 159/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0259 - mae: 0.1185 - val_loss: 0.0280 - val_mae: 0.1299
# Epoch 160/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0229 - mae: 0.1134 - val_loss: 0.0337 - val_mae: 0.1413
# Epoch 161/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0185 - mae: 0.1043 - val_loss: 0.0189 - val_mae: 0.1052
# Epoch 162/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0109 - mae: 0.0790 - val_loss: 0.0270 - val_mae: 0.1320
# Epoch 163/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0802 - val_loss: 0.0111 - val_mae: 0.0820
# Epoch 164/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0138 - mae: 0.0878 - val_loss: 0.0194 - val_mae: 0.1038
# Epoch 165/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0183 - mae: 0.1031 - val_loss: 0.0167 - val_mae: 0.0985
# Epoch 166/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0117 - mae: 0.0811 - val_loss: 0.0217 - val_mae: 0.1103
# Epoch 167/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0111 - mae: 0.0761 - val_loss: 0.0644 - val_mae: 0.1988
# Epoch 168/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0311 - mae: 0.1280 - val_loss: 0.0358 - val_mae: 0.1488
# Epoch 169/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0110 - mae: 0.0788 - val_loss: 0.0168 - val_mae: 0.1006
# Epoch 170/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0125 - mae: 0.0835 - val_loss: 0.0207 - val_mae: 0.1139
# Epoch 171/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0082 - mae: 0.0648 - val_loss: 0.0077 - val_mae: 0.0687
# Epoch 172/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0064 - mae: 0.0590 - val_loss: 0.0058 - val_mae: 0.0583
# Epoch 173/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0054 - mae: 0.0525 - val_loss: 0.0174 - val_mae: 0.1001
# Epoch 174/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0073 - mae: 0.0637 - val_loss: 0.0075 - val_mae: 0.0681
# Epoch 175/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0040 - mae: 0.0475 - val_loss: 0.0070 - val_mae: 0.0598
# Epoch 176/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0042 - mae: 0.0474 - val_loss: 0.0053 - val_mae: 0.0565
# Epoch 177/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0032 - mae: 0.0427 - val_loss: 0.0041 - val_mae: 0.0494
# Epoch 178/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0031 - mae: 0.0427 - val_loss: 0.0076 - val_mae: 0.0667
# Epoch 179/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0022 - mae: 0.0359 - val_loss: 0.0049 - val_mae: 0.0536
# Epoch 180/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0022 - mae: 0.0360 - val_loss: 0.0044 - val_mae: 0.0510
# Epoch 181/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0022 - mae: 0.0361 - val_loss: 0.0041 - val_mae: 0.0483
# Epoch 182/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0396 - val_loss: 0.0050 - val_mae: 0.0542
# Epoch 183/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0042 - mae: 0.0472 - val_loss: 0.0084 - val_mae: 0.0682
# Epoch 184/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0030 - mae: 0.0392 - val_loss: 0.0172 - val_mae: 0.0942
# Epoch 185/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0030 - mae: 0.0397 - val_loss: 0.0130 - val_mae: 0.0888
# Epoch 186/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0018 - mae: 0.0299 - val_loss: 0.0196 - val_mae: 0.0767
# Epoch 187/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0078 - mae: 0.0632 - val_loss: 0.0041 - val_mae: 0.0507
# Epoch 188/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0038 - mae: 0.0469 - val_loss: 0.0104 - val_mae: 0.0777
# Epoch 189/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0024 - mae: 0.0368 - val_loss: 0.0024 - val_mae: 0.0353
# Epoch 190/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0017 - mae: 0.0303 - val_loss: 0.0019 - val_mae: 0.0308
# Epoch 191/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0016 - mae: 0.0291 - val_loss: 0.0063 - val_mae: 0.0553
# Epoch 192/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0012 - mae: 0.0257 - val_loss: 0.0023 - val_mae: 0.0325
# Epoch 193/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0017 - mae: 0.0284 - val_loss: 0.0095 - val_mae: 0.0762
# Epoch 194/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0048 - mae: 0.0493 - val_loss: 0.0074 - val_mae: 0.0665
# Epoch 195/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0030 - mae: 0.0399 - val_loss: 0.0034 - val_mae: 0.0451
# Epoch 196/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0022 - mae: 0.0355 - val_loss: 0.0022 - val_mae: 0.0352
# Epoch 197/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0020 - mae: 0.0308 - val_loss: 0.0131 - val_mae: 0.0909
# Epoch 198/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0415 - mae: 0.1460 - val_loss: 0.0306 - val_mae: 0.1417
# Epoch 199/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0179 - mae: 0.1037 - val_loss: 0.0118 - val_mae: 0.0896
# Epoch 200/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0101 - mae: 0.0717 - val_loss: 0.0219 - val_mae: 0.1193
# Epoch 201/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0046 - mae: 0.0505 - val_loss: 0.0036 - val_mae: 0.0450
# Epoch 202/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0046 - mae: 0.0492 - val_loss: 0.0075 - val_mae: 0.0662
# Epoch 203/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0033 - mae: 0.0428 - val_loss: 0.0084 - val_mae: 0.0686
# Epoch 204/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0022 - mae: 0.0344 - val_loss: 0.0025 - val_mae: 0.0345
# Epoch 205/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0014 - mae: 0.0282 - val_loss: 0.0063 - val_mae: 0.0592
# Epoch 206/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0022 - mae: 0.0342 - val_loss: 0.0085 - val_mae: 0.0635
# Epoch 207/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0024 - mae: 0.0352 - val_loss: 0.0155 - val_mae: 0.0931
# Epoch 208/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0023 - mae: 0.0355 - val_loss: 0.0076 - val_mae: 0.0673
# Epoch 209/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0398 - val_loss: 0.1267 - val_mae: 0.1971
# Epoch 210/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0034 - mae: 0.0428 - val_loss: 0.0078 - val_mae: 0.0703
# Epoch 211/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0045 - mae: 0.0490 - val_loss: 0.0031 - val_mae: 0.0424
# Epoch 212/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0025 - mae: 0.0369 - val_loss: 0.0026 - val_mae: 0.0365
# Epoch 213/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0021 - mae: 0.0336 - val_loss: 0.0033 - val_mae: 0.0426
# Epoch 214/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0015 - mae: 0.0294 - val_loss: 0.0034 - val_mae: 0.0425
# Epoch 215/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0015 - mae: 0.0276 - val_loss: 0.0031 - val_mae: 0.0415
# Epoch 216/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0020 - mae: 0.0329 - val_loss: 0.0043 - val_mae: 0.0476
# Epoch 217/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0023 - mae: 0.0341 - val_loss: 0.0036 - val_mae: 0.0438
# Epoch 218/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0012 - mae: 0.0255 - val_loss: 0.0027 - val_mae: 0.0388
# Epoch 219/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0016 - mae: 0.0268 - val_loss: 0.1107 - val_mae: 0.1703
# Epoch 220/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0034 - mae: 0.0433 - val_loss: 0.0025 - val_mae: 0.0378
# Epoch 221/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0014 - mae: 0.0292 - val_loss: 0.0022 - val_mae: 0.0332
# Epoch 222/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0011 - mae: 0.0256 - val_loss: 0.0022 - val_mae: 0.0316
# Epoch 223/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 6.0929e-04 - mae: 0.0187 - val_loss: 0.0017 - val_mae: 0.0267
# Epoch 224/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0012 - mae: 0.0258 - val_loss: 0.0025 - val_mae: 0.0299
# Epoch 225/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0010 - mae: 0.0231 - val_loss: 0.0024 - val_mae: 0.0349
# Epoch 226/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 9.0194e-04 - mae: 0.0221 - val_loss: 0.0034 - val_mae: 0.0433
# Epoch 227/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 8.4353e-04 - mae: 0.0211 - val_loss: 0.0018 - val_mae: 0.0288
# Epoch 228/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0042 - mae: 0.0425 - val_loss: 0.0041 - val_mae: 0.0475
# Epoch 229/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0021 - mae: 0.0330 - val_loss: 0.0026 - val_mae: 0.0360
# Epoch 230/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0013 - mae: 0.0265 - val_loss: 0.0040 - val_mae: 0.0483
# Epoch 231/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0039 - mae: 0.0431 - val_loss: 0.0097 - val_mae: 0.0708
# Epoch 232/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0044 - mae: 0.0495 - val_loss: 0.0051 - val_mae: 0.0561
# Epoch 233/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0025 - mae: 0.0375 - val_loss: 0.0107 - val_mae: 0.0808
# Epoch 234/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0047 - mae: 0.0483 - val_loss: 0.0048 - val_mae: 0.0464
# Epoch 235/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0055 - mae: 0.0514 - val_loss: 0.0041 - val_mae: 0.0472
# Epoch 236/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0029 - mae: 0.0391 - val_loss: 0.0037 - val_mae: 0.0410
# Epoch 237/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0026 - mae: 0.0359 - val_loss: 0.0029 - val_mae: 0.0406
# Epoch 238/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0020 - mae: 0.0328 - val_loss: 0.0649 - val_mae: 0.1265
# Epoch 239/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0045 - mae: 0.0498 - val_loss: 0.0085 - val_mae: 0.0707
# Epoch 240/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0073 - mae: 0.0537 - val_loss: 0.0058 - val_mae: 0.0564
# Epoch 241/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0042 - mae: 0.0473 - val_loss: 0.0054 - val_mae: 0.0551
# Epoch 242/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0023 - mae: 0.0357 - val_loss: 0.0024 - val_mae: 0.0336
# Epoch 243/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0014 - mae: 0.0283 - val_loss: 0.0031 - val_mae: 0.0380
# Epoch 244/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0017 - mae: 0.0286 - val_loss: 0.0034 - val_mae: 0.0371
# Epoch 245/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0015 - mae: 0.0286 - val_loss: 0.0085 - val_mae: 0.0682
# Epoch 246/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0023 - mae: 0.0336 - val_loss: 0.0036 - val_mae: 0.0398
# Epoch 247/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0099 - mae: 0.0667 - val_loss: 0.0254 - val_mae: 0.1144
# Epoch 248/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0225 - mae: 0.0999 - val_loss: 0.0265 - val_mae: 0.1203
# Epoch 249/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0261 - mae: 0.1142 - val_loss: 0.0289 - val_mae: 0.1374
# Epoch 250/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0755 - mae: 0.1813 - val_loss: 0.0711 - val_mae: 0.2060
# Epoch 251/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0644 - mae: 0.1833 - val_loss: 0.0534 - val_mae: 0.1714
# Epoch 252/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0421 - mae: 0.1504 - val_loss: 0.0406 - val_mae: 0.1585
# Epoch 253/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0164 - mae: 0.0955 - val_loss: 0.0155 - val_mae: 0.0929
# Epoch 254/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0056 - mae: 0.0568 - val_loss: 0.0055 - val_mae: 0.0548
# Epoch 255/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0042 - mae: 0.0458 - val_loss: 0.0118 - val_mae: 0.0794
# Epoch 256/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0387 - mae: 0.1365 - val_loss: 0.0440 - val_mae: 0.1585
# Epoch 257/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0111 - mae: 0.0786 - val_loss: 0.0118 - val_mae: 0.0816
# Epoch 258/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0047 - mae: 0.0517 - val_loss: 0.0045 - val_mae: 0.0514
# Epoch 259/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0024 - mae: 0.0366 - val_loss: 0.0088 - val_mae: 0.0672
# Epoch 260/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0019 - mae: 0.0313 - val_loss: 0.0083 - val_mae: 0.0594
# Epoch 261/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0018 - mae: 0.0305 - val_loss: 0.0126 - val_mae: 0.0888
# Epoch 262/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0017 - mae: 0.0305 - val_loss: 0.0027 - val_mae: 0.0394
# Epoch 263/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0013 - mae: 0.0272 - val_loss: 0.0020 - val_mae: 0.0322
# Epoch 264/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0011 - mae: 0.0243 - val_loss: 0.0033 - val_mae: 0.0412
# Epoch 265/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 9.0789e-04 - mae: 0.0217 - val_loss: 0.0074 - val_mae: 0.0585
# Epoch 266/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 6.3308e-04 - mae: 0.0187 - val_loss: 0.0192 - val_mae: 0.0772
# Epoch 267/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 5.5988e-04 - mae: 0.0174 - val_loss: 0.0026 - val_mae: 0.0342
# Epoch 268/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 5.5605e-04 - mae: 0.0175 - val_loss: 0.0029 - val_mae: 0.0345
# Epoch 269/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 6.4696e-04 - mae: 0.0185 - val_loss: 0.0024 - val_mae: 0.0305
# Epoch 270/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 6.4828e-04 - mae: 0.0185 - val_loss: 0.0015 - val_mae: 0.0242
# Epoch 271/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 6.1736e-04 - mae: 0.0188 - val_loss: 0.0020 - val_mae: 0.0273
# Epoch 272/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 5.1155e-04 - mae: 0.0165 - val_loss: 0.0017 - val_mae: 0.0236
# Epoch 273/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 5.6294e-04 - mae: 0.0146 - val_loss: 0.0146 - val_mae: 0.0815
# Epoch 274/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0017 - mae: 0.0292 - val_loss: 0.0034 - val_mae: 0.0439
# Epoch 275/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0013 - mae: 0.0263 - val_loss: 0.0456 - val_mae: 0.1204
# Epoch 276/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 8.9024e-04 - mae: 0.0223 - val_loss: 0.0073 - val_mae: 0.0563
# Epoch 277/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 6.1671e-04 - mae: 0.0182 - val_loss: 0.0016 - val_mae: 0.0259
# Epoch 278/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0014 - mae: 0.0250 - val_loss: 0.0016 - val_mae: 0.0244
# Epoch 279/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 7.0866e-04 - mae: 0.0188 - val_loss: 0.0053 - val_mae: 0.0483
# Epoch 280/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0010 - mae: 0.0241 - val_loss: 0.0020 - val_mae: 0.0318
# Epoch 281/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 7.1144e-04 - mae: 0.0199 - val_loss: 0.0058 - val_mae: 0.0541
# Epoch 282/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 6.8273e-04 - mae: 0.0190 - val_loss: 0.0022 - val_mae: 0.0363
# Epoch 283/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 7.7728e-04 - mae: 0.0191 - val_loss: 0.0022 - val_mae: 0.0296
# Epoch 284/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 5.7214e-04 - mae: 0.0178 - val_loss: 0.0021 - val_mae: 0.0274
# Epoch 285/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 4.8025e-04 - mae: 0.0161 - val_loss: 0.0028 - val_mae: 0.0341
# Epoch 286/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 4.6432e-04 - mae: 0.0161 - val_loss: 0.0014 - val_mae: 0.0241
# Epoch 287/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 4.3596e-04 - mae: 0.0154 - val_loss: 0.0016 - val_mae: 0.0221
# Epoch 288/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 3.4844e-04 - mae: 0.0141 - val_loss: 0.0016 - val_mae: 0.0265
# Epoch 289/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 6.0078e-04 - mae: 0.0176 - val_loss: 0.0018 - val_mae: 0.0242
# Epoch 290/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 4.0998e-04 - mae: 0.0150 - val_loss: 0.0023 - val_mae: 0.0320
# Epoch 291/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 4.4721e-04 - mae: 0.0157 - val_loss: 0.0046 - val_mae: 0.0403
# Epoch 292/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 6.4430e-04 - mae: 0.0183 - val_loss: 0.0021 - val_mae: 0.0288
# Epoch 293/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 5.6715e-04 - mae: 0.0178 - val_loss: 0.0018 - val_mae: 0.0254
# Epoch 294/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 8.7616e-04 - mae: 0.0216 - val_loss: 0.0022 - val_mae: 0.0319
# Epoch 295/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 6.3806e-04 - mae: 0.0179 - val_loss: 0.0024 - val_mae: 0.0301
# Epoch 296/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 5.5480e-04 - mae: 0.0174 - val_loss: 0.0016 - val_mae: 0.0280
# Epoch 297/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 7.5000e-04 - mae: 0.0190 - val_loss: 0.0045 - val_mae: 0.0456
# Epoch 298/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 9.2659e-04 - mae: 0.0219 - val_loss: 0.0019 - val_mae: 0.0250
# Epoch 299/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 7.6089e-04 - mae: 0.0205 - val_loss: 0.0024 - val_mae: 0.0332
# Epoch 300/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 9.9279e-04 - mae: 0.0223 - val_loss: 0.0018 - val_mae: 0.0243
# Epoch 301/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 6.4078e-04 - mae: 0.0183 - val_loss: 0.0019 - val_mae: 0.0263
# Epoch 302/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 9.6072e-04 - mae: 0.0224 - val_loss: 0.0038 - val_mae: 0.0426
# Epoch 303/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0010 - mae: 0.0231 - val_loss: 0.0036 - val_mae: 0.0388
# Epoch 304/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0014 - mae: 0.0264 - val_loss: 0.0704 - val_mae: 0.1801
# Epoch 305/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0208 - mae: 0.0896 - val_loss: 0.0536 - val_mae: 0.1865
# Epoch 306/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0596 - mae: 0.1667 - val_loss: 0.0696 - val_mae: 0.2026
# Epoch 307/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0726 - mae: 0.1981 - val_loss: 0.0574 - val_mae: 0.1631
# Epoch 308/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0415 - mae: 0.1448 - val_loss: 0.0237 - val_mae: 0.1126
# Epoch 309/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0226 - mae: 0.1127 - val_loss: 0.0121 - val_mae: 0.0873
# Epoch 310/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0140 - mae: 0.0850 - val_loss: 0.0078 - val_mae: 0.0661
# Epoch 311/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0049 - mae: 0.0521 - val_loss: 0.0054 - val_mae: 0.0602
# Epoch 312/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0044 - mae: 0.0461 - val_loss: 0.0031 - val_mae: 0.0396
# Epoch 313/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0014 - mae: 0.0285 - val_loss: 0.0021 - val_mae: 0.0295
# Epoch 314/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0016 - mae: 0.0285 - val_loss: 0.0051 - val_mae: 0.0450
# Epoch 315/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0017 - mae: 0.0285 - val_loss: 0.0028 - val_mae: 0.0376
# Epoch 316/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 8.0442e-04 - mae: 0.0207 - val_loss: 0.0031 - val_mae: 0.0410
# Epoch 317/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 7.3314e-04 - mae: 0.0197 - val_loss: 0.0036 - val_mae: 0.0441
# Epoch 318/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 6.9812e-04 - mae: 0.0201 - val_loss: 0.0024 - val_mae: 0.0333
# Epoch 319/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 7.6986e-04 - mae: 0.0199 - val_loss: 0.0014 - val_mae: 0.0285
# Epoch 320/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 9.7987e-04 - mae: 0.0224 - val_loss: 0.0027 - val_mae: 0.0345
# Epoch 321/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0010 - mae: 0.0235 - val_loss: 0.0113 - val_mae: 0.0668
# Epoch 322/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 7.2687e-04 - mae: 0.0188 - val_loss: 0.0016 - val_mae: 0.0248
# Epoch 323/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 5.7503e-04 - mae: 0.0174 - val_loss: 0.0096 - val_mae: 0.0678
# Epoch 324/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 6.8249e-04 - mae: 0.0190 - val_loss: 0.0096 - val_mae: 0.0577
# Epoch 325/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0011 - mae: 0.0227 - val_loss: 0.0085 - val_mae: 0.0699
# Epoch 326/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0344 - val_loss: 0.0044 - val_mae: 0.0484
# Epoch 327/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0013 - mae: 0.0259 - val_loss: 0.0019 - val_mae: 0.0305
# Epoch 328/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 5.6264e-04 - mae: 0.0182 - val_loss: 0.0028 - val_mae: 0.0358
# Epoch 329/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 5.1441e-04 - mae: 0.0164 - val_loss: 0.0047 - val_mae: 0.0423
# Epoch 330/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 3.8394e-04 - mae: 0.0138 - val_loss: 0.0110 - val_mae: 0.0697
# Epoch 331/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0021 - mae: 0.0274 - val_loss: 0.0020 - val_mae: 0.0289
# Epoch 332/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 7.2974e-04 - mae: 0.0185 - val_loss: 0.0024 - val_mae: 0.0306
# Epoch 333/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 3.2922e-04 - mae: 0.0137 - val_loss: 0.0017 - val_mae: 0.0228
# Epoch 334/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 5.7280e-04 - mae: 0.0175 - val_loss: 0.0013 - val_mae: 0.0237
# Epoch 335/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 2.9216e-04 - mae: 0.0129 - val_loss: 0.0018 - val_mae: 0.0211
# Epoch 336/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 3.3594e-04 - mae: 0.0134 - val_loss: 0.0011 - val_mae: 0.0175
# Epoch 337/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 4.8623e-04 - mae: 0.0157 - val_loss: 0.0062 - val_mae: 0.0478
# Epoch 338/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 4.2023e-04 - mae: 0.0147 - val_loss: 0.0020 - val_mae: 0.0249
# Epoch 339/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 5.7338e-04 - mae: 0.0165 - val_loss: 0.0020 - val_mae: 0.0326
# Epoch 340/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0032 - mae: 0.0170 - val_loss: 0.0251 - val_mae: 0.1099
# Epoch 341/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.3200 - mae: 0.4124 - val_loss: 0.1997 - val_mae: 0.3459
# Epoch 342/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.1327 - mae: 0.2789 - val_loss: 0.1110 - val_mae: 0.2624
# Epoch 343/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0691 - mae: 0.1993 - val_loss: 0.0546 - val_mae: 0.1799
# Epoch 344/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0494 - mae: 0.1635 - val_loss: 0.0424 - val_mae: 0.1636
# Epoch 345/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0345 - mae: 0.1416 - val_loss: 0.0429 - val_mae: 0.1578
# Epoch 346/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0302 - mae: 0.1283 - val_loss: 0.0204 - val_mae: 0.1141
# Epoch 347/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0125 - mae: 0.0841 - val_loss: 0.0743 - val_mae: 0.1985
# Epoch 348/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0112 - mae: 0.0809 - val_loss: 0.0104 - val_mae: 0.0800
# Epoch 349/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0096 - mae: 0.0739 - val_loss: 0.0230 - val_mae: 0.1221
# Epoch 350/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0095 - mae: 0.0743 - val_loss: 0.0262 - val_mae: 0.1162
# Epoch 351/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0045 - mae: 0.0507 - val_loss: 0.0177 - val_mae: 0.0954
# Epoch 352/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0045 - mae: 0.0497 - val_loss: 0.0062 - val_mae: 0.0573
# Epoch 353/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0024 - mae: 0.0363 - val_loss: 0.0037 - val_mae: 0.0438
# Epoch 354/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0020 - mae: 0.0328 - val_loss: 0.0051 - val_mae: 0.0531
# Epoch 355/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0016 - mae: 0.0290 - val_loss: 0.0023 - val_mae: 0.0346
# Epoch 356/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0014 - mae: 0.0272 - val_loss: 0.0032 - val_mae: 0.0388
# Epoch 357/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0016 - mae: 0.0295 - val_loss: 0.0042 - val_mae: 0.0425
# Epoch 358/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0017 - mae: 0.0286 - val_loss: 0.0027 - val_mae: 0.0348
# Epoch 359/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0010 - mae: 0.0236 - val_loss: 0.0035 - val_mae: 0.0392
# Epoch 360/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 9.7635e-04 - mae: 0.0225 - val_loss: 0.0068 - val_mae: 0.0518
# Epoch 361/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0015 - mae: 0.0264 - val_loss: 0.0052 - val_mae: 0.0554
# Epoch 362/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0013 - mae: 0.0257 - val_loss: 0.1024 - val_mae: 0.2088
# Epoch 363/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0012 - mae: 0.0251 - val_loss: 0.0021 - val_mae: 0.0336
# Epoch 364/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0016 - mae: 0.0284 - val_loss: 0.0030 - val_mae: 0.0369
# Epoch 365/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0012 - mae: 0.0259 - val_loss: 0.0022 - val_mae: 0.0317
# Epoch 366/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0011 - mae: 0.0245 - val_loss: 0.0048 - val_mae: 0.0513
# Epoch 367/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0014 - mae: 0.0273 - val_loss: 0.0019 - val_mae: 0.0290
# Epoch 368/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0013 - mae: 0.0254 - val_loss: 0.0019 - val_mae: 0.0300
# Epoch 369/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0013 - mae: 0.0253 - val_loss: 0.0029 - val_mae: 0.0369
# Epoch 370/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0010 - mae: 0.0223 - val_loss: 0.0067 - val_mae: 0.0544
# Epoch 371/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 8.6948e-04 - mae: 0.0209 - val_loss: 0.0020 - val_mae: 0.0277
# Epoch 372/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 6.5537e-04 - mae: 0.0187 - val_loss: 0.0022 - val_mae: 0.0287
# Epoch 373/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 6.6221e-04 - mae: 0.0186 - val_loss: 0.0024 - val_mae: 0.0342
# Epoch 374/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 6.4118e-04 - mae: 0.0182 - val_loss: 0.0114 - val_mae: 0.0714
# Epoch 375/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 7.6165e-04 - mae: 0.0193 - val_loss: 0.0028 - val_mae: 0.0343
# Epoch 376/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0010 - mae: 0.0213 - val_loss: 0.0026 - val_mae: 0.0336
# Epoch 377/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 8.0218e-04 - mae: 0.0200 - val_loss: 0.0037 - val_mae: 0.0443
# Epoch 378/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0021 - mae: 0.0324 - val_loss: 0.0030 - val_mae: 0.0365
# Epoch 379/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0012 - mae: 0.0248 - val_loss: 0.0034 - val_mae: 0.0389
# Epoch 380/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0011 - mae: 0.0240 - val_loss: 0.0023 - val_mae: 0.0344
# Epoch 381/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 7.6032e-04 - mae: 0.0204 - val_loss: 0.0029 - val_mae: 0.0373
# Epoch 382/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 6.9864e-04 - mae: 0.0186 - val_loss: 0.0020 - val_mae: 0.0254
# Epoch 383/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 6.1833e-04 - mae: 0.0180 - val_loss: 0.0025 - val_mae: 0.0302
# Epoch 384/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 6.5345e-04 - mae: 0.0177 - val_loss: 0.0021 - val_mae: 0.0297
# Epoch 385/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 5.3407e-04 - mae: 0.0172 - val_loss: 0.0019 - val_mae: 0.0300
# Epoch 386/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 6.5071e-04 - mae: 0.0188 - val_loss: 0.0036 - val_mae: 0.0390
# Epoch 387/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 6.0913e-04 - mae: 0.0175 - val_loss: 0.0015 - val_mae: 0.0225
# Epoch 388/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 5.9231e-04 - mae: 0.0178 - val_loss: 0.0017 - val_mae: 0.0219
# Epoch 389/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 7.2381e-04 - mae: 0.0191 - val_loss: 0.0022 - val_mae: 0.0264
# Epoch 390/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 6.9294e-04 - mae: 0.0182 - val_loss: 0.1461 - val_mae: 0.2380
# Epoch 391/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0015 - mae: 0.0285 - val_loss: 0.0032 - val_mae: 0.0407
# Epoch 392/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0015 - mae: 0.0275 - val_loss: 0.0024 - val_mae: 0.0319
# Epoch 393/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 9.7044e-04 - mae: 0.0222 - val_loss: 0.0018 - val_mae: 0.0290
# Epoch 394/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 7.3980e-04 - mae: 0.0189 - val_loss: 0.0016 - val_mae: 0.0222
# Epoch 395/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 4.9712e-04 - mae: 0.0153 - val_loss: 0.1302 - val_mae: 0.2277
# Epoch 396/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 7.9233e-04 - mae: 0.0201 - val_loss: 0.0023 - val_mae: 0.0315
# Epoch 397/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 8.1229e-04 - mae: 0.0207 - val_loss: 0.0084 - val_mae: 0.0546
# Epoch 398/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 8.5449e-04 - mae: 0.0206 - val_loss: 0.0021 - val_mae: 0.0314
# Epoch 399/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 0.0136 - val_mae: 0.0802
# Epoch 400/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0014 - mae: 0.0268 - val_loss: 0.0022 - val_mae: 0.0287
# Epoch 401/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 8.9624e-04 - mae: 0.0215 - val_loss: 0.0024 - val_mae: 0.0280
# Epoch 402/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 6.6201e-04 - mae: 0.0190 - val_loss: 0.0017 - val_mae: 0.0219
# Epoch 403/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 6.8738e-04 - mae: 0.0179 - val_loss: 0.0018 - val_mae: 0.0291
# Epoch 404/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 6.8615e-04 - mae: 0.0185 - val_loss: 0.0021 - val_mae: 0.0320
# Epoch 405/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0010 - mae: 0.0231 - val_loss: 0.0082 - val_mae: 0.0613
# Epoch 406/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0011 - mae: 0.0234 - val_loss: 0.0025 - val_mae: 0.0311
# Epoch 407/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 9.7774e-04 - mae: 0.0224 - val_loss: 0.0029 - val_mae: 0.0330
# Epoch 408/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0015 - mae: 0.0273 - val_loss: 0.0031 - val_mae: 0.0358
# Epoch 409/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0017 - mae: 0.0296 - val_loss: 0.0019 - val_mae: 0.0290
# Epoch 410/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0019 - mae: 0.0302 - val_loss: 0.0035 - val_mae: 0.0410
# Epoch 411/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0019 - mae: 0.0278 - val_loss: 0.0031 - val_mae: 0.0375
# Epoch 412/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0013 - mae: 0.0262 - val_loss: 0.0020 - val_mae: 0.0277
# Epoch 413/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0018 - mae: 0.0292 - val_loss: 0.0038 - val_mae: 0.0463
# Epoch 414/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0013 - mae: 0.0260 - val_loss: 0.0054 - val_mae: 0.0517
# Epoch 415/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0347 - val_loss: 0.0030 - val_mae: 0.0358
# Epoch 416/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0019 - mae: 0.0314 - val_loss: 0.0033 - val_mae: 0.0379
# Epoch 417/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0016 - mae: 0.0296 - val_loss: 0.0028 - val_mae: 0.0351
# Epoch 418/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0011 - mae: 0.0235 - val_loss: 0.0071 - val_mae: 0.0466
# Epoch 419/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0017 - mae: 0.0302 - val_loss: 0.0036 - val_mae: 0.0438
# Epoch 420/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0015 - mae: 0.0279 - val_loss: 0.0025 - val_mae: 0.0328
# Epoch 421/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 9.1675e-04 - mae: 0.0212 - val_loss: 0.0037 - val_mae: 0.0386
# Epoch 422/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0013 - mae: 0.0234 - val_loss: 0.0093 - val_mae: 0.0747
# Epoch 423/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0065 - mae: 0.0571 - val_loss: 0.0063 - val_mae: 0.0554
# Epoch 424/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0039 - mae: 0.0434 - val_loss: 0.0086 - val_mae: 0.0640
# Epoch 425/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0080 - mae: 0.0592 - val_loss: 0.0143 - val_mae: 0.0890
# Epoch 426/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0072 - mae: 0.0568 - val_loss: 0.0084 - val_mae: 0.0736
# Epoch 427/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.1269 - mae: 0.2627 - val_loss: 0.0693 - val_mae: 0.2093
# Epoch 428/1000
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0623 - mae: 0.1825 - val_loss: 0.0669 - val_mae: 0.1928
# Epoch 429/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0204 - mae: 0.1089 - val_loss: 0.0174 - val_mae: 0.1038
# Epoch 430/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0104 - mae: 0.0750 - val_loss: 0.0128 - val_mae: 0.0891
# Epoch 431/1000
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0095 - mae: 0.0679 - val_loss: 0.0071 - val_mae: 0.0660
# Epoch 432/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0073 - mae: 0.0621 - val_loss: 0.0070 - val_mae: 0.0607
# Epoch 433/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0035 - mae: 0.0441 - val_loss: 0.0037 - val_mae: 0.0445
# Epoch 434/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0024 - mae: 0.0351 - val_loss: 0.0037 - val_mae: 0.0429
# Epoch 435/1000
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0018 - mae: 0.0302 - val_loss: 0.0035 - val_mae: 0.0401
# Epoch 436/1000
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0016 - mae: 0.0285 - val_loss: 0.0034 - val_mae: 0.0428

# %% [markdown]
# # チューニング結果確認

# %%
import pandas as pd

def plot_history(history:dict, ymax:float=None):
    history_df = pd.DataFrame(history)
    
    loss_df = history_df[["loss", "val_loss"]]
    loss_df.plot()
    plt.xlabel("epochs")
    plt.ylabel("Loss")
    if ymax is not None:
        plt.ylim(0., ymax)
    plt.show()

    acc_df = history_df[["mae", "val_mae"]]
    acc_df.plot()
    plt.xlabel("epochs")
    plt.ylabel("MeanAbsoluteError")
    plt.show()

# %%
X_pc_train.shape
# Out:
# (705, 2048, 3)

# %%
from tensorflow.keras.callbacks import EarlyStopping

estop =  EarlyStopping(monitor='val_loss', min_delta=0.0, patience=20)

# batch_size_list = [1, 4, 16, 64, 256, None]
batch_size_list = [128, 512]

# history_dict = {}

for batch_size in batch_size_list:
    print("===========================================================")
    print("batch_size : ", batch_size)
    print("===========================================================")
    
    # Build the model with the optimal hyperparameters
    model = tuner.hypermodel.build(best_hps)

    history = model.fit(
        {'pointCloud':X_pc_train, 'meta':X_meta_train}, y_train,
        batch_size = batch_size,
        epochs = 1000,
        verbose = 0,
        validation_data = ({'pointCloud':X_pc_val, 'meta':X_meta_val}, y_val),
        callbacks=[estop]
    )
    
    history_dict[batch_size] = history
# Out:
# ===========================================================
# batch_size :  128
# ===========================================================
# ===========================================================
# batch_size :  512
# ===========================================================

# %%
batch_size_list = [1, 4, 16, 64, 128, 256, 512, None]

for batch_size in batch_size_list:
    print("===========================================================")
    print("batch_size : ", batch_size)
    print("===========================================================")
    plot_history(history_dict[batch_size].history, ymax=2.)
# Out:
# ===========================================================
# batch_size :  1
# ===========================================================
# ===========================================================
# batch_size :  4
# ===========================================================
# ===========================================================
# batch_size :  16
# ===========================================================
# ===========================================================
# batch_size :  64
# ===========================================================
# ===========================================================
# batch_size :  128
# ===========================================================
# ===========================================================
# batch_size :  256
# ===========================================================
# ===========================================================
# batch_size :  512
# ===========================================================
# ===========================================================
# batch_size :  None
# ===========================================================

# %%
plot_history(best_history.history)

# %%
plot_history(best_history.history)

# %%
Y_train_pred = model.predict({'pointCloud':X_pc_train, 'meta':X_meta_train})
Y_test_pred = model.predict({'pointCloud':X_pc_test, 'meta':X_meta_test})
# Out:
# 23/23 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step

# %%
np.var(y_test)
# Out:
# 0.588685784208906

# %%
test_mse, test_mae = model.evaluate({'pointCloud':X_pc_test, 'meta':X_meta_test}, y_test, verbose=0)

print(test_mse)

print(test_mae)
# Out:
# 0.7909894585609436
# 0.7375370860099792

# %% [markdown]
# # いよいよ手詰まり状態
#
# **残された手段**
#
# *   点群データを調節
#  *   現在、1点群あたりの点の数は2048個に統一
#  *   点群データの作り方もいろいろある
#  *   モデルから人体モデルだけ取り除く（現状、全点群のうち人体表面の頂点が多くを占める）
#  *   エアコン・換気口を構成する頂点は必ずサンプリング
# *   点群を諦め、部屋のサイズを説明変数（入力）に加える
#  *   ニューラルネットワークすらも諦め、重回帰へ（線形・非線形）
# *   座っている位置と立っている位置とで観測飛沫数データを足し算した場合に分散は大きくなるだろうか（要確認）
# * RNN
# * 微分方程式を機械学習で解く
# * 感染リスク定義見直し
# * 分類問題へ
# *
#
# いずれも大きな効果はあまり期待できそうにない・・・
