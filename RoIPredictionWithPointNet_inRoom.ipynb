# %% [markdown]
# # 環境構築
#
#
# *   Pythonモジュールへのパス追加

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import sys
sys.path.append('/home/i9-10920x/ML/modules')

# %%
# !pip install keras-tuner --upgrade

# %%
# %matplotlib inline
import os
import glob
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy import interpolate
import show_mod

# %% [markdown]
# # 前処理

# %%
#読み込むデータのパスの設定

data_path = '/home/i9-10920x/ML/MLTrial/data'
input_list = glob.glob(data_path+"/*"+"/inputdata.csv")

# %%
#input(空調条件等)の読み込み
df_input = None

for input_fname in input_list:
    df_read = pd.read_csv(input_fname, index_col="case_name")
    if df_input is None:
        df_input = df_read
    else:
        df_input = pd.concat([df_input, df_read])

df_input
# Out:
#                        aircon  ventilation exhaust    1_x    1_y    1_z  \
# case_name
# office2_960_164_aout      960          164       a  3.780  1.265  1.255
# office2_960_82_bout       960           82       b  3.780  1.265  1.255
# office2_960_246_bout      960          246       b  3.780  1.265  1.255
# office2_660_164_bout      660          164       b  3.780  1.265  1.255
# office2_0_164_bout          0          164       b  3.780  1.265  1.255
# ...                       ...          ...     ...    ...    ...    ...
# office28_960_82_bout      960           82       b  1.265  3.820  1.255
# office28_660_0            660            0     off  1.265  3.820  1.255
# office28_360_246_aout     360          246       a  1.265  3.820  1.255
# office28_960_0            960            0     off  1.265  3.820  1.255
# office28_960_246_bout     960          246       b  1.265  3.820  1.255
#
#                        1_angle   2_x   2_y    2_z  ...    4_z  4_angle   5_x  \
# case_name                                          ...
# office2_960_164_aout      90.0  4.76  2.74  1.255  ...  1.255      0.0  2.84
# office2_960_82_bout       90.0  4.76  2.74  1.255  ...  1.255      0.0  2.84
# office2_960_246_bout      90.0  4.76  2.74  1.255  ...  1.255      0.0  2.84
# office2_660_164_bout      90.0  4.76  2.74  1.255  ...  1.255      0.0  2.84
# office2_0_164_bout        90.0  4.76  2.74  1.255  ...  1.255      0.0  2.84
# ...                        ...   ...   ...    ...  ...    ...      ...   ...
# office28_960_82_bout       0.0  2.93  2.84  1.255  ...  1.255    270.0  2.97
# office28_660_0             0.0  2.93  2.84  1.255  ...  1.255    270.0  2.97
# office28_360_246_aout      0.0  2.93  2.84  1.255  ...  1.255    270.0  2.97
# office28_960_0             0.0  2.93  2.84  1.255  ...  1.255    270.0  2.97
# office28_960_246_bout      0.0  2.93  2.84  1.255  ...  1.255    270.0  2.97
#
#                         5_y    5_z  5_angle  office_size_x  office_size_y  \
# case_name
# office2_960_164_aout   3.14  1.255      0.0            6.0            5.5
# office2_960_82_bout    3.14  1.255      0.0            6.0            5.5
# office2_960_246_bout   3.14  1.255      0.0            6.0            5.5
# office2_660_164_bout   3.14  1.255      0.0            6.0            5.5
# office2_0_164_bout     3.14  1.255      0.0            6.0            5.5
# ...                     ...    ...      ...            ...            ...
# office28_960_82_bout   4.76  1.255    270.0            9.5            6.0
# office28_660_0         4.76  1.255    270.0            9.5            6.0
# office28_360_246_aout  4.76  1.255    270.0            9.5            6.0
# office28_960_0         4.76  1.255    270.0            9.5            6.0
# office28_960_246_bout  4.76  1.255    270.0            9.5            6.0
#
#                        aircon_position_x  aircon_position_y
# case_name
# office2_960_164_aout                3.00               2.75
# office2_960_82_bout                 3.00               2.75
# office2_960_246_bout                3.00               2.75
# office2_660_164_bout                3.00               2.75
# office2_0_164_bout                  3.00               2.75
# ...                                  ...                ...
# office28_960_82_bout                4.75               3.00
# office28_660_0                      4.75               3.00
# office28_360_246_aout               4.75               3.00
# office28_960_0                      4.75               3.00
# office28_960_246_bout               4.75               3.00
#
# [263 rows x 27 columns]

# %%
#空調条件のみ抽出
df_meta = df_input.loc[:, ['aircon', 'ventilation', 'exhaust']]

df_meta
# Out:
#                        aircon  ventilation exhaust
# case_name
# office2_960_164_aout      960          164       a
# office2_960_82_bout       960           82       b
# office2_960_246_bout      960          246       b
# office2_660_164_bout      660          164       b
# office2_0_164_bout          0          164       b
# ...                       ...          ...     ...
# office28_960_82_bout      960           82       b
# office28_660_0            660            0     off
# office28_360_246_aout     360          246       a
# office28_960_0            960            0     off
# office28_960_246_bout     960          246       b
#
# [263 rows x 3 columns]

# %%
#排気口位置a,b,offをダミー変数化

df_meta = pd.get_dummies(df_meta, columns=['exhaust'])
# dummies = pd.get_dummies(df_input['exhaust'])
# df_input.drop("exhaust", axis=1, inplace=True)
# df_input = pd.concat([df_input, dummies], axis=1)
# df_input = df_input.reindex(columns=['aircon','ventilation','exhaust_a','b','off'
#           ,'1_x','1_y','1_z','1_angle','2_x','2_y','2_z','2_angle','3_x','3_y','3_z','3_angle'
#           ,'4_x','4_y','4_z','4_angle','5_x','5_y','5_z','5_angle',"office_size_x","office_size_y"
#           ,"aircon_position_x","aircon_position_y"])

df_meta
# Out:
#                        aircon  ventilation  exhaust_a  exhaust_b  exhaust_off
# case_name
# office2_960_164_aout      960          164          1          0            0
# office2_960_82_bout       960           82          0          1            0
# office2_960_246_bout      960          246          0          1            0
# office2_660_164_bout      660          164          0          1            0
# office2_0_164_bout          0          164          0          1            0
# ...                       ...          ...        ...        ...          ...
# office28_960_82_bout      960           82          0          1            0
# office28_660_0            660            0          0          0            1
# office28_360_246_aout     360          246          1          0            0
# office28_960_0            960            0          0          0            1
# office28_960_246_bout     960          246          0          1            0
#
# [263 rows x 5 columns]

# %%
#入力データフレームのインデックス順に、感染リスク分布ファイルを読み込むためのパスリスト作成
case_index_list = list(df_meta.index)

path2data = '/home/i9-10920x/ML/MLTrial/data'

distribution_path_list = []
for case_index in case_index_list:
    str_list = case_index.split('_', maxsplit=1)
    distribution_path_list.append(path2data + '/' + str_list[0] + '/data/' + str_list[1] + '/risk_dist.csv')

# distribution_path_list

# %%
#高さと幅の最大値の取得

max_height = 0
max_width = 0
for file_path in distribution_path_list:
    array_read = np.loadtxt(file_path, delimiter=",", dtype=np.float32)
    max_height = max(max_height, array_read.shape[0])
    max_width = max(max_width, array_read.shape[1])

print(max_height, max_width)
# Out:
# 65 95

# %%
#−１パディングでサイズ合わせ
distributionArray_list = []

for file_path in distribution_path_list:
    array_read = np.loadtxt(file_path, delimiter=",", dtype=np.float32)
    array_padded = np.pad(array=array_read, pad_width=[(0, max_height - array_read.shape[0]), (0,  max_width - array_read.shape[1])],\
                        mode="constant", constant_values = (-1) )
    distributionArray_list.append(array_padded)

distributionArray_padded = np.array(distributionArray_list)
distributionArray_padded.shape
# Out:
# (263, 65, 95)

# %%
#感染リスク分布を読み込んで平均値をそのケースのリスクとする

risk_mean_list = []

for file_path in distribution_path_list:
    array_read = np.loadtxt(file_path, delimiter=",", dtype=np.float32)
    risk_mean_list.append(array_read.mean())

risk_mean_array = np.array(risk_mean_list)
risk_mean_array.shape
# Out:
# (263,)

# %%
case_index_with_meanOfRisk = []

for i, case_index in enumerate(case_index_list):
    case_index_with_meanOfRisk.append(case_index + ', {:.2%}'.format(risk_mean_array[i]))
    
case_index_with_meanOfRisk
# Out:
# ['office2_960_164_aout, 6.14%',
#  'office2_960_82_bout, 6.63%',
#  'office2_960_246_bout, 8.85%',
#  'office2_660_164_bout, 6.05%',
#  'office2_0_164_bout, 4.98%',
#  'office2_0_82_aout, 5.61%',
#  'office2_960_82_aout, 6.50%',
#  'office2_0_246_bout, 6.03%',
#  'office2_0_0, 5.17%',
#  'office2_0_82_bout, 5.37%',
#  'office2_660_246_bout, 5.22%',
#  'office2_0_246_aout, 5.25%',
#  'office2_660_164_aout, 6.73%',
#  'office2_360_82_aout, 4.16%',
#  'office2_660_246_aout, 6.73%',
#  'office2_660_82_bout, 5.57%',
#  'office2_360_164_aout, 4.84%',
#  'office2_360_0, 4.93%',
#  'office2_960_0, 6.60%',
#  'office2_660_82_aout, 5.84%',
#  'office2_0_164_aout, 5.37%',
#  'office2_360_246_bout, 6.08%',
#  'office2_960_246_aout, 8.65%',
#  'office2_960_164_bout, 7.32%',
#  'office2_360_246_aout, 4.22%',
#  'office2_360_164_bout, 5.49%',
#  'office2_660_0, 5.82%',
#  'office2_360_82_bout, 4.27%',
#  'office7_360_164_bout, 6.27%',
#  'office7_660_246_aout, 7.67%',
#  'office7_660_82_bout, 6.44%',
#  'office7_660_82_aout, 6.59%',
#  'office7_660_164_bout, 7.39%',
#  'office7_0_164_aout, 6.14%',
#  'office7_0_82_aout, 5.86%',
#  'office7_660_164_aout, 6.92%',
#  'office7_660_246_bout, 7.32%',
#  'office7_360_246_bout, 6.00%',
#  'office7_960_82_aout, 8.63%',
#  'office7_360_82_bout, 5.38%',
#  'office7_360_82_aout, 6.04%',
#  'office7_0_0, 5.69%',
#  'office7_960_164_bout, 8.33%',
#  'office7_0_246_aout, 5.98%',
#  'office7_360_164_aout, 5.04%',
#  'office7_360_0, 5.30%',
#  'office7_0_82_bout, 5.24%',
#  'office7_960_246_aout, 7.46%',
#  'office7_960_164_aout, 7.42%',
#  'office7_0_164_bout, 5.82%',
#  'office7_0_246_bout, 5.78%',
#  'office7_960_82_bout, 8.25%',
#  'office7_660_0, 6.71%',
#  'office7_360_246_aout, 6.52%',
#  'office7_960_0, 8.33%',
#  'office7_960_246_bout, 9.15%',
#  'office1_960_164_aout, 5.54%',
#  'office1_0_205_aout, 5.81%',
#  'office1_660_41_bout, 4.96%',
#  'office1_960_82_bout, 7.84%',
#  'office1_960_205_bout, 5.80%',
#  'office1_960_246_bout, 7.53%',
#  'office1_660_164_bout, 5.67%',
#  'office1_960_205_aout, 5.44%',
#  'office1_0_123_bout, 5.61%',
#  'office1_960_123_aout, 8.04%',
#  'office1_0_164_bout, 5.59%',
#  'office1_0_82_aout, 5.78%',
#  'office1_660_205_bout, 5.92%',
#  'office1_0_123_aout, 5.86%',
#  'office1_0_41_bout, 5.65%',
#  'office1_960_82_aout, 6.39%',
#  'office1_0_246_bout, 5.97%',
#  'office1_0_0, 6.37%',
#  'office1_0_82_bout, 6.47%',
#  'office1_660_246_bout, 5.38%',
#  'office1_0_246_aout, 5.37%',
#  'office1_660_164_aout, 5.27%',
#  'office1_0_205_bout, 6.03%',
#  'office1_660_123_bout, 5.78%',
#  'office1_660_246_aout, 6.63%',
#  'office1_960_123_bout, 7.84%',
#  'office1_660_82_bout, 5.76%',
#  'office1_0_41_aout, 5.38%',
#  'office1_960_41_bout, 8.53%',
#  'office1_660_41_aout, 5.60%',
#  'office1_660_205_aout, 4.95%',
#  'office1_960_0, 6.45%',
#  'office1_660_123_aout, 5.73%',
#  'office1_660_82_aout, 4.54%',
#  'office1_0_164_aout, 5.90%',
#  'office1_960_246_aout, 6.68%',
#  'office1_960_41_aout, 6.97%',
#  'office1_960_164_bout, 7.19%',
#  'office1_660_0, 5.46%',
#  'office10_360_164_bout, 3.59%',
#  'office10_660_246_aout, 5.90%',
#  'office10_660_82_bout, 3.34%',
#  'office10_660_82_aout, 2.82%',
#  'office10_660_164_bout, 2.38%',
#  'office10_0_164_aout, 4.47%',
#  'office10_0_82_aout, 4.01%',
#  'office10_660_164_aout, 3.25%',
#  'office10_660_246_bout, 2.92%',
#  'office10_360_246_bout, 4.29%',
#  'office10_960_82_aout, 4.85%',
#  'office10_360_82_bout, 3.15%',
#  'office10_360_82_aout, 3.88%',
#  'office10_0_0, 3.55%',
#  'office10_960_164_bout, 4.24%',
#  'office10_0_246_aout, 4.15%',
#  'office10_360_164_aout, 3.86%',
#  'office10_360_0, 3.71%',
#  'office10_0_82_bout, 4.68%',
#  'office10_960_246_aout, 4.56%',
#  'office10_960_164_aout, 3.52%',
#  'office10_0_164_bout, 3.72%',
#  'office10_0_246_bout, 4.54%',
#  'office10_960_82_bout, 5.03%',
#  'office10_660_0, 2.68%',
#  'office10_360_246_aout, 4.00%',
#  'office10_960_0, 4.29%',
#  'office10_960_246_bout, 5.28%',
#  'office22_360_164_bout, 3.23%',
#  'office22_660_246_aout, 2.82%',
#  'office22_660_82_bout, 3.28%',
#  'office22_660_82_aout, 2.44%',
#  'office22_660_164_bout, 3.83%',
#  'office22_0_164_aout, 2.90%',
#  'office22_0_82_aout, 3.55%',
#  'office22_660_164_aout, 3.21%',
#  'office22_660_246_bout, 3.85%',
#  'office22_360_246_bout, 2.90%',
#  'office22_960_82_aout, 4.05%',
#  'office22_360_82_bout, 2.09%',
#  'office22_360_82_aout, 2.83%',
#  'office22_0_0, 3.35%',
#  'office22_960_164_bout, 3.89%',
#  'office22_0_246_aout, 3.27%',
#  'office22_360_164_aout, 2.52%',
#  'office22_360_0, 2.23%',
#  'office22_0_82_bout, 2.88%',
#  'office22_960_246_aout, 4.07%',
#  'office22_960_164_aout, 3.53%',
#  'office22_0_164_bout, 3.75%',
#  'office22_0_246_bout, 3.61%',
#  'office22_960_82_bout, 4.12%',
#  'office22_660_0, 2.66%',
#  'office22_360_246_aout, 2.53%',
#  'office22_960_0, 3.60%',
#  'office22_960_246_bout, 4.87%',
#  'office3_960_164_aout, 3.83%',
#  'office3_960_82_bout, 3.69%',
#  'office3_960_246_bout, 3.87%',
#  'office3_660_164_bout, 3.77%',
#  'office3_0_164_bout, 4.00%',
#  'office3_0_82_aout, 3.91%',
#  'office3_960_82_aout, 4.36%',
#  'office3_0_246_bout, 4.05%',
#  'office3_0_0, 4.02%',
#  'office3_0_82_bout, 3.90%',
#  'office3_660_246_bout, 3.30%',
#  'office3_0_246_aout, 3.81%',
#  'office3_660_164_aout, 3.62%',
#  'office3_360_82_aout, 4.45%',
#  'office3_660_246_aout, 4.12%',
#  'office3_660_82_bout, 3.67%',
#  'office3_360_164_aout, 4.25%',
#  'office3_360_0, 4.19%',
#  'office3_960_0, 3.86%',
#  'office3_660_82_aout, 3.99%',
#  'office3_0_164_aout, 4.12%',
#  'office3_360_246_bout, 4.24%',
#  'office3_960_246_aout, 4.16%',
#  'office3_960_164_bout, 3.72%',
#  'office3_360_246_aout, 3.90%',
#  'office3_360_164_bout, 4.07%',
#  'office3_660_0, 3.41%',
#  'office3_360_82_bout, 4.20%',
#  'office15_360_164_bout, 4.64%',
#  'office15_660_246_aout, 5.16%',
#  'office15_660_82_bout, 4.56%',
#  'office15_660_82_aout, 4.40%',
#  'office15_660_164_bout, 4.43%',
#  'office15_0_164_aout, 4.56%',
#  'office15_0_82_aout, 4.56%',
#  'office15_660_164_aout, 4.63%',
#  'office15_660_246_bout, 5.48%',
#  'office15_360_246_bout, 5.27%',
#  'office15_960_82_aout, 5.29%',
#  'office15_360_82_bout, 4.11%',
#  'office15_360_82_aout, 4.37%',
#  'office15_0_0, 3.64%',
#  'office15_960_164_bout, 5.86%',
#  'office15_0_246_aout, 5.23%',
#  'office15_360_164_aout, 4.20%',
#  'office15_360_0, 4.00%',
#  'office15_0_82_bout, 4.17%',
#  'office15_960_246_aout, 5.44%',
#  'office15_960_164_aout, 4.29%',
#  'office15_0_164_bout, 4.70%',
#  'office15_0_246_bout, 4.36%',
#  'office15_960_82_bout, 4.83%',
#  'office15_660_0, 4.31%',
#  'office15_360_246_aout, 4.61%',
#  'office15_960_0, 4.66%',
#  'office15_960_246_bout, 5.66%',
#  'office16_360_164_bout, 4.12%',
#  'office16_660_246_aout, 5.37%',
#  'office16_660_82_bout, 4.17%',
#  'office16_660_82_aout, 4.06%',
#  'office16_660_164_bout, 4.16%',
#  'office16_0_164_aout, 4.19%',
#  'office16_0_82_aout, 4.07%',
#  'office16_660_164_aout, 5.42%',
#  'office16_660_246_bout, 5.00%',
#  'office16_360_246_bout, 4.00%',
#  'office16_960_82_aout, 6.10%',
#  'office16_360_82_bout, 4.27%',
#  'office16_360_82_aout, 4.29%',
#  'office16_0_0, 4.05%',
#  'office16_960_164_bout, 5.68%',
#  'office16_0_246_aout, 5.12%',
#  'office16_360_164_aout, 4.66%',
#  'office16_360_0, 3.63%',
#  'office16_0_82_bout, 4.56%',
#  'office16_960_246_aout, 6.98%',
#  'office16_960_164_aout, 5.69%',
#  'office16_0_164_bout, 4.13%',
#  'office16_0_246_bout, 3.77%',
#  'office16_960_82_bout, 5.83%',
#  'office16_660_0, 5.07%',
#  'office16_360_246_aout, 4.69%',
#  'office16_960_0, 5.35%',
#  'office16_960_246_bout, 5.80%',
#  'office28_360_164_bout, 3.86%',
#  'office28_660_246_aout, 3.65%',
#  'office28_660_82_bout, 3.77%',
#  'office28_660_82_aout, 3.24%',
#  'office28_660_164_bout, 4.13%',
#  'office28_0_164_aout, 2.74%',
#  'office28_0_82_aout, 3.05%',
#  'office28_660_164_aout, 2.82%',
#  'office28_660_246_bout, 4.43%',
#  'office28_360_246_bout, 3.59%',
#  'office28_960_82_aout, 4.14%',
#  'office28_360_82_bout, 3.41%',
#  'office28_360_82_aout, 2.86%',
#  'office28_0_0, 3.12%',
#  'office28_960_164_bout, 4.56%',
#  'office28_0_246_aout, 2.93%',
#  'office28_360_164_aout, 2.72%',
#  'office28_360_0, 2.87%',
#  'office28_0_82_bout, 3.12%',
#  'office28_960_246_aout, 4.00%',
#  'office28_960_164_aout, 4.08%',
#  'office28_0_164_bout, 3.23%',
#  'office28_0_246_bout, 3.47%',
#  'office28_960_82_bout, 4.80%',
#  'office28_660_0, 2.55%',
#  'office28_360_246_aout, 2.80%',
#  'office28_960_0, 4.56%',
#  'office28_960_246_bout, 5.37%']

# %%
ID_max = risk_mean_array.argmax()
ID_min = risk_mean_array.argmin()

print(case_index_with_meanOfRisk[ID_max])
show_mod.show_image(distributionArray_padded[ID_max], cbar=True, cmap=cmap)

print('=======================================================')

print(case_index_with_meanOfRisk[ID_min])
show_mod.show_image(distributionArray_padded[ID_min], cbar=True, cmap=cmap)
# Out:
# office7_960_246_bout, 9.15%
# =======================================================
# office22_360_82_bout, 2.09%

# %%
arg = np.argsort(risk_mean_array)
median_ID = arg[len(arg)//2]

print(case_index_with_meanOfRisk[median_ID])
# Out:
# office10_960_246_aout, 4.56%

# %%
#複数プロット
offset = 20
show_mod.show_images(
    distributionArray_padded[offset:],
    title_name=case_index_with_meanOfRisk[offset:],
    row=4, column=5, cbar=False, cmap=cmap
)

# %%
# np_output = np.empty((max_num_row, max_num_column))
# for i in range(num_output):
#     np_temp = np.loadtxt(output_list[i], delimiter=",", dtype=np.float32)
    
#     if np_temp.shape[0] < max_num_row :
#         nan = np.empty((max_num_row - int(np_temp.shape[0]), max_num_column))
#         nan[max_num_row - int(np_temp.shape[0]), max_num_column] = np.nan
#         np.insert(np_temp, int(np_temp.shape[0]) + 1 : max_num_row, :] = np.nan
#     if np_temp.shape[1] < max_num_column :
#         np_temp[:, int(np_temp.shape[1]) + 1:] = np.nan 
    
#     np_output = np.append(np_output, np_temp, axis=0)
    
# output = []
# for i in range(num_output):
#     with open (output_list[i], "r") as csv_fname:
#         reader = csv.reader(csv_fname)
#         temp_list = [row for row in reader]
#         output.append(temp_list)

# %%
# np_output_2D = df_output_2D.to_numpy()
# np_output_3D = np_output_2D.reshape(office_list.shape[0], max_num_row, max_num_column)

# %%
# np_output_3D.shape

# %%
# plt.imshow(np_output_3D[0], cmap="bwr", origin="lower")

# %%
from sklearn import preprocessing

#入力データの標準化
stdscaler = preprocessing.StandardScaler()
stdscaler.fit(df_meta)
df_meta_tf = stdscaler.transform(df_meta)

df_meta_standardized = pd.DataFrame(df_meta_tf, index=df_meta.index, columns=df_meta.columns)
df_meta_standardized

# df_input_std = df_input.copy()
# for i in range(int(input_std.shape[1])):
#     df_input_std.iloc[:, i] = input_std[:, i]
# Out:
#                          aircon  ventilation  exhaust_a  exhaust_b  \
# case_name
# office2_960_164_aout   1.261546     0.294952   1.143249  -0.874700
# office2_960_82_bout    1.261546    -0.686976  -0.874700   1.143249
# office2_960_246_bout   1.261546     1.276880  -0.874700   1.143249
# office2_660_164_bout   0.435795     0.294952  -0.874700   1.143249
# office2_0_164_bout    -1.380856     0.294952  -0.874700   1.143249
# ...                         ...          ...        ...        ...
# office28_960_82_bout   1.261546    -0.686976  -0.874700   1.143249
# office28_660_0         0.435795    -1.668904  -0.874700  -0.874700
# office28_360_246_aout -0.389955     1.276880   1.143249  -0.874700
# office28_960_0         1.261546    -1.668904  -0.874700  -0.874700
# office28_960_246_bout  1.261546     1.276880  -0.874700   1.143249
#
#                        exhaust_off
# case_name
# office2_960_164_aout     -0.391802
# office2_960_82_bout      -0.391802
# office2_960_246_bout     -0.391802
# office2_660_164_bout     -0.391802
# office2_0_164_bout       -0.391802
# ...                            ...
# office28_960_82_bout     -0.391802
# office28_660_0            2.552310
# office28_360_246_aout    -0.391802
# office28_960_0            2.552310
# office28_960_246_bout    -0.391802
#
# [263 rows x 5 columns]

# %%
stdscaler_risk = preprocessing.StandardScaler()

risk_mean_array_2d = risk_mean_array.reshape(-1,1)
stdscaler.fit(risk_mean_array_2d)
risk_mean_standardized = stdscaler.transform(risk_mean_array_2d)

risk_mean_standardized
# Out:
# array([[ 0.9345412 ],
#        [ 1.2850636 ],
#        [ 2.862018  ],
#        [ 0.86967397],
#        [ 0.11055076],
#        [ 0.5610365 ],
#        [ 1.1942706 ],
#        [ 0.85717595],
#        [ 0.24909812],
#        [ 0.39123523],
#        [ 0.285279  ],
#        [ 0.30451414],
#        [ 1.3531778 ],
#        [-0.4741317 ],
#        [ 1.358757  ],
#        [ 0.534159  ],
#        [ 0.01228911],
#        [ 0.07505318],
#        [ 1.2663293 ],
#        [ 0.7212473 ],
#        [ 0.38598612],
#        [ 0.89376587],
#        [ 2.7209587 ],
#        [ 1.7743342 ],
#        [-0.42763245],
#        [ 0.47296607],
#        [ 0.70791143],
#        [-0.39276862],
#        [ 1.0263467 ],
#        [ 2.0259984 ],
#        [ 1.1496191 ],
#        [ 1.2559699 ],
#        [ 1.8239795 ],
#        [ 0.935982  ],
#        [ 0.7353287 ],
#        [ 1.4926533 ],
#        [ 1.7769964 ],
#        [ 0.8357208 ],
#        [ 2.7070622 ],
#        [ 0.3997305 ],
#        [ 0.866603  ],
#        [ 0.6137162 ],
#        [ 2.4923546 ],
#        [ 0.82104486],
#        [ 0.15278648],
#        [ 0.33922112],
#        [ 0.29678327],
#        [ 1.877619  ],
#        [ 1.8491415 ],
#        [ 0.7117042 ],
#        [ 0.68385905],
#        [ 2.44056   ],
#        [ 1.3450016 ],
#        [ 1.2055658 ],
#        [ 2.4944322 ],
#        [ 3.0795422 ],
#        [ 0.5093854 ],
#        [ 0.7007976 ],
#        [ 0.09584859],
#        [ 2.147997  ],
#        [ 0.6971061 ],
#        [ 1.9280463 ],
#        [ 0.60405016],
#        [ 0.43896914],
#        [ 0.5632698 ],
#        [ 2.285449  ],
#        [ 0.54760295],
#        [ 0.68051887],
#        [ 0.7830917 ],
#        [ 0.74036694],
#        [ 0.5912347 ],
#        [ 1.1136541 ],
#        [ 0.8193253 ],
#        [ 1.0993125 ],
#        [ 1.1683122 ],
#        [ 0.39853904],
#        [ 0.3901092 ],
#        [ 0.31878948],
#        [ 0.8608131 ],
#        [ 0.6820423 ],
#        [ 1.285948  ],
#        [ 2.1495595 ],
#        [ 0.6687271 ],
#        [ 0.39798185],
#        [ 2.6385772 ],
#        [ 0.549483  ],
#        [ 0.09417175],
#        [ 1.1551797 ],
#        [ 0.64265794],
#        [-0.19754541],
#        [ 0.76316637],
#        [ 1.3224275 ],
#        [ 1.5291142 ],
#        [ 1.6829519 ],
#        [ 0.455177  ],
#        [-0.87666583],
#        [ 0.7654791 ],
#        [-1.057327  ],
#        [-1.4225695 ],
#        [-1.7337126 ],
#        [-0.25358567],
#        [-0.57862914],
#        [-1.1166112 ],
#        [-1.350021  ],
#        [-0.37833166],
#        [ 0.02257911],
#        [-1.1909341 ],
#        [-0.6687985 ],
#        [-0.90669173],
#        [-0.41345912],
#        [-0.48119226],
#        [-0.6862975 ],
#        [-0.79278255],
#        [-0.09948988],
#        [-0.18845057],
#        [-0.9246922 ],
#        [-0.78340554],
#        [-0.19754118],
#        [ 0.15024218],
#        [-1.5228584 ],
#        [-0.58355796],
#        [-0.37718526],
#        [ 0.32766175],
#        [-1.1312426 ],
#        [-1.4267435 ],
#        [-1.1001475 ],
#        [-1.6936275 ],
#        [-0.70359796],
#        [-1.3654873 ],
#        [-0.90254027],
#        [-1.1490364 ],
#        [-0.6890731 ],
#        [-1.3679968 ],
#        [-0.5526432 ],
#        [-1.9453884 ],
#        [-1.4143846 ],
#        [-1.0454656 ],
#        [-0.6648749 ],
#        [-1.1019224 ],
#        [-1.6366124 ],
#        [-1.8451017 ],
#        [-1.3790814 ],
#        [-0.5352579 ],
#        [-0.9205596 ],
#        [-0.7637184 ],
#        [-0.86525136],
#        [-0.5016666 ],
#        [-1.5360273 ],
#        [-1.6311325 ],
#        [-0.87145084],
#        [ 0.03388625],
#        [-0.7091261 ],
#        [-0.8049688 ],
#        [-0.6798036 ],
#        [-0.74868506],
#        [-0.58188087],
#        [-0.6504287 ],
#        [-0.32570526],
#        [-0.5467362 ],
#        [-0.56978416],
#        [-0.65302014],
#        [-1.0847095 ],
#        [-0.7166498 ],
#        [-0.85258585],
#        [-0.2681821 ],
#        [-0.5016112 ],
#        [-0.8167404 ],
#        [-0.40622157],
#        [-0.449782  ],
#        [-0.68232936],
#        [-0.59106946],
#        [-0.5026212 ],
#        [-0.41319683],
#        [-0.4690394 ],
#        [-0.7818188 ],
#        [-0.6552139 ],
#        [-0.5357149 ],
#        [-1.0027652 ],
#        [-0.43953413],
#        [-0.12794146],
#        [ 0.2398149 ],
#        [-0.18924807],
#        [-0.29888257],
#        [-0.279884  ],
#        [-0.18419129],
#        [-0.18782187],
#        [-0.13582973],
#        [ 0.46980393],
#        [ 0.3176036 ],
#        [ 0.3342298 ],
#        [-0.5084688 ],
#        [-0.3224586 ],
#        [-0.8436635 ],
#        [ 0.7374064 ],
#        [ 0.2897794 ],
#        [-0.4406305 ],
#        [-0.5855233 ],
#        [-0.46502945],
#        [ 0.43584567],
#        [-0.37689963],
#        [-0.08873171],
#        [-0.32781848],
#        [ 0.00368999],
#        [-0.36410165],
#        [-0.15198064],
#        [-0.11348569],
#        [ 0.5945147 ],
#        [-0.4980853 ],
#        [ 0.38846153],
#        [-0.46631843],
#        [-0.543844  ],
#        [-0.47143003],
#        [-0.45019588],
#        [-0.5374331 ],
#        [ 0.4236825 ],
#        [ 0.12677796],
#        [-0.5880973 ],
#        [ 0.9052807 ],
#        [-0.393777  ],
#        [-0.3773776 ],
#        [-0.54945797],
#        [ 0.61157227],
#        [ 0.21010163],
#        [-0.11820043],
#        [-0.8512667 ],
#        [-0.18598948],
#        [ 1.5347433 ],
#        [ 0.62041855],
#        [-0.4907097 ],
#        [-0.745334  ],
#        [ 0.7138828 ],
#        [ 0.17719232],
#        [-0.09418987],
#        [ 0.37344566],
#        [ 0.69241786],
#        [-0.68369144],
#        [-0.83151937],
#        [-0.74551046],
#        [-1.123091  ],
#        [-0.4898049 ],
#        [-1.4821047 ],
#        [-1.2596194 ],
#        [-1.4257936 ],
#        [-0.28265828],
#        [-0.87657255],
#        [-0.48723254],
#        [-1.003525  ],
#        [-1.3945216 ],
#        [-1.2079713 ],
#        [-0.1900657 ],
#        [-1.3437161 ],
#        [-1.4980085 ],
#        [-1.3890234 ],
#        [-1.2093933 ],
#        [-0.5818379 ],
#        [-0.52750844],
#        [-1.13386   ],
#        [-0.96298075],
#        [-0.01868425],
#        [-1.6188884 ],
#        [-1.4381713 ],
#        [-0.18790956],
#        [ 0.38780552]], dtype=float32)

# %%
import os
import random
import numpy as np
import json
import glob
from stl import mesh
from enum import Enum, auto

# 列挙型の定義
class OfficePart(Enum):
    aircon = auto()
    airvent = auto()
    # body = auto()
    room = auto()
    desks = auto()


"""
データの前処理

オフィスモデル（STLファイル）を読み込み、点群情報のみ取り出し、
ランダムサンプリングで指定個の点群(ndarray)にする。
"""
officemodel_path = '/home/i9-10920x/ML/officemodel'
# office_list = os.listdir(officemodel_path)
case_list = [s.replace('office', 'case') for s in os.listdir(data_path)]
# office_list = ['office1', 'office2', 'office3', 'office7', 'office10', 'office15', 'office16', 'office22', 'office28']
print(office_list)

# 列挙型のメンバーの列挙
for part in OfficePart:
    print(part)
    
NUM_POINTS = 2048

sampledPointCloud_dict = {}
for casename in case_list:
    officename = casename.replace('case', 'office') 
    pc_dict = {}
    for part in OfficePart:
        path = officemodel_path + '/' + casename + '/' + part.name
        # print(path)
        stl_list = glob.glob(path + "/*.stl")
        print(stl_list)
        pc_list = []
        for stlfname in stl_list:
            for mesh_read in mesh.Mesh.from_multi_file(stlfname):
                points = mesh_read.points.reshape([-1, 3])
                pc_list.append(points)

        points_concat = np.concatenate(pc_list)
        points_concat = np.unique(points_concat, axis=0)
        pc_dict[part] = points_concat.copy()
                        

    pc_aircon = pc_dict[OfficePart.aircon]
    pc_airvent = pc_dict[OfficePart.airvent]
    pc_room = pc_dict[OfficePart.room]
    pc_base = np.concatenate([pc_aircon, pc_airvent, pc_room])
    num_sampling = NUM_POINTS - len(pc_base)

    # pc_forSampling = np.concatenate([pc_dict[OfficePart.body], pc_dict[OfficePart.desks]])
    pc_forSampling = pc_dict[OfficePart.desks]
    print(f'#sampling {num_sampling} from {len(pc_forSampling)}', )
    rand_list = random.sample(range(len(pc_forSampling)), k=num_sampling)
    pc_sampled = pc_forSampling[rand_list, :]
    
    pointCloud = np.concatenate([pc_base, pc_sampled])
    print(pointCloud.shape)
    sampledPointCloud_dict[officename] = pointCloud
# Out:
# ['case10', 'case28', 'case7', 'case19', 'case2', 'case15', 'case12', 'case9', 'case30', 'case22', 'case5', 'case27', 'case31', 'case24', 'case29', 'case3', 'case6', 'case26', 'case1', 'case25', 'case14', 'case11', 'case32', 'case23', 'case21', 'case33', 'case4', 'case13', 'case8', 'case20', 'case17', 'case18', 'case16']
# OfficePart.aircon
# OfficePart.airvent
# OfficePart.room
# OfficePart.desks
# ['/home/i9-10920x/ML/officemodel/case2/aircon/aircon_inlets.stl', '/home/i9-10920x/ML/officemodel/case2/aircon/aircon_body.stl', '/home/i9-10920x/ML/officemodel/case2/aircon/aircon_outlet.stl']
# ['/home/i9-10920x/ML/officemodel/case2/airvent/airvent_b.stl', '/home/i9-10920x/ML/officemodel/case2/airvent/20210812_airvent_a.stl']
# ['/home/i9-10920x/ML/officemodel/case2/room/20210810_office_side3.stl', '/home/i9-10920x/ML/officemodel/case2/room/20210810_office_bottom.stl', '/home/i9-10920x/ML/officemodel/case2/room/20210812_office_side4.stl', '/home/i9-10920x/ML/officemodel/case2/room/20210810_office_side1.stl', '/home/i9-10920x/ML/officemodel/case2/room/20210810_office_side2.stl', '/home/i9-10920x/ML/officemodel/case2/room/20210810_office_top.stl']
# ['/home/i9-10920x/ML/officemodel/case2/desks/20210812_desks_case2.stl']
# #sampling 1440 from 1821
# (2048, 3)
# ['/home/i9-10920x/ML/officemodel/case7/aircon/20210812_aircon_inlets_model2.stl', '/home/i9-10920x/ML/officemodel/case7/aircon/aircon_outlet_model2.stl', '/home/i9-10920x/ML/officemodel/case7/aircon/aircon_body_model2.stl']
# ['/home/i9-10920x/ML/officemodel/case7/airvent/20210812_airvent_a_model2.stl', '/home/i9-10920x/ML/officemodel/case7/airvent/20210812_airvent_b_model2.stl']
# ['/home/i9-10920x/ML/officemodel/case7/room/20210812_office_side3_model2.stl', '/home/i9-10920x/ML/officemodel/case7/room/20210812_office_top_model2.stl', '/home/i9-10920x/ML/officemodel/case7/room/20210812_office_side4_model2.stl', '/home/i9-10920x/ML/officemodel/case7/room/20210812_office_side2_model2.stl', '/home/i9-10920x/ML/officemodel/case7/room/20210812_office_bottom_model2.stl', '/home/i9-10920x/ML/officemodel/case7/room/20210812_office_side1_model2.stl']
# ['/home/i9-10920x/ML/officemodel/case7/desks/20210812_desks_case7.stl']
# #sampling 1440 from 1825
# (2048, 3)
# ['/home/i9-10920x/ML/officemodel/case1/aircon/aircon_inlets.stl', '/home/i9-10920x/ML/officemodel/case1/aircon/aircon_body.stl', '/home/i9-10920x/ML/officemodel/case1/aircon/aircon_outlet.stl']
# ['/home/i9-10920x/ML/officemodel/case1/airvent/airvent_b.stl', '/home/i9-10920x/ML/officemodel/case1/airvent/20210812_airvent_a.stl']
# ['/home/i9-10920x/ML/officemodel/case1/room/20210810_office_side3.stl', '/home/i9-10920x/ML/officemodel/case1/room/20210810_office_bottom.stl', '/home/i9-10920x/ML/officemodel/case1/room/20210812_office_side4.stl', '/home/i9-10920x/ML/officemodel/case1/room/20210810_office_side1.stl', '/home/i9-10920x/ML/officemodel/case1/room/20210810_office_side2.stl', '/home/i9-10920x/ML/officemodel/case1/room/20210810_office_top.stl']
# ['/home/i9-10920x/ML/officemodel/case1/desks/20210810_desks.stl']
# #sampling 1440 from 1821
# (2048, 3)
# ['/home/i9-10920x/ML/officemodel/case10/aircon/aircon_outlet_model3.stl', '/home/i9-10920x/ML/officemodel/case10/aircon/aircon_body_model3.stl', '/home/i9-10920x/ML/officemodel/case10/aircon/20210812_aircon_inlets_model3.stl']
# ['/home/i9-10920x/ML/officemodel/case10/airvent/20210812_airvent_b_model3.stl', '/home/i9-10920x/ML/officemodel/case10/airvent/20210812_airvent_a_model3.stl']
# ['/home/i9-10920x/ML/officemodel/case10/room/20210812_office_top_model3.stl', '/home/i9-10920x/ML/officemodel/case10/room/20210812_office_side4_model3.stl', '/home/i9-10920x/ML/officemodel/case10/room/20210812_office_side3_model3.stl', '/home/i9-10920x/ML/officemodel/case10/room/20210812_office_side1_model3.stl', '/home/i9-10920x/ML/officemodel/case10/room/20210812_office_bottom_model3.stl', '/home/i9-10920x/ML/officemodel/case10/room/20210812_office_side2_model3.stl']
# ['/home/i9-10920x/ML/officemodel/case10/desks/20210812_desks_case10.stl']
# #sampling 1440 from 1825
# (2048, 3)
# ['/home/i9-10920x/ML/officemodel/case22/aircon/aircon_body_model5.stl', '/home/i9-10920x/ML/officemodel/case22/aircon/20210812_aircon_inlets_model5.stl', '/home/i9-10920x/ML/officemodel/case22/aircon/aircon_outlet_model5.stl']
# ['/home/i9-10920x/ML/officemodel/case22/airvent/20210812_airvent_b_model5.stl', '/home/i9-10920x/ML/officemodel/case22/airvent/20210812_airvent_a_model5.stl']
# ['/home/i9-10920x/ML/officemodel/case22/room/20210812_office_side1_model5.stl', '/home/i9-10920x/ML/officemodel/case22/room/20210812_office_side3_model5.stl', '/home/i9-10920x/ML/officemodel/case22/room/20210812_office_bottom_model5.stl', '/home/i9-10920x/ML/officemodel/case22/room/20210812_office_side4_model5.stl', '/home/i9-10920x/ML/officemodel/case22/room/20210812_office_top_model5.stl', '/home/i9-10920x/ML/officemodel/case22/room/20210812_office_side2_model5.stl']
# ['/home/i9-10920x/ML/officemodel/case22/desks/20210812_desks_case22.stl']
# #sampling 1376 from 1805
# (2048, 3)
# ['/home/i9-10920x/ML/officemodel/case3/aircon/aircon_inlets.stl', '/home/i9-10920x/ML/officemodel/case3/aircon/aircon_body.stl', '/home/i9-10920x/ML/officemodel/case3/aircon/aircon_outlet.stl']
# ['/home/i9-10920x/ML/officemodel/case3/airvent/airvent_b.stl', '/home/i9-10920x/ML/officemodel/case3/airvent/20210812_airvent_a.stl']
# ['/home/i9-10920x/ML/officemodel/case3/room/20210810_office_side3.stl', '/home/i9-10920x/ML/officemodel/case3/room/20210810_office_bottom.stl', '/home/i9-10920x/ML/officemodel/case3/room/20210812_office_side4.stl', '/home/i9-10920x/ML/officemodel/case3/room/20210810_office_side1.stl', '/home/i9-10920x/ML/officemodel/case3/room/20210810_office_side2.stl', '/home/i9-10920x/ML/officemodel/case3/room/20210810_office_top.stl']
# ['/home/i9-10920x/ML/officemodel/case3/desks/20210812_desks_case3.stl']
# #sampling 1440 from 1825
# (2048, 3)
# ['/home/i9-10920x/ML/officemodel/case15/aircon/aircon_outlet_model3.stl', '/home/i9-10920x/ML/officemodel/case15/aircon/aircon_body_model3.stl', '/home/i9-10920x/ML/officemodel/case15/aircon/20210812_aircon_inlets_model3.stl']
# ['/home/i9-10920x/ML/officemodel/case15/airvent/20210812_airvent_b_model3.stl', '/home/i9-10920x/ML/officemodel/case15/airvent/20210812_airvent_a_model3.stl']
# ['/home/i9-10920x/ML/officemodel/case15/room/20210812_office_top_model3.stl', '/home/i9-10920x/ML/officemodel/case15/room/20210812_office_side4_model3.stl', '/home/i9-10920x/ML/officemodel/case15/room/20210812_office_side3_model3.stl', '/home/i9-10920x/ML/officemodel/case15/room/20210812_office_side1_model3.stl', '/home/i9-10920x/ML/officemodel/case15/room/20210812_office_bottom_model3.stl', '/home/i9-10920x/ML/officemodel/case15/room/20210812_office_side2_model3.stl']
# ['/home/i9-10920x/ML/officemodel/case15/desks/20210812_desks_case15.stl']
# #sampling 1440 from 1825
# (2048, 3)
# ['/home/i9-10920x/ML/officemodel/case16/aircon/20210812_aircon_inlets_model4.stl', '/home/i9-10920x/ML/officemodel/case16/aircon/aircon_body_model4.stl', '/home/i9-10920x/ML/officemodel/case16/aircon/aircon_outlet_model4.stl']
# ['/home/i9-10920x/ML/officemodel/case16/airvent/20210812_airvent_a_model4.stl', '/home/i9-10920x/ML/officemodel/case16/airvent/20210812_airvent_b_model4.stl']
# ['/home/i9-10920x/ML/officemodel/case16/room/20210812_office_side4_model4.stl', '/home/i9-10920x/ML/officemodel/case16/room/20210812_office_bottom_model4.stl', '/home/i9-10920x/ML/officemodel/case16/room/20210812_office_top_model4.stl', '/home/i9-10920x/ML/officemodel/case16/room/20210812_office_side3_model4.stl', '/home/i9-10920x/ML/officemodel/case16/room/20210812_office_side2_model4.stl', '/home/i9-10920x/ML/officemodel/case16/room/20210812_office_side1_model4.stl']
# ['/home/i9-10920x/ML/officemodel/case16/desks/20210812_desks_case16.stl']
# #sampling 1440 from 1821
# (2048, 3)
# ['/home/i9-10920x/ML/officemodel/case28/aircon/aircon_outlet_model6.stl', '/home/i9-10920x/ML/officemodel/case28/aircon/20210812_aircon_inlets_model6.stl', '/home/i9-10920x/ML/officemodel/case28/aircon/aircon_body_model6.stl']
# ['/home/i9-10920x/ML/officemodel/case28/airvent/20210812_airvent_b_model6.stl', '/home/i9-10920x/ML/officemodel/case28/airvent/20210812_airvent_a_model6.stl']
# ['/home/i9-10920x/ML/officemodel/case28/room/20210812_office_top_model6.stl', '/home/i9-10920x/ML/officemodel/case28/room/20210812_office_side1_model6.stl', '/home/i9-10920x/ML/officemodel/case28/room/20210812_office_side4_model6.stl', '/home/i9-10920x/ML/officemodel/case28/room/20210812_office_bottom_model6.stl', '/home/i9-10920x/ML/officemodel/case28/room/20210812_office_side2_model6.stl', '/home/i9-10920x/ML/officemodel/case28/room/20210812_office_side3_model6.stl']
# ['/home/i9-10920x/ML/officemodel/case28/desks/20210812_desks_case28.stl']
# #sampling 1382 from 1805
# (2048, 3)

# %%
# import os
# import glob
# import shutil


# officemodel_path = '/home/i9-10920x/ML/officemodel'
# case_list = os.listdir(officemodel_path)
# print(office_list)

    
# # NUM_POINTS = 2048

# # sampledPointCloud_dict = {}
# for casename in case_list:
#     path = officemodel_path + '/' + casename
#     # if os.path.exists(path + '/room'):
#     #     os.rmdir(path + '/room')
#     stl_desks_path = glob.glob(path + "/room_and_desks/*desks*")
#     # print(stl_desks_path)
#     os.makedirs(path + '/desks')
#     shutil.move(stl_desks_path[0], path + '/desks')
    
#     os.rename(path + "/room_and_desks", path + "/room") 
# #         path = officemodel_path + '/' + casename + '/' + part.name
# #         stl_list = glob.glob(path + "/*.stl")

# %%
# mesh_read = mesh.Mesh.from_file('officemodel/case2/body/20210812_bodies_case2.stl')
# points = mesh_read.points.reshape([-1, 3])
# print(points.shape)

# for mesh_read in mesh.Mesh.from_multi_file('officemodel/case2/body/20210812_bodies_case2.stl'):
#     points = mesh_read.points.reshape([-1, 3])
#     print(points.shape)
    
# for mesh_read in mesh.Mesh.from_multi_file('officemodel/case2/airvent/20210812_airvent_a.stl'):
#     points = mesh_read.points.reshape([-1, 3])
#     print(points.shape)

# %%
from matplotlib import pyplot as plt

def plot3d_points(point_cloud):
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(projection="3d")
    ax.scatter(point_cloud[:, 0], point_cloud[:, 1], point_cloud[:, 2], alpha=0.4, s=2)
    # ax.set_axis_off()
    plt.show()
    
plot3d_points(sampledPointCloud_dict['office1'])

# %%
import numpy as np
'''
点群シャッフルによるデータ増強
'''
rng = np.random.default_rng()

pointCloud_augumented_dict = {}
for office_name, pointCloud in sampledPointCloud_dict.items():
    pc_list = []
    for i in range(4):
        pc = pointCloud.copy()

        if i >= 1:
            #点群のシャッフル
            rng.shuffle(pc)

        pc_list.append(pc)

    pointCloud_augumented_dict[office_name] = pc_list

pointCloud_augumented_dict
# Out:
# {'office2': [array([[2.5     , 2.25    , 2.6     ],
#          [2.5     , 2.375   , 2.6     ],
#          [2.5     , 2.45    , 2.6     ],
#          ...,
#          [3.745   , 1.175   , 0.48    ],
#          [2.878333, 4.81    , 0.53    ],
#          [3.98    , 1.178   , 0.53    ]], dtype=float32),
#   array([[3.825   , 4.7     , 0.7     ],
#          [3.075   , 3.027778, 0.75    ],
#          [3.775   , 3.65    , 0.61    ],
#          ...,
#          [3.7     , 0.99    , 0.48    ],
#          [4.233333, 1.766667, 0.7     ],
#          [3.125   , 5.05    , 0.2125  ]], dtype=float32),
#   array([[2.7      , 2.3497   , 2.566467 ],
#          [4.258333 , 3.45     , 0.05     ],
#          [4.475    , 3.75     , 0.2125   ],
#          ...,
#          [4.475    , 5.1      , 0.5166667],
#          [2.7      , 3.1503   , 2.6      ],
#          [5.035    , 2.855    , 0.53     ]], dtype=float32),
#   array([[3.075   , 2.483333, 0.7     ],
#          [3.98    , 1.084   , 0.48    ],
#          [3.775   , 3.183333, 0.75    ],
#          ...,
#          [3.3     , 2.375   , 2.6     ],
#          [3.075   , 2.561111, 0.75    ],
#          [4.258333, 5.1     , 0.05    ]], dtype=float32)],
#  'office7': [array([[4.       , 1.5      , 2.6      ],
#          [4.       , 1.625    , 2.6      ],
#          [4.       , 1.7      , 2.6      ],
#          ...,
#          [1.55     , 2.75     , 0.2666667],
#          [1.55     , 2.116667 , 0.7      ],
#          [2.96     , 1.053    , 0.48     ]], dtype=float32),
#   array([[4.41    , 1.021667, 0.48    ],
#          [4.85    , 2.3     , 2.5     ],
#          [4.8     , 2.1     , 2.6     ],
#          ...,
#          [2.725   , 1.1     , 0.1575  ],
#          [4.2     , 2.433233, 2.583233],
#          [0.94    , 2.405   , 0.96    ]], dtype=float32),
#   array([[2.68     , 0.815    , 0.8166667],
#          [3.75     , 1.5875   , 0.7      ],
#          [4.13     , 0.815    , 0.6733333],
#          ...,
#          [4.4      , 2.45     , 2.6      ],
#          [4.166667 , 2.075    , 0.75     ],
#          [0.99     , 2.51     , 0.8525   ]], dtype=float32),
#   array([[5.05     , 2.125    , 0.5166667],
#          [4.2      , 2.433233 , 2.583233 ],
#          [1.5      , 2.591667 , 0.7      ],
#          ...,
#          [3.7      , 2.125    , 0.61     ],
#          [1.303333 , 2.51     , 0.53     ],
#          [2.855    , 1.335    , 0.53     ]], dtype=float32)],
#  'office1': [array([[2.5     , 2.25    , 2.6     ],
#          [2.5     , 2.375   , 2.6     ],
#          [2.5     , 2.45    , 2.6     ],
#          ...,
#          [2.325   , 2.225   , 0.33    ],
#          [4.525   , 2.666667, 0.7     ],
#          [3.725   , 2.658333, 0.05    ]], dtype=float32),
#   array([[2.7      , 3.166467 , 2.566467 ],
#          [4.475    , 2.9      , 0.4833333],
#          [4.475    , 1.875    , 0.7      ],
#          ...,
#          [6.       , 0.       , 2.6      ],
#          [1.72     , 3.435    , 0.48     ],
#          [4.291667 , 1.733333 , 0.75     ]], dtype=float32),
#   array([[2.7      , 2.325    , 2.6      ],
#          [2.425    , 1.958333 , 0.05     ],
#          [1.85     , 3.2      , 0.1933333],
#          ...,
#          [3.775    , 2.225    , 0.19     ],
#          [3.3      , 2.4      , 2.575    ],
#          [3.775    , 1.941667 , 0.2833333]], dtype=float32),
#   array([[1.755   , 2.965   , 0.48    ],
#          [3.440909, 2.45    , 2.590909],
#          [3.085   , 1.059   , 0.48    ],
#          ...,
#          [3.366167, 2.45    , 2.516167],
#          [1.925   , 1.475   , 0.7     ],
#          [3.775   , 1.475   , 0.7     ]], dtype=float32)],
#  'office10': [array([[3.      , 2.5     , 2.6     ],
#          [3.      , 2.625   , 2.6     ],
#          [3.      , 2.7     , 2.6     ],
#          ...,
#          [1.968333, 3.7     , 0.05    ],
#          [4.21    , 2.      , 0.48    ],
#          [2.235   , 3.35    , 0.05    ]], dtype=float32),
#   array([[4.61     , 4.       , 0.1933333],
#          [4.21     , 2.       , 0.1575   ],
#          [4.       , 3.1      , 2.6      ],
#          ...,
#          [3.15     , 3.3      , 2.5125   ],
#          [3.086364 , 2.7      , 2.563636 ],
#          [1.751667 , 3.65     , 0.2666667]], dtype=float32),
#   array([[3.05     , 2.94     , 2.6      ],
#          [1.535    , 2.7      , 0.4833333],
#          [4.185    , 1.715    , 0.96     ],
#          ...,
#          [3.205    , 4.285    , 0.96     ],
#          [3.235    , 2.541667 , 0.7      ],
#          [3.32     , 3.45     , 2.6      ]], dtype=float32),
#   array([[3.11    , 4.      , 0.1575  ],
#          [3.917067, 3.3     , 2.6     ],
#          [4.401667, 3.025   , 0.7     ],
#          ...,
#          [2.185   , 2.3     , 0.19    ],
#          [3.068182, 3.3     , 2.581818],
#          [4.3225  , 3.025   , 0.7     ]], dtype=float32)],
#  'office22': [array([[3.85     , 2.75     , 2.6      ],
#          [3.85     , 2.875    , 2.6      ],
#          [3.85     , 2.95     , 2.6      ],
#          ...,
#          [2.51     , 2.196667 , 0.48     ],
#          [4.85     , 2.816667 , 0.4833333],
#          [4.82     , 4.51     , 0.8166667]], dtype=float32),
#   array([[3.96     , 2.228    , 0.53     ],
#          [4.65     , 3.625    , 2.6      ],
#          [5.466667 , 4.       , 0.7      ],
#          ...,
#          [4.05     , 2.9      , 2.6      ],
#          [5.       , 3.3      , 0.7      ],
#          [3.4      , 3.25     , 0.4833333]], dtype=float32),
#   array([[5.595    , 2.275    , 0.1933333],
#          [5.233333 , 3.3      , 0.75     ],
#          [2.05     , 2.6      , 0.2833333],
#          ...,
#          [3.79     , 4.51     , 0.48     ],
#          [3.79     , 4.196667 , 0.53     ],
#          [4.9      , 2.55     , 0.75     ]], dtype=float32),
#   array([[3.083333, 3.3     , 0.75    ],
#          [4.65    , 2.8     , 2.6     ],
#          [4.2     , 2.55    , 0.7     ],
#          ...,
#          [4.05    , 3.6     , 2.575   ],
#          [5.      , 2.925   , 0.7     ],
#          [4.38    , 2.04    , 0.8525  ]], dtype=float32)],
#  'office3': [array([[2.5  , 2.25 , 2.6  ],
#          [2.5  , 2.375, 2.6  ],
#          [2.5  , 2.45 , 2.6  ],
#          ...,
#          [5.21 , 1.055, 0.53 ],
#          [0.7  , 1.5  , 0.375],
#          [1.025, 0.575, 0.05 ]], dtype=float32),
#   array([[0.75     , 2.341667 , 0.7      ],
#          [2.65     , 3.05     , 2.5497   ],
#          [4.74     , 2.19     , 0.8525   ],
#          ...,
#          [2.65     , 3.05     , 2.5875   ],
#          [0.79     , 2.105    , 0.53     ],
#          [0.4833333, 2.5      , 0.05     ]], dtype=float32),
#   array([[0.7      , 1.05     , 0.4833333],
#          [4.69     , 3.78     , 0.53     ],
#          [0.375    , 1.5      , 0.05     ],
#          ...,
#          [5.25     , 2.95     , 0.7      ],
#          [5.053333 , 2.19     , 0.48     ],
#          [5.733333 , 3.35     , 0.7      ]], dtype=float32),
#   array([[5.625   , 2.9     , 0.05    ],
#          [5.25    , 3.261111, 0.75    ],
#          [0.7     , 2.025   , 0.7     ],
#          ...,
#          [3.383533, 2.45    , 2.566467],
#          [1.075   , 0.525   , 0.1575  ],
#          [5.625   , 1.9     , 0.05    ]], dtype=float32)],
#  'office15': [array([[3.      , 2.5     , 2.6     ],
#          [3.      , 2.625   , 2.6     ],
#          [3.      , 2.7     , 2.6     ],
#          ...,
#          [2.2     , 1.522222, 0.75    ],
#          [1.5     , 4.266667, 0.7     ],
#          [1.225   , 4.725   , 0.3725  ]], dtype=float32),
#   array([[1.225    , 1.825    , 0.1933333],
#          [3.4      , 3.7375   , 0.7      ],
#          [3.4      , 2.208333 , 0.7      ],
#          ...,
#          [3.125    , 3.975    , 0.265    ],
#          [3.8      , 2.616467 , 2.533533 ],
#          [1.5      , 3.75     , 0.75     ]], dtype=float32),
#   array([[1.5      , 4.033333 , 0.75     ],
#          [3.1375   , 3.3      , 2.6      ],
#          [3.2      , 2.616467 , 2.566467 ],
#          ...,
#          [1.983333 , 4.2      , 0.2666667],
#          [1.55     , 1.1      , 0.2666667],
#          [1.55     , 2.35     , 0.375    ]], dtype=float32),
#   array([[3.775    , 1.65     , 0.05     ],
#          [2.2      , 1.366667 , 0.75     ],
#          [2.2      , 2.75     , 0.4833333],
#          ...,
#          [1.55     , 3.75     , 0.5166667],
#          [3.8      , 3.35     , 2.55     ],
#          [3.2      , 2.566767 , 2.583233 ]], dtype=float32)],
#  'office16': [array([[4.   , 2.   , 2.6  ],
#          [4.   , 2.125, 2.6  ],
#          [4.   , 2.2  , 2.6  ],
#          ...,
#          [4.73 , 3.76 , 0.96 ],
#          [6.04 , 3.81 , 0.745],
#          [5.35 , 2.08 , 0.75 ]], dtype=float32),
#   array([[4.583333, 1.8     , 0.7     ],
#          [7.45    , 3.175   , 0.266667],
#          [8.06    , 2.565   , 0.48    ],
#          ...,
#          [4.931818, 2.8     , 2.581818],
#          [6.145   , 3.81    , 0.96    ],
#          [4.61    , 1.24    , 0.96    ]], dtype=float32),
#   array([[4.73    , 3.81    , 0.96    ],
#          [6.325   , 2.325   , 2.6     ],
#          [4.775   , 3.575   , 0.265   ],
#          ...,
#          [6.191667, 2.5     , 0.7     ],
#          [6.7     , 2.983333, 0.483333],
#          [5.35    , 3.2     , 0.5375  ]], dtype=float32),
#   array([[4.2     , 2.886364, 2.536364],
#          [5.505556, 3.25    , 0.75    ],
#          [4.95    , 2.6     , 2.6     ],
#          ...,
#          [5.25    , 2.766667, 0.05    ],
#          [4.905   , 3.81    , 0.53    ],
#          [3.9     , 2.55    , 0.283333]], dtype=float32)],
#  'office28': [array([[4.35     , 2.5      , 2.6      ],
#          [4.35     , 2.625    , 2.6      ],
#          [4.35     , 2.7      , 2.6      ],
#          ...,
#          [2.733333 , 3.341667 , 0.7      ],
#          [0.99     , 3.9      , 0.96     ],
#          [4.5      , 5.085    , 0.8166667]], dtype=float32),
#   array([[2.716667, 3.825   , 0.7     ],
#          [4.55    , 3.1     , 2.6     ],
#          [5.15    , 2.94    , 2.6     ],
#          ...,
#          [2.95    , 3.308333, 0.75    ],
#          [4.37    , 2.565   , 0.96    ],
#          [3.9125  , 3.125   , 0.7     ]], dtype=float32),
#   array([[4.535    , 5.035    , 0.96     ],
#          [5.233533 , 2.7      , 2.5497   ],
#          [4.455    , 4.85     , 0.3366667],
#          ...,
#          [1.225    , 3.805    , 0.48     ],
#          [4.85     , 3.5      , 2.6      ],
#          [2.325    , 3.175    , 2.6      ]], dtype=float32),
#   array([[3.183333 , 3.308333 , 0.75     ],
#          [2.99     , 2.515    , 0.6733333],
#          [4.75     , 2.65     , 2.6      ],
#          ...,
#          [4.011111 , 3.775    , 0.75     ],
#          [5.2497   , 2.7      , 2.5497   ],
#          [4.16     , 2.721667 , 0.48     ]], dtype=float32)]}

# %%
'''
点群データ増強に合わせて、メタデータや感染リスク分布のデータも複製して増やす
'''
case_index_augumented_list = []

pointCloudArray_list = []
metaArray_list = []

riskArray_list = []

for ID, case_index in enumerate(case_index_list):
    office_name = case_index.split('_', maxsplit=1)[0]
    pc_list = pointCloud_augumented_dict[office_name]
    for augumentID, pointCloud in enumerate(pc_list):
        case_index_augumented_list.append(case_index + '-' + str(augumentID))
        pointCloudArray_list.append(pointCloud)
        metaArray_list.append(df_meta_standardized.loc[case_index])
        riskArray_list.append(risk_mean_standardized[ID])

case_index_array = np.array(case_index_augumented_list)
pointCloudArray = np.array(pointCloudArray_list)
metaArray = np.array(metaArray_list)
riskArray = np.array(riskArray_list)

# %%
print(case_index_array)

print(pointCloudArray)
print(metaArray)

print(riskArray)
# Out:
# ['office2_960_164_aout-0' 'office2_960_164_aout-1'
#  'office2_960_164_aout-2' ... 'office28_960_246_bout-1'
#  'office28_960_246_bout-2' 'office28_960_246_bout-3']
# [[[2.5       2.25      2.6      ]
#   [2.5       2.375     2.6      ]
#   [2.5       2.45      2.6      ]
#   ...
#   [3.745     1.175     0.48     ]
#   [2.878333  4.81      0.53     ]
#   [3.98      1.178     0.53     ]]
#
#  [[3.825     4.7       0.7      ]
#   [3.075     3.027778  0.75     ]
#   [3.775     3.65      0.61     ]
#   ...
#   [3.7       0.99      0.48     ]
#   [4.233333  1.766667  0.7      ]
#   [3.125     5.05      0.2125   ]]
#
#  [[2.7       2.3497    2.566467 ]
#   [4.258333  3.45      0.05     ]
#   [4.475     3.75      0.2125   ]
#   ...
#   [4.475     5.1       0.5166667]
#   [2.7       3.1503    2.6      ]
#   [5.035     2.855     0.53     ]]
#
#  ...
#
#  [[2.716667  3.825     0.7      ]
#   [4.55      3.1       2.6      ]
#   [5.15      2.94      2.6      ]
#   ...
#   [2.95      3.308333  0.75     ]
#   [4.37      2.565     0.96     ]
#   [3.9125    3.125     0.7      ]]
#
#  [[4.535     5.035     0.96     ]
#   [5.233533  2.7       2.5497   ]
#   [4.455     4.85      0.3366667]
#   ...
#   [1.225     3.805     0.48     ]
#   [4.85      3.5       2.6      ]
#   [2.325     3.175     2.6      ]]
#
#  [[3.183333  3.308333  0.75     ]
#   [2.99      2.515     0.6733333]
#   [4.75      2.65      2.6      ]
#   ...
#   [4.011111  3.775     0.75     ]
#   [5.2497    2.7       2.5497   ]
#   [4.16      2.721667  0.48     ]]]
# [[ 1.26154599  0.29495173  1.14324868 -0.87470033 -0.39180195]
#  [ 1.26154599  0.29495173  1.14324868 -0.87470033 -0.39180195]
#  [ 1.26154599  0.29495173  1.14324868 -0.87470033 -0.39180195]
#  ...
#  [ 1.26154599  1.27687963 -0.87470033  1.14324868 -0.39180195]
#  [ 1.26154599  1.27687963 -0.87470033  1.14324868 -0.39180195]
#  [ 1.26154599  1.27687963 -0.87470033  1.14324868 -0.39180195]]
# [[0.9345412 ]
#  [0.9345412 ]
#  [0.9345412 ]
#  ...
#  [0.38780552]
#  [0.38780552]
#  [0.38780552]]

# %%
'''
特定のofficeだけ、テスト用にとっておく。
学習にも、チューニング中の検証にも使わない。
'''

office_for_test = 'office10'
fit_ID = []
test_ID = []

for (ID, case_index) in enumerate(case_index_augumented_list):
    if office_for_test + '_' not in case_index:
        fit_ID.append(ID)
    else:
        test_ID.append(ID)

print(case_index_array[test_ID])
        
case_index_fit = case_index_array[fit_ID]
X_pc_fit = pointCloudArray[fit_ID]
X_meta_fit = metaArray[fit_ID]
y_fit = riskArray[fit_ID]

case_index_test = case_index_array[test_ID]
X_pc_test = pointCloudArray[test_ID]
X_meta_test = metaArray[test_ID]
y_test = riskArray[test_ID]
# Out:
# ['office10_360_164_bout-0' 'office10_360_164_bout-1'
#  'office10_360_164_bout-2' 'office10_360_164_bout-3'
#  'office10_660_246_aout-0' 'office10_660_246_aout-1'
#  'office10_660_246_aout-2' 'office10_660_246_aout-3'
#  'office10_660_82_bout-0' 'office10_660_82_bout-1'
#  'office10_660_82_bout-2' 'office10_660_82_bout-3'
#  'office10_660_82_aout-0' 'office10_660_82_aout-1'
#  'office10_660_82_aout-2' 'office10_660_82_aout-3'
#  'office10_660_164_bout-0' 'office10_660_164_bout-1'
#  'office10_660_164_bout-2' 'office10_660_164_bout-3'
#  'office10_0_164_aout-0' 'office10_0_164_aout-1' 'office10_0_164_aout-2'
#  'office10_0_164_aout-3' 'office10_0_82_aout-0' 'office10_0_82_aout-1'
#  'office10_0_82_aout-2' 'office10_0_82_aout-3' 'office10_660_164_aout-0'
#  'office10_660_164_aout-1' 'office10_660_164_aout-2'
#  'office10_660_164_aout-3' 'office10_660_246_bout-0'
#  'office10_660_246_bout-1' 'office10_660_246_bout-2'
#  'office10_660_246_bout-3' 'office10_360_246_bout-0'
#  'office10_360_246_bout-1' 'office10_360_246_bout-2'
#  'office10_360_246_bout-3' 'office10_960_82_aout-0'
#  'office10_960_82_aout-1' 'office10_960_82_aout-2'
#  'office10_960_82_aout-3' 'office10_360_82_bout-0'
#  'office10_360_82_bout-1' 'office10_360_82_bout-2'
#  'office10_360_82_bout-3' 'office10_360_82_aout-0'
#  'office10_360_82_aout-1' 'office10_360_82_aout-2'
#  'office10_360_82_aout-3' 'office10_0_0-0' 'office10_0_0-1'
#  'office10_0_0-2' 'office10_0_0-3' 'office10_960_164_bout-0'
#  'office10_960_164_bout-1' 'office10_960_164_bout-2'
#  'office10_960_164_bout-3' 'office10_0_246_aout-0' 'office10_0_246_aout-1'
#  'office10_0_246_aout-2' 'office10_0_246_aout-3' 'office10_360_164_aout-0'
#  'office10_360_164_aout-1' 'office10_360_164_aout-2'
#  'office10_360_164_aout-3' 'office10_360_0-0' 'office10_360_0-1'
#  'office10_360_0-2' 'office10_360_0-3' 'office10_0_82_bout-0'
#  'office10_0_82_bout-1' 'office10_0_82_bout-2' 'office10_0_82_bout-3'
#  'office10_960_246_aout-0' 'office10_960_246_aout-1'
#  'office10_960_246_aout-2' 'office10_960_246_aout-3'
#  'office10_960_164_aout-0' 'office10_960_164_aout-1'
#  'office10_960_164_aout-2' 'office10_960_164_aout-3'
#  'office10_0_164_bout-0' 'office10_0_164_bout-1' 'office10_0_164_bout-2'
#  'office10_0_164_bout-3' 'office10_0_246_bout-0' 'office10_0_246_bout-1'
#  'office10_0_246_bout-2' 'office10_0_246_bout-3' 'office10_960_82_bout-0'
#  'office10_960_82_bout-1' 'office10_960_82_bout-2'
#  'office10_960_82_bout-3' 'office10_660_0-0' 'office10_660_0-1'
#  'office10_660_0-2' 'office10_660_0-3' 'office10_360_246_aout-0'
#  'office10_360_246_aout-1' 'office10_360_246_aout-2'
#  'office10_360_246_aout-3' 'office10_960_0-0' 'office10_960_0-1'
#  'office10_960_0-2' 'office10_960_0-3' 'office10_960_246_bout-0'
#  'office10_960_246_bout-1' 'office10_960_246_bout-2'
#  'office10_960_246_bout-3']

# %%
from k_cross_split import get_k_cross_ID_list

'''
チューニングに使うデータを，学習用と検証用に分ける
'''

data_size = len(X_pc_fit)
k = 4
print('data_size =', data_size)
print('k =', k)

#k分割交差検証用の関数だが、ここでは単に訓練データと検証データの分割目的で使う
k_cross_ID_list = get_k_cross_ID_list(data_size, k)

(train_ID, val_ID) = k_cross_ID_list[0]
print(train_ID)
print(val_ID)

X_pc_train = X_pc_fit[train_ID]
X_meta_train = X_meta_fit[train_ID]
y_train = y_fit[train_ID]

X_pc_val = X_pc_fit[val_ID]
X_meta_val = X_meta_fit[val_ID]
y_val = y_fit[val_ID]
# Out:
# data_size = 940
# k = 4
# [4, 768, 601, 188, 893, 226, 490, 450, 244, 785, 811, 75, 894, 636, 473, 340, 28, 455, 284, 153, 810, 224, 287, 897, 414, 702, 371, 143, 772, 51, 186, 710, 610, 69, 797, 262, 86, 11, 432, 263, 871, 540, 358, 826, 155, 482, 676, 693, 201, 116, 850, 309, 167, 285, 273, 935, 842, 146, 71, 603, 173, 776, 239, 755, 795, 40, 854, 726, 370, 227, 429, 326, 885, 891, 443, 377, 879, 925, 567, 454, 530, 369, 461, 293, 250, 930, 292, 225, 678, 586, 136, 698, 132, 845, 355, 626, 41, 97, 539, 605, 164, 241, 682, 647, 122, 910, 172, 67, 596, 181, 385, 246, 709, 691, 609, 364, 779, 525, 724, 299, 697, 413, 487, 624, 89, 800, 238, 840, 538, 884, 844, 535, 495, 444, 72, 621, 860, 672, 289, 500, 486, 147, 343, 488, 283, 76, 901, 368, 882, 363, 690, 247, 807, 399, 353, 275, 334, 474, 376, 841, 210, 707, 195, 264, 723, 301, 349, 276, 321, 604, 921, 8, 563, 85, 193, 600, 267, 386, 877, 716, 507, 861, 533, 183, 65, 451, 818, 667, 203, 156, 506, 514, 50, 374, 689, 665, 271, 419, 759, 862, 748, 774, 277, 741, 843, 191, 361, 578, 727, 185, 825, 590, 13, 617, 913, 481, 73, 517, 440, 859, 24, 216, 623, 47, 184, 426, 170, 290, 127, 934, 757, 515, 177, 219, 436, 27, 501, 63, 886, 498, 240, 117, 914, 243, 151, 858, 649, 683, 168, 584, 620, 628, 58, 666, 618, 418, 88, 154, 407, 634, 124, 694, 228, 56, 251, 685, 823, 745, 868, 26, 616, 212, 372, 320, 524, 670, 718, 234, 520, 332, 559, 566, 420, 708, 233, 3, 549, 829, 179, 677, 396, 337, 140, 457, 767, 410, 786, 365, 808, 34, 528, 448, 430, 378, 497, 627, 923, 749, 295, 824, 644, 852, 298, 479, 323, 513, 763, 493, 562, 658, 503, 809, 595, 550, 357, 159, 16, 784, 788, 319, 280, 19, 762, 898, 2, 821, 931, 791, 433, 643, 625, 711, 307, 591, 770, 714, 912, 558, 522, 903, 106, 771, 656, 54, 611, 782, 638, 31, 61, 553, 467, 546, 55, 29, 848, 214, 253, 633, 675, 705, 545, 66, 939, 512, 674, 799, 48, 379, 108, 502, 109, 875, 938, 459, 354, 424, 798, 612, 5, 659, 81, 557, 190, 777, 217, 98, 722, 743, 389, 213, 270, 765, 265, 847, 204, 96, 99, 20, 428, 23, 423, 569, 561, 887, 564, 712, 79, 302, 753, 926, 651, 134, 801, 730, 441, 10, 736, 296, 532, 892, 731, 544, 235, 93, 583, 908, 855, 577, 279, 17, 362, 796, 521, 120, 742, 752, 551, 266, 87, 14, 64, 640, 83, 314, 890, 719, 537, 830, 622, 758, 57, 732, 46, 311, 915, 222, 909, 350, 589, 330, 793, 929, 403, 209, 33, 684, 402, 229, 180, 751, 619, 42, 310, 397, 445, 268, 44, 637, 812, 316, 439, 294, 803, 837, 463, 576, 259, 827, 920, 692, 92, 431, 101, 906, 347, 53, 465, 9, 661, 111, 832, 345, 761, 141, 632, 458, 453, 548, 7, 509, 194, 653, 312, 542, 646, 165, 382, 59, 248, 608, 460, 278, 437, 35, 919, 211, 822, 110, 435, 580, 662, 715, 395, 881, 701, 18, 103, 373, 470, 663, 641, 242, 387, 113, 221, 257, 317, 125, 629, 527, 878, 728, 288, 206, 820, 269, 114, 927, 575, 131, 335, 924, 664, 329, 139, 272, 45, 700, 356, 754, 422, 207, 902, 77, 816, 36, 189, 375, 831, 328, 68, 864, 534, 30, 469, 764, 756, 80, 650, 346, 928, 480, 607, 642, 313, 536, 406, 390, 249, 865, 746, 471, 205, 597, 327, 158, 706, 835, 286, 291, 504, 587, 529, 336, 261, 880, 932, 169, 555, 384, 25, 516, 352, 876, 95, 673, 135, 518, 405, 614, 836, 84, 22, 123, 427, 834, 679, 452, 496, 297, 208, 648, 856, 819, 417, 366, 571, 602, 308, 182, 464, 220, 570, 760, 560, 49, 794, 425, 442, 322, 849, 392, 485, 733, 787, 547, 867, 359, 778, 137, 613, 606, 456, 671, 680, 394, 594, 39, 434, 230, 922, 839, 187, 421, 21, 734, 699, 237, 907, 720, 750, 142, 655, 438, 635]
# [511, 696, 688, 703, 814, 254, 341, 572, 197, 766, 43, 904, 62, 828, 128, 492, 781, 510, 851, 805, 223, 790, 176, 568, 121, 565, 60, 150, 588, 846, 484, 737, 681, 383, 38, 773, 174, 905, 573, 152, 599, 593, 468, 160, 162, 499, 198, 477, 872, 585, 526, 735, 192, 218, 178, 416, 541, 792, 739, 315, 90, 78, 94, 630, 344, 282, 342, 447, 631, 652, 105, 581, 889, 74, 104, 157, 863, 388, 657, 215, 592, 166, 704, 554, 102, 200, 873, 446, 333, 0, 325, 472, 574, 231, 107, 896, 129, 853, 668, 119, 318, 138, 491, 37, 857, 274, 15, 489, 367, 916, 802, 393, 899, 281, 883, 256, 202, 866, 483, 660, 112, 449, 669, 494, 400, 740, 838, 126, 639, 32, 523, 695, 245, 937, 769, 236, 713, 149, 171, 118, 130, 725, 338, 380, 687, 351, 505, 874, 579, 408, 100, 348, 729, 895, 252, 917, 869, 305, 531, 552, 815, 260, 199, 789, 145, 462, 196, 721, 654, 232, 475, 411, 304, 52, 918, 744, 717, 144, 686, 806, 133, 360, 508, 833, 331, 339, 300, 615, 519, 478, 598, 804, 543, 412, 306, 813, 888, 775, 747, 645, 738, 415, 148, 817, 783, 255, 780, 258, 324, 401, 70, 466, 933, 82, 1, 409, 476, 391, 6, 556, 582, 91, 404, 303, 175, 870, 381, 163, 936, 900, 398, 115, 161, 12, 911]

# %%
case_index_train = case_index_fit[train_ID]
case_index_val = case_index_fit[val_ID]

# %% [markdown]
# # モデル実装

# %%
import IPython
import keras_tuner as kt

# %%
from tensorflow import keras
from PointNet import conv_bn, dense_bn


def permutation_invariant_network_builder(hp, inputs):
    """
    順序不変性（PointNetからtnetを除去したもの）モデルビルダー関数

    ハイパーパラメータを引数にとる（チューニング用）
    """

    x = inputs
    
    hp_conv_bn_layers = hp.Int('conv_bn_layers', min_value = 1, max_value = 4, step = 1)
    for i in range(hp_conv_bn_layers):
        hp_filters_bn = hp.Int(f'filters_bn-{i}', min_value = 32, max_value = 512, step = 32)
        x = conv_bn(x, hp_filters_bn)
    
    x = keras.layers.GlobalMaxPooling1D()(x)
    
    # Tune the dropout rate for the optimizer 
    hp_dropout_rate = hp.Choice('dropout_rate', values = [0.3, 0.5, 0.9])
    
    hp_dense_bn_layers = hp.Int('dense_bn_layers', min_value = 0, max_value = 4, step = 1)
    for i in range(hp_dense_bn_layers):
        hp_units_bn = hp.Int(f'units_bn_{i}', min_value = 32, max_value = 512, step = 32)
        x = dense_bn(x, hp_units_bn)
        x = keras.layers.Dropout(hp_dropout_rate)(x)

    hp_features = hp.Int('features', min_value = 4, max_value = 64, step = 4)
    features = keras.layers.Dense(hp_features, activation="relu")(x)

    return features

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from keras.layers.convolutional import Conv2DTranspose, Conv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Activation
from keras.layers import LeakyReLU

# %%
#確認用コード
# inputs = keras.Input(shape=(metaArray.shape[1], ), name='meta')
# outputs = generator_builder(inputs)
# model = keras.Model(inputs=inputs, outputs=outputs, name="test")
# keras.utils.plot_model(model, show_shapes=True)

# %%
NUM_POINTS = pointCloudArray.shape[1]

def total_model_builder(hp):
    """
    感染リスク分布予測モデル

    順序不変性モデルに、メタデータ（空調条件）を合流させ、
    転置畳み込みで感染リスク分布を出力する。

    KerasTunerから呼び出され、ハイパーパラメータをチューニングする
    """
    input_pointCloud = keras.Input(shape=(NUM_POINTS, 3), name='pointCloud')
    input_meta = keras.Input(shape=(metaArray.shape[1], ), name='meta')

    features_pc = permutation_invariant_network_builder(hp, input_pointCloud)
    
    features = keras.layers.Concatenate()([features_pc, input_meta])
    
    x = features
    
    hp_dense_layers = hp.Int('dense_layers', min_value = 0, max_value = 8, step = 1)
    for i in range(hp_dense_layers):
        hp_units = hp.Int(f'units-{i}', min_value = 32, max_value = 512, step = 32)
        x = keras.layers.Dense(hp_units, activation="relu")(x)
    
    outputs = keras.layers.Dense(1)(x)
#     hp_activation = hp.Int('activation', min_value = 0, max_value = 2, step = 1)
#     if hp_activation == 0:
#         outputs = keras.layers.Dense(1)(x)
        
#     elif hp_activation == 1:
#         outputs = keras.layers.Dense(1, activation="relu", name='dense_relu')(x)
        
#     elif hp_activation == 2:
#         outputs = keras.layers.Dense(1, activation="sigmoid", name='dense_sigmoid')(x)


    hp_learning_rate = hp.Choice('learning_rate', values = [1e-2, 1e-3, 1e-4]) 
    model = keras.Model(inputs=[input_pointCloud, input_meta], outputs=outputs, name="predictionnet")
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
        loss='mse',
        metrics=['mae']
        )

    return model

# %%
import shutil
import datetime

output_dir = '/home/i9-10920x/ML/KerasTuner_log'

# if os.path.exists(output_dir):
#     shutil.rmtree(output_dir)

project = 'RoomRisk_noBody_' + f'no_{office_for_test}_' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

tuner = kt.Hyperband(total_model_builder,
                     objective = 'val_loss', 
                     max_epochs = 100,
                    #  factor = 3,
                     directory = output_dir,
                     project_name = project
                     )

# %%
# %load_ext tensorboard

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import datetime

logdir = os.path.join("tblogs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_cb = keras.callbacks.TensorBoard(log_dir=logdir, histogram_freq=1)

class ClearTrainingOutput(tf.keras.callbacks.Callback):
    def on_train_end(*args, **kwargs):
        IPython.display.clear_output(wait = True)

estop_tuning =  EarlyStopping(monitor='val_loss', min_delta=0.0, patience=10)

# %%
tuner.search({'pointCloud':X_pc_train, 'meta':X_meta_train}, y_train,
             epochs = 100,
             validation_data = ({'pointCloud':X_pc_val, 'meta':X_meta_val}, y_val),
             # callbacks = [tensorboard_cb, estop_tuning, ClearTrainingOutput()])
             callbacks = [estop_tuning, ClearTrainingOutput()])
# Out:
# Trial 254 Complete [00h 00m 09s]
# val_loss: 2542904541184.0
#
# Best val_loss So Far: 0.17521356046199799
# Total elapsed time: 00h 23m 19s
# INFO:tensorflow:Oracle triggered exit

# %%
# %tensorboard --logdir /tblogs

# %%
# function ClickConnect(){
#   console.log("60sごとに再接続");
#   document.querySelector("colab-connect-button").click()
# }
# setInterval(ClickConnect,1000*60);

# %%
# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials = 1)[0]

best_conv_layers =best_hps.get('conv_layers')
print('best_conv_layers = ', best_conv_layers)
for i in range(best_conv_layers):
    print(best_hps.get(f'filters-{i}'))
    
best_dense_layers =best_hps.get('dense_layers')
print('best_dense_layers = ', best_dense_layers)
for i in range(best_dense_layers):
    print(best_hps.get(f'units_{i}'))

print('best_features = ', best_hps.get('features'))
    
print('best_dropout = ', best_hps.get('dropout_rate'))
print('best_learning_rate = ', best_hps.get('learning_rate'))
# Out:
# best_conv_layers =  4
# 352
# 288
# 416
# 32
# best_dense_layers =  0
# best_features =  48
# best_dropout =  0.9
# best_learning_rate =  0.001

# %%
# Build the model with the optimal hyperparameters
model = tuner.hypermodel.build(best_hps)

keras.utils.plot_model(model, show_shapes=True)

# %%
from tensorflow.keras.callbacks import EarlyStopping

estop =  EarlyStopping(monitor='val_loss', min_delta=0.0, patience=20)

best_history = model.fit(
   {'pointCloud':X_pc_fit, 'meta':X_meta_fit}, y_fit,
    epochs = 100,
    validation_data = ({'pointCloud':X_pc_test, 'meta':X_meta_test}, y_test),
    callbacks=[estop]
)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 2s 42ms/step - loss: 0.7951 - mae: 0.6559 - val_loss: 0.3215 - val_mae: 0.4458
# Epoch 2/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.3323 - mae: 0.4495 - val_loss: 0.5478 - val_mae: 0.5612
# Epoch 3/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.2356 - mae: 0.3746 - val_loss: 0.4957 - val_mae: 0.5418
# Epoch 4/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.2136 - mae: 0.3550 - val_loss: 0.5012 - val_mae: 0.5406
# Epoch 5/100
# 30/30 [==============================] - 1s 35ms/step - loss: 0.1797 - mae: 0.3209 - val_loss: 0.4222 - val_mae: 0.4782
# Epoch 6/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.1496 - mae: 0.2956 - val_loss: 0.3388 - val_mae: 0.4290
# Epoch 7/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.1282 - mae: 0.2717 - val_loss: 0.4406 - val_mae: 0.5034
# Epoch 8/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.1137 - mae: 0.2484 - val_loss: 0.3903 - val_mae: 0.4594
# Epoch 9/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.1163 - mae: 0.2554 - val_loss: 0.3551 - val_mae: 0.4488
# Epoch 10/100
# 30/30 [==============================] - 1s 35ms/step - loss: 0.1143 - mae: 0.2541 - val_loss: 0.4100 - val_mae: 0.4772
# Epoch 11/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.1015 - mae: 0.2398 - val_loss: 0.3958 - val_mae: 0.4732
# Epoch 12/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0966 - mae: 0.2335 - val_loss: 0.3275 - val_mae: 0.4105
# Epoch 13/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0874 - mae: 0.2177 - val_loss: 0.3498 - val_mae: 0.4279
# Epoch 14/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0967 - mae: 0.2394 - val_loss: 0.3366 - val_mae: 0.4188
# Epoch 15/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0982 - mae: 0.2425 - val_loss: 0.3155 - val_mae: 0.4109
# Epoch 16/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.1013 - mae: 0.2390 - val_loss: 0.2985 - val_mae: 0.4152
# Epoch 17/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0889 - mae: 0.2260 - val_loss: 0.3859 - val_mae: 0.4611
# Epoch 18/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0805 - mae: 0.2171 - val_loss: 0.4036 - val_mae: 0.4615
# Epoch 19/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0816 - mae: 0.2120 - val_loss: 0.2783 - val_mae: 0.3904
# Epoch 20/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0789 - mae: 0.2153 - val_loss: 0.3738 - val_mae: 0.4475
# Epoch 21/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0658 - mae: 0.1923 - val_loss: 0.4027 - val_mae: 0.4677
# Epoch 22/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0641 - mae: 0.1910 - val_loss: 0.4221 - val_mae: 0.4899
# Epoch 23/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0536 - mae: 0.1752 - val_loss: 0.3486 - val_mae: 0.4347
# Epoch 24/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0590 - mae: 0.1780 - val_loss: 0.2939 - val_mae: 0.4163
# Epoch 25/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0673 - mae: 0.1942 - val_loss: 0.3527 - val_mae: 0.4482
# Epoch 26/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0609 - mae: 0.1870 - val_loss: 0.3511 - val_mae: 0.4537
# Epoch 27/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0592 - mae: 0.1841 - val_loss: 0.4999 - val_mae: 0.5824
# Epoch 28/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0531 - mae: 0.1731 - val_loss: 0.3788 - val_mae: 0.4453
# Epoch 29/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0498 - mae: 0.1672 - val_loss: 0.4517 - val_mae: 0.5286
# Epoch 30/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0473 - mae: 0.1634 - val_loss: 0.3114 - val_mae: 0.3968
# Epoch 31/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0454 - mae: 0.1579 - val_loss: 0.3661 - val_mae: 0.4557
# Epoch 32/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0536 - mae: 0.1788 - val_loss: 0.4361 - val_mae: 0.4956
# Epoch 33/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0396 - mae: 0.1463 - val_loss: 0.4337 - val_mae: 0.4995
# Epoch 34/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0355 - mae: 0.1379 - val_loss: 0.4737 - val_mae: 0.5545
# Epoch 35/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0434 - mae: 0.1575 - val_loss: 0.3828 - val_mae: 0.4715
# Epoch 36/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0385 - mae: 0.1468 - val_loss: 0.3751 - val_mae: 0.4808
# Epoch 37/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0319 - mae: 0.1283 - val_loss: 0.6278 - val_mae: 0.6703
# Epoch 38/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0338 - mae: 0.1343 - val_loss: 0.4896 - val_mae: 0.5396
# Epoch 39/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0296 - mae: 0.1232 - val_loss: 0.4575 - val_mae: 0.5198

# %%
import pandas as pd

def plot_history(history:dict):
    history_df = pd.DataFrame(history)
    
    loss_df = history_df[["loss", "val_loss"]]
    loss_df.plot()
    plt.xlabel("epochs")
    plt.ylabel("Loss")
    # plt.ylim(0., 5.)
    plt.show()

    acc_df = history_df[["mae", "val_mae"]]
    acc_df.plot()
    plt.xlabel("epochs")
    plt.ylabel("MeanAbsoluteError")
    plt.show()

# %%
plot_history(best_history.history)

# %%
y_train_pred = model.predict({'pointCloud':X_pc_train, 'meta':X_meta_train})
y_val_pred = model.predict({'pointCloud':X_pc_val, 'meta':X_meta_val})
y_test_pred = model.predict({'pointCloud':X_pc_test, 'meta':X_meta_test})

# %%
print(y_train_pred.shape)
print(y_val_pred.shape)
print(y_test_pred.shape)
# Out:
# (705, 1)
# (235, 1)
# (112, 1)

# %%
import numpy as np
from matplotlib import pyplot as plt

# yyplot 作成関数
def yyplot(y_obs, y_pred):
    yvalues = np.concatenate([y_obs.flatten(), y_pred.flatten()])
    ymin, ymax, yrange = np.amin(yvalues), np.amax(yvalues), np.ptp(yvalues)
    fig = plt.figure(figsize=(8, 8))
    plt.scatter(y_obs, y_pred)
    plt.plot([ymin - yrange * 0.01, ymax + yrange * 0.01], [ymin - yrange * 0.01, ymax + yrange * 0.01])
    plt.xlim(ymin - yrange * 0.01, ymax + yrange * 0.01)
    plt.ylim(ymin - yrange * 0.01, ymax + yrange * 0.01)
    plt.xlabel('y_observed', fontsize=24)
    plt.ylabel('y_predicted', fontsize=24)
    plt.title('Observed-Predicted Plot', fontsize=24)
    plt.tick_params(labelsize=16)
    plt.show()

    return fig

fig = yyplot(y_test, y_test_pred)

# %%
import importlib
import show_mod
importlib.reload(show_mod)
# Out:
# <module 'show_mod' from '/home/i9-10920x/ML/modules/show_mod.py'>

# %%
#訓練データの正解値
# train_target_2D = train_target.to_numpy()
# train_target_3D = train_target_2D.reshape(-1 , max_num_row, max_num_column)
show_mod.show_images(Y_train, title_name=case_index_train, row=2, column=2, cmap=cmap, cbar=True)

# %%
#訓練データの予測値
# predict_2D = model.predict(test_data, verbose=0)
# predict_3D = predict_2D.reshape(-1, max_num_row, max_num_column)
show_mod.show_images(Y_train_pred, title_name=case_index_train, row=2, column=2, cmap=cmap, cbar=True)

# %%
#検証データの正解値
# test_target_2D = test_target.to_numpy()
# test_target_3D = test_target_2D.reshape(-1, max_num_row, max_num_column)
show_mod.show_images(Y_val, title_name=case_index_val, row=3, column=3, cmap=cmap, cbar=True)

# %%
#検証データの予測値
# predict_2D = model.predict(test_data, verbose=0)
# predict_3D = predict_2D.reshape(-1, max_num_row, max_num_column)
show_mod.show_images(Y_val_pred, title_name=case_index_val, row=3, column=3, cmap=cmap, cbar=True)

# %%
#テストデータの正解値
# test_target_2D = test_target.to_numpy()
# test_target_3D = test_target_2D.reshape(-1, max_num_row, max_num_column)
show_mod.show_images(Y_test, title_name=case_index_test, row=2, column=2, cmap=cmap, cbar=True)

# %%
#テストデータの予測値
# test_target_2D = test_target.to_numpy()
# test_target_3D = test_target_2D.reshape(-1, max_num_row, max_num_column)
show_mod.show_images(Y_test_pred, title_name=case_index_test, row=2, column=2, cmap=cmap, cbar=True)
